# %%
# !git clone https://github.com/VarunGumma/IndicTransToolkit.git
# %cd IndicTransToolkit
# Out:
# Cloning into 'IndicTransToolkit'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 155 (delta 34), reused 45 (delta 30), pack-reused 95 (from 1)
# Receiving objects: 100% (155/155), 3.88 MiB | 11.77 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# /content/IndicTransToolkit

# %%
pip install --editable ./
# Out:
# Obtaining file:///content/IndicTransToolkit
#   Preparing metadata (setup.py) ... done
# Collecting indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library (from IndicTransToolkit==1.0.2)
#   Cloning https://github.com/VarunGumma/indic_nlp_library to /tmp/pip-install-txm7rm1_/indic-nlp-library-it2_327b34f1009d4f318f508fd497d2f93b
#   Running command git clone --filter=blob:none --quiet https://github.com/VarunGumma/indic_nlp_library /tmp/pip-install-txm7rm1_/indic-nlp-library-it2_327b34f1009d4f318f508fd497d2f93b
#   Resolved https://github.com/VarunGumma/indic_nlp_library to commit 601521e05ed0ed8f2165ac317a47d186e25b6f0d
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=68.2.2 in /usr/local/lib/python3.10/dist-packages (from IndicTransToolkit==1.0.2) (75.1.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from IndicTransToolkit==1.0.2) (2.5.0+cu121)
# Collecting sacremoses (from IndicTransToolkit==1.0.2)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from IndicTransToolkit==1.0.2) (0.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from IndicTransToolkit==1.0.2) (4.44.2)
# Collecting sacrebleu (from IndicTransToolkit==1.0.2)
#   Downloading sacrebleu-2.4.3-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.2 MB/s eta 0:00:00
# Collecting sphinx-argparse (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting sphinx_rtd_theme (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2)
#   Downloading sphinx_rtd_theme-3.0.1-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting morfessor (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (1.26.4)
# Collecting portalocker (from sacrebleu->IndicTransToolkit==1.0.2)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu->IndicTransToolkit==1.0.2) (2024.9.11)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu->IndicTransToolkit==1.0.2) (0.9.0)
# Collecting colorama (from sacrebleu->IndicTransToolkit==1.0.2)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu->IndicTransToolkit==1.0.2) (5.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses->IndicTransToolkit==1.0.2) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses->IndicTransToolkit==1.0.2) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sacremoses->IndicTransToolkit==1.0.2) (4.66.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->IndicTransToolkit==1.0.2) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->IndicTransToolkit==1.0.2) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->IndicTransToolkit==1.0.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->IndicTransToolkit==1.0.2) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->IndicTransToolkit==1.0.2) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->IndicTransToolkit==1.0.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->IndicTransToolkit==1.0.2) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers->IndicTransToolkit==1.0.2) (0.24.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers->IndicTransToolkit==1.0.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->IndicTransToolkit==1.0.2) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->IndicTransToolkit==1.0.2) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->IndicTransToolkit==1.0.2) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->IndicTransToolkit==1.0.2) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->IndicTransToolkit==1.0.2) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->IndicTransToolkit==1.0.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->IndicTransToolkit==1.0.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->IndicTransToolkit==1.0.2) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->IndicTransToolkit==1.0.2) (2024.8.30)
# Collecting sphinx>=5.1.0 (from sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2)
#   Downloading sphinx-8.1.3-py3-none-any.whl.metadata (6.4 kB)
# Collecting docutils>=0.19 (from sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2)
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx_rtd_theme->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.0)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.18.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (1.4.1)
# Requirement already satisfied: tomli>=2 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library-IT2@ git+https://github.com/VarunGumma/indic_nlp_library->IndicTransToolkit==1.0.2) (2.0.2)
# Downloading sacrebleu-2.4.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 5.0 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 22.8 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Downloading sphinx_rtd_theme-3.0.1-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 83.1 MB/s eta 0:00:00
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 41.0 MB/s eta 0:00:00
# Downloading sphinx-8.1.3-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 72.2 MB/s eta 0:00:00
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 13.2 MB/s eta 0:00:00
# Building wheels for collected packages: indic-nlp-library-IT2
#   Building wheel for indic-nlp-library-IT2 (setup.py) ... done
#   Created wheel for indic-nlp-library-IT2: filename=indic_nlp_library_IT2-0.0.2-py3-none-any.whl size=49560 sha256=1f7e3e3bd7c1dfd04c2e4707b6cbcb9c729be6ddc6a68e1ea3c90303c3ad2436
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0eny50_r/wheels/e9/72/fa/bd9f19a3f2bacb50efcaf28b7ab89fe7ca539e35b75334befc
# Successfully built indic-nlp-library-IT2
# Installing collected packages: morfessor, sacremoses, portalocker, docutils, colorama, sphinx, sacrebleu, sphinxcontrib-jquery, sphinx-argparse, sphinx_rtd_theme, indic-nlp-library-IT2, IndicTransToolkit
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 5.0.2
#     Uninstalling Sphinx-5.0.2:
#       Successfully uninstalled Sphinx-5.0.2
#   Running setup.py develop for IndicTransToolkit
# Successfully installed IndicTransToolkit-1.0.2 colorama-0.4.6 docutils-0.21.2 indic-nlp-library-IT2-0.0.2 morfessor-2.0.6 portalocker-2.10.1 sacrebleu-2.4.3 sacremoses-0.1.1 sphinx-8.1.3 sphinx-argparse-0.5.2 sphinx_rtd_theme-3.0.1 sphinxcontrib-jquery-4.1

# %%
import torch
from transformers import AutoModelForSeq2SeqLM, BitsAndBytesConfig, AutoTokenizer
from IndicTransToolkit import IndicProcessor

BATCH_SIZE = 4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
quantization = None

# %%
def initialize_model_and_tokenizer(ckpt_dir, quantization):
    if quantization == "4-bit":
        qconfig = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_use_double_quant=True,
            bnb_4bit_compute_dtype=torch.bfloat16,
        )
    elif quantization == "8-bit":
        qconfig = BitsAndBytesConfig(
            load_in_8bit=True,
            bnb_8bit_use_double_quant=True,
            bnb_8bit_compute_dtype=torch.bfloat16,
        )
    else:
        qconfig = None

    tokenizer = AutoTokenizer.from_pretrained(ckpt_dir, trust_remote_code=True)
    model = AutoModelForSeq2SeqLM.from_pretrained(
        ckpt_dir,
        trust_remote_code=True,
        low_cpu_mem_usage=True,
        quantization_config=qconfig,
    )

    if qconfig == None:
        model = model.to(DEVICE)
        if DEVICE == "cuda":
            model.half()

    model.eval()

    return tokenizer, model


def batch_translate(input_sentences, src_lang, tgt_lang, model, tokenizer, ip):
    translations = []
    for i in range(0, len(input_sentences), BATCH_SIZE):
        batch = input_sentences[i : i + BATCH_SIZE]

        # Preprocess the batch and extract entity mappings
        batch = ip.preprocess_batch(batch, src_lang=src_lang, tgt_lang=tgt_lang)

        # Tokenize the batch and generate input encodings
        inputs = tokenizer(
            batch,
            truncation=True,
            padding="longest",
            return_tensors="pt",
            return_attention_mask=True,
        ).to(DEVICE)

        # Generate translations using the model
        with torch.no_grad():
            generated_tokens = model.generate(
                **inputs,
                use_cache=True,
                min_length=0,
                max_length=256,
                num_beams=5,
                num_return_sequences=1,
            )

        # Decode the generated tokens into text

        with tokenizer.as_target_tokenizer():
            generated_tokens = tokenizer.batch_decode(
                generated_tokens.detach().cpu().tolist(),
                skip_special_tokens=True,
                clean_up_tokenization_spaces=True,
            )

        # Postprocess the translations, including entity replacement
        translations += ip.postprocess_batch(generated_tokens, lang=tgt_lang)

        del inputs
        torch.cuda.empty_cache()

    return translations

# %%
en_indic_ckpt_dir = "ai4bharat/indictrans2-en-indic-1B"  # ai4bharat/indictrans2-en-indic-dist-200M
en_indic_tokenizer, en_indic_model = initialize_model_and_tokenizer(en_indic_ckpt_dir, quantization)

ip = IndicProcessor(inference=True)

en_sents = [
    "When I was young, I used to go to the park every day.",
    "He has many old books, which he inherited from his ancestors.",
    "I can't figure out how to solve my problem.",
    "She is very hardworking and intelligent, which is why she got all the good marks.",
    "We watched a new movie last week, which was very inspiring.",
    "If you had met me at that time, we would have gone out to eat.",
    "She went to the market with her sister to buy a new sari.",
    "Raj told me that he is going to his grandmother's house next month.",
    "All the kids were having fun at the party and were eating lots of sweets.",
    "My friend has invited me to his birthday party, and I will give him a gift.",
]

src_lang, tgt_lang = "eng_Latn", "hin_Deva"
hi_translations = batch_translate(en_sents, src_lang, tgt_lang, en_indic_model, en_indic_tokenizer, ip)

print(f"\n{src_lang} - {tgt_lang}")
for input_sentence, translation in zip(en_sents, hi_translations):
    print(f"{src_lang}: {input_sentence}")
    print(f"{tgt_lang}: {translation}")

# flush the models to free the GPU memory
del en_indic_tokenizer, en_indic_model
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# tokenization_indictrans.py:   0%|          | 0.00/8.10k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-1B:
# - tokenization_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# dict.SRC.json:   0%|          | 0.00/645k [00:00<?, ?B/s]
# dict.TGT.json:   0%|          | 0.00/3.39M [00:00<?, ?B/s]
# model.SRC:   0%|          | 0.00/759k [00:00<?, ?B/s]
# model.TGT:   0%|          | 0.00/3.26M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# configuration_indictrans.py:   0%|          | 0.00/14.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-1B:
# - configuration_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_indictrans.py:   0%|          | 0.00/79.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-en-indic-1B:
# - modeling_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors:   0%|          | 0.00/4.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/163 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# eng_Latn - hin_Deva
# eng_Latn: When I was young, I used to go to the park every day.
# hin_Deva: जब मैं छोटा था, मैं हर दिन पार्क जाता था।
# eng_Latn: He has many old books, which he inherited from his ancestors.
# hin_Deva: उनके पास कई पुरानी किताबें हैं, जो उन्हें अपने पूर्वजों से विरासत में मिली हैं।
# eng_Latn: I can't figure out how to solve my problem.
# hin_Deva: मुझे समझ नहीं आ रहा है कि मैं अपनी समस्या का समाधान कैसे करूं।
# eng_Latn: She is very hardworking and intelligent, which is why she got all the good marks.
# hin_Deva: वह बहुत मेहनती और बुद्धिमान है, यही कारण है कि उसे सभी अच्छे अंक मिले।
# eng_Latn: We watched a new movie last week, which was very inspiring.
# hin_Deva: हमने पिछले हफ्ते एक नई फिल्म देखी, जो बहुत प्रेरणादायक थी।
# eng_Latn: If you had met me at that time, we would have gone out to eat.
# hin_Deva: अगर आप उस समय मुझसे मिलते तो हम बाहर खाना खाने जाते।
# eng_Latn: She went to the market with her sister to buy a new sari.
# hin_Deva: वह अपनी बहन के साथ नई साड़ी खरीदने के लिए बाजार गई थी।
# eng_Latn: Raj told me that he is going to his grandmother's house next month.
# hin_Deva: राज ने मुझे बताया कि वह अगले महीने अपनी दादी के घर जा रहा है।
# eng_Latn: All the kids were having fun at the party and were eating lots of sweets.
# hin_Deva: पार्टी में सभी बच्चे खूब मस्ती कर रहे थे और खूब मिठाइयां खा रहे थे।
# eng_Latn: My friend has invited me to his birthday party, and I will give him a gift.
# hin_Deva: मेरे दोस्त ने मुझे अपने जन्मदिन की पार्टी में आमंत्रित किया है, और मैं उसे एक उपहार दूंगा।

# %%
indic_en_ckpt_dir = "ai4bharat/indictrans2-indic-en-1B"  # ai4bharat/indictrans2-indic-en-dist-200M
indic_en_tokenizer, indic_en_model = initialize_model_and_tokenizer(indic_en_ckpt_dir, quantization)

ip = IndicProcessor(inference=True)

hi_sents = [
    "जब मैं छोटा था, मैं हर रोज़ पार्क जाता था।",
    "उसके पास बहुत सारी पुरानी किताबें हैं, जिन्हें उसने अपने दादा-परदादा से विरासत में पाया।",
    "मुझे समझ में नहीं आ रहा कि मैं अपनी समस्या का समाधान कैसे ढूंढूं।",
    "वह बहुत मेहनती और समझदार है, इसलिए उसे सभी अच्छे मार्क्स मिले।",
    "हमने पिछले सप्ताह एक नई फिल्म देखी जो कि बहुत प्रेरणादायक थी।",
    "अगर तुम मुझे उस समय पास मिलते, तो हम बाहर खाना खाने चलते।",
    "वह अपनी दीदी के साथ बाजार गयी थी ताकि वह नई साड़ी खरीद सके।",
    "राज ने मुझसे कहा कि वह अगले महीने अपनी नानी के घर जा रहा है।",
    "सभी बच्चे पार्टी में मज़ा कर रहे थे और खूब सारी मिठाइयाँ खा रहे थे।",
    "मेरे मित्र ने मुझे उसके जन्मदिन की पार्टी में बुलाया है, और मैं उसे एक तोहफा दूंगा।",
]
src_lang, tgt_lang = "hin_Deva", "eng_Latn"
en_translations = batch_translate(hi_sents, src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip)


print(f"\n{src_lang} - {tgt_lang}")
for input_sentence, translation in zip(hi_sents, en_translations):
    print(f"{src_lang}: {input_sentence}")
    print(f"{tgt_lang}: {translation}")

# flush the models to free the GPU memory
del indic_en_tokenizer, indic_en_model
# Out:
# hin_Deva - eng_Latn
# hin_Deva: जब मैं छोटा था, मैं हर रोज़ पार्क जाता था।
# eng_Latn: When I was young, I used to go to the park every day.
# hin_Deva: उसके पास बहुत सारी पुरानी किताबें हैं, जिन्हें उसने अपने दादा-परदादा से विरासत में पाया।
# eng_Latn: She has a lot of old books, which she inherited from her grandparents.
# hin_Deva: मुझे समझ में नहीं आ रहा कि मैं अपनी समस्या का समाधान कैसे ढूंढूं।
# eng_Latn: I don't know how to find a solution to my problem.
# hin_Deva: वह बहुत मेहनती और समझदार है, इसलिए उसे सभी अच्छे मार्क्स मिले।
# eng_Latn: He is very hardworking and understanding, so he got all the good marks.
# hin_Deva: हमने पिछले सप्ताह एक नई फिल्म देखी जो कि बहुत प्रेरणादायक थी।
# eng_Latn: We saw a new movie last week that was very inspiring.
# hin_Deva: अगर तुम मुझे उस समय पास मिलते, तो हम बाहर खाना खाने चलते।
# eng_Latn: If you'd given me a pass at that time, we'd have gone out to eat.
# hin_Deva: वह अपनी दीदी के साथ बाजार गयी थी ताकि वह नई साड़ी खरीद सके।
# eng_Latn: She had gone to the market with her sister so that she could buy a new sari.
# hin_Deva: राज ने मुझसे कहा कि वह अगले महीने अपनी नानी के घर जा रहा है।
# eng_Latn: Raj told me that he was going to his grandmother's house next month.
# hin_Deva: सभी बच्चे पार्टी में मज़ा कर रहे थे और खूब सारी मिठाइयाँ खा रहे थे।
# eng_Latn: All the children were having fun at the party and eating a lot of sweets.
# hin_Deva: मेरे मित्र ने मुझे उसके जन्मदिन की पार्टी में बुलाया है, और मैं उसे एक तोहफा दूंगा।
# eng_Latn: My friend has invited me to her birthday party, and I'll give her a present.

# %%
# !pip install transformers
# !pip install datasets transformers[sentencepiece] sacrebleu
# !pip install nltk
# !pip install torch
# !pip install bert_score
# !pip install torchtext
# !pip install language-tool-python
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.10/dist-packages (2.4.3)
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.19.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.2.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2.10.1)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (5.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 9.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.0 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 20.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.5 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.5.0+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.44.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.66.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2024.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.24.7)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.19.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.2)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13
# Collecting torchtext
#   Downloading torchtext-0.18.0-cp310-cp310-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext) (4.66.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext) (2.32.3)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from torchtext) (2.5.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.3.0->torchtext) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.3.0->torchtext) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.3.0->torchtext) (3.0.2)
# Downloading torchtext-0.18.0-cp310-cp310-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 19.6 MB/s eta 0:00:00
# Installing collected packages: torchtext
# Successfully installed torchtext-0.18.0
# Collecting language-tool-python
#   Downloading language_tool_python-2.8.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (4.66.6)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from language-tool-python) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->language-tool-python) (2024.8.30)
# Downloading language_tool_python-2.8.1-py3-none-any.whl (35 kB)
# Installing collected packages: language-tool-python
# Successfully installed language-tool-python-2.8.1

# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import tensorflow as tf
import torch

# %%
# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
# Define dataset path
dataset_path = "cfilt/iitb-english-hindi"
train_dataset = load_dataset(dataset_path, split="train[:1000]")
# Out:
# README.md:   0%|          | 0.00/3.14k [00:00<?, ?B/s]
# dataset_infos.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/190M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/85.7k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1659083 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/520 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2507 [00:00<?, ? examples/s]

# %%
english_sentences = [item['en'] for item in train_dataset['translation']]
hindi_sentences = [item['hi'] for item in train_dataset['translation']]

# %% [markdown]
# English to Hindi

# %%
en_indic_ckpt_dir = "ai4bharat/indictrans2-en-indic-1B"  # ai4bharat/indictrans2-en-indic-dist-200M
en_indic_tokenizer, en_indic_model = initialize_model_and_tokenizer(en_indic_ckpt_dir, quantization)

ip = IndicProcessor(inference=True)

en_sents = english_sentences
translation_hindi=[]

src_lang, tgt_lang = "eng_Latn", "hin_Deva"
hi_translations = batch_translate(en_sents, src_lang, tgt_lang, en_indic_model, en_indic_tokenizer, ip)

print(f"\n{src_lang} - {tgt_lang}")
for input_sentence, translation in zip(en_sents, hi_translations):
    print(f"{src_lang}: {input_sentence}")
    print(f"{tgt_lang}: {translation}")
    translation_hindi.append(translation)

# flush the models to free the GPU memory
del en_indic_tokenizer, en_indic_model
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:4126: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# eng_Latn - hin_Deva
# eng_Latn: Give your application an accessibility workout
# hin_Deva: अपने अनुप्रयोग को एक सुलभता अभ्यास दें
# eng_Latn: Accerciser Accessibility Explorer
# hin_Deva: एक्सर्साइज़र एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: The default plugin layout for the bottom panel
# hin_Deva: निचला पैनल के लिए डिफ़ॉल्ट प्लगइन लेआउट
# eng_Latn: The default plugin layout for the top panel
# hin_Deva: शीर्ष पटल के लिए पूर्वनिर्धारित प्लगइन लेआउट
# eng_Latn: A list of plugins that are disabled by default
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
# eng_Latn: Highlight duration
# hin_Deva: समयावधि को हाइलाइट करें
# eng_Latn: The duration of the highlight box when selecting accessible nodes
# hin_Deva: सुलभ नोड्स का चयन करते समय हाइलाइट बॉक्स की अवधि
# eng_Latn: Highlight border color
# hin_Deva: सीमा रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight border.
# hin_Deva: हाइलाइट बॉर्डर का रंग और अपारदर्शिता।
# eng_Latn: Highlight fill color
# hin_Deva: भरने के रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight fill.
# hin_Deva: हाइलाइट भरने का रंग और अपारदर्शिता।
# eng_Latn: API Browser
# hin_Deva: एपीआई ब्राउज़र
# eng_Latn: Browse the various methods of the current accessible
# hin_Deva: वर्तमान सुलभ के विभिन्न तरीकों को ब्राउज़ करें।
# eng_Latn: Hide private attributes
# hin_Deva: निजी विशेषताओं को छुपाएँ
# eng_Latn: Method
# hin_Deva: विधि
# eng_Latn: Property
# hin_Deva: संपत्ति
# eng_Latn: Value
# hin_Deva: मूल्य
# eng_Latn: IPython Console
# hin_Deva: IPython कंसोल
# eng_Latn: Interactive console for manipulating currently selected accessible
# hin_Deva: वर्तमान में चयनित सुलभ हेरफेर के लिए अंतःक्रियात्मक कंसोल
# eng_Latn: Event monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: _ Monitor Events
# hin_Deva: घटनाओं की निगरानी करें (_ M)
# eng_Latn: C _ lear Selection
# hin_Deva: सी लीयर चयन (_ l)
# eng_Latn: Everything
# hin_Deva: सब कुछ
# eng_Latn: Selected application
# hin_Deva: चयनित अनुप्रयोग
# eng_Latn: Selected accessible
# hin_Deva: चयनित सुलभ
# eng_Latn: Source
# hin_Deva: स्रोत
# eng_Latn: Event Monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: Shows events as they occur from selected types and sources
# hin_Deva: चयनित प्रकारों और स्रोतों से घटित होने वाली घटनाओं को दिखाता है
# eng_Latn: Highlight last event entry
# hin_Deva: अंतिम कार्यक्रम प्रविष्टि को हाइलाइट करें
# eng_Latn: Start / stop event recording
# hin_Deva: घटना रिकॉर्डिंग शुरू/बंद करें
# eng_Latn: Clear event log
# hin_Deva: इवेंट लॉग साफ़ करें
# eng_Latn: (no description)
# hin_Deva: (कोई विवरण नहीं)
# eng_Latn: Description
# hin_Deva: वर्णन
# eng_Latn: Show
# hin_Deva: दिखाएँ
# eng_Latn: _ Accessible
# hin_Deva: सुलभ (_ A)
# eng_Latn: Perform action
# hin_Deva: क्रिया करें
# eng_Latn: Acti _ on
# hin_Deva: सक्रिय करें (_ o)
# eng_Latn: ID
# hin_Deva: आई. डी.
# eng_Latn: Toolkit
# hin_Deva: टूलकिट
# eng_Latn: Version
# hin_Deva: संस्करण
# eng_Latn: Ap _ plication
# hin_Deva: ए. पी. प्लिकेशन (_ p)
# eng_Latn: Col _ lection
# hin_Deva: कॉल लेक्शन (_ l)
# eng_Latn: 0, 0
# hin_Deva: 0, 0
# eng_Latn: Relative position
# hin_Deva: सापेक्षिक स्थिति
# eng_Latn: Size
# hin_Deva: आकार.
# eng_Latn: WIDGET
# hin_Deva: WIDGET
# eng_Latn: Layer
# hin_Deva: परत
# eng_Latn: MDI - Z - order
# hin_Deva: एम. डी. आई.-जेड.-क्रम
# eng_Latn: Alpha
# hin_Deva: अल्फा
# eng_Latn: Absolute position
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Co _ mponent
# hin_Deva: सह-घटक (_ m)
# eng_Latn: Des _ ktop
# hin_Deva: डेसकॉटॉप (_ k)
# eng_Latn: Locale:
# hin_Deva: स्थानः
# eng_Latn: _ Document
# hin_Deva: दस्तावेज़ (_ D)
# eng_Latn: Hyperlink
# hin_Deva: हाइपरलिंक
# eng_Latn: H _ ypertext
# hin_Deva: H _ yपरटेक्स्ट
# eng_Latn: Position
# hin_Deva: पोजीशन
# eng_Latn: Description
# hin_Deva: वर्णन
# eng_Latn: Locale
# hin_Deva: स्थानीय
# eng_Latn: _ Image
# hin_Deva: छवि (_ I)
# eng_Latn: Lo _ gin Helper
# hin_Deva: लो-जिन सहायक (_ g)
# eng_Latn: Select All
# hin_Deva: सभी चुनें
# eng_Latn: _ Selection
# hin_Deva: चयन (_ S)
# eng_Latn: St _ reamable Content
# hin_Deva: एस. टी. रीमेबल सामग्री (_ r)
# eng_Latn: Selected columns
# hin_Deva: चयनित स्तंभ
# eng_Latn: Selected rows
# hin_Deva: चुनी हुई पंक्तियाँ
# eng_Latn: Columns
# hin_Deva: कॉलम
# eng_Latn: Rows
# hin_Deva: पंक्तियाँ
# eng_Latn: Table Information
# hin_Deva: तालिका की जानकारी
# eng_Latn: name (x, y)
# hin_Deva: नाम (x, y)
# eng_Latn: Header:
# hin_Deva: शीर्षकः
# eng_Latn: Extents:
# hin_Deva: विस्तारः
# eng_Latn: Row
# hin_Deva: पंक्ति
# eng_Latn: Column
# hin_Deva: स्तम्भ
# eng_Latn: Selected Cell
# hin_Deva: चयनित कक्ष
# eng_Latn: _ Table
# hin_Deva: तालिका (_ T)
# eng_Latn: Offset
# hin_Deva: ऑफसेट
# eng_Latn: Include defaults
# hin_Deva: डिफ़ॉल्ट शामिल करें
# eng_Latn: Te _ xt
# hin_Deva: टी. ई. एक्स. टी.
# eng_Latn: Current value
# hin_Deva: वर्तमान मूल्य
# eng_Latn: Minimum increment
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Maximum value
# hin_Deva: अधिकतम मूल्य
# eng_Latn: Minimum value
# hin_Deva: न्यूनतम मूल्य
# eng_Latn: Val _ ue
# hin_Deva: वैल _ यूई
# eng_Latn: Interface Viewer
# hin_Deva: इंटरफेस दर्शक
# eng_Latn: Allows viewing of various interface properties
# hin_Deva: विभिन्न इंटरफेस गुणों को देखने की अनुमति देता है
# eng_Latn: (not implemented)
# hin_Deva: (लागू नहीं किया गया)
# eng_Latn: Name
# hin_Deva: नाम
# eng_Latn: URI
# hin_Deva: यू. आर. आई.
# eng_Latn: Start
# hin_Deva: आरंभ करें।
# eng_Latn: End
# hin_Deva: अंत।
# eng_Latn: Too many selectable children
# hin_Deva: बहुत सारे चुनने योग्य बच्चे
# eng_Latn: Quick Select
# hin_Deva: त्वरित चयन
# eng_Latn: Plugin with various methods of selecting accessibles quickly.
# hin_Deva: जल्दी से एक्सेसिबल चुनने के विभिन्न तरीकों के साथ प्लगइन करें।
# eng_Latn: Inspect last focused accessible
# hin_Deva: अंतिम ध्यान केंद्रित सुलभ का निरीक्षण करें
# eng_Latn: Inspect accessible under mouse
# hin_Deva: माउस के नीचे उपलब्ध निरीक्षण करें
# eng_Latn: Native
# hin_Deva: देशी
# eng_Latn: Dogtail
# hin_Deva: डॉगटेल
# eng_Latn: LDTP
# hin_Deva: एल. डी. टी. पी.
# eng_Latn: Script Type
# hin_Deva: स्क्रिप्टक प्रकार
# eng_Latn: Script Recorder
# hin_Deva: स्क्रिप्ट रिकॉर्डर
# eng_Latn: Creates dogtail style scripts
# hin_Deva: डॉगटेल शैली की लिपियाँ बनाता है
# eng_Latn: The current script will be lost.
# hin_Deva: वर्तमान लिपि खो जाएगी।
# eng_Latn: Confirm clear
# hin_Deva: साफ तौर पर पुष्टि करें
# eng_Latn: Sche _ ma:
# hin_Deva: योजना _ माः
# eng_Latn: V _ alidate
# hin_Deva: वी अलाइडेट (_ a)
# eng_Latn: Idle
# hin_Deva: निष्क्रिय।
# eng_Latn: No description
# hin_Deva: कोई विवरण नहीं
# eng_Latn: AT - SPI Validator
# hin_Deva: ए. टी.-एस. पी. आई. वैलिडेटर
# eng_Latn: Validates application accessibility
# hin_Deva: अनुप्रयोग सुलभता को प्रमाणित करता है
# eng_Latn: Level
# hin_Deva: स्तर
# eng_Latn: Role
# hin_Deva: भूमिका
# eng_Latn: Saving
# hin_Deva: बचत करना।
# eng_Latn: Validating
# hin_Deva: मान्य कर रहे हैं।
# eng_Latn: EXCEPT
# hin_Deva: इसके अलावा
# eng_Latn: ERROR
# hin_Deva: त्रुटि
# eng_Latn: WARN
# hin_Deva: चेतावनी
# eng_Latn: INFO
# hin_Deva: जानकारी
# eng_Latn: DEBUG
# hin_Deva: डी. ई. बी. यू. जी.
# eng_Latn: Basic
# hin_Deva: बुनियादी
# eng_Latn: Tests fundamental GUI application accessibility
# hin_Deva: मौलिक जी. यू. आई. अनुप्रयोग अभिगम्यता का परीक्षण करता है
# eng_Latn: actionable% s is not focusable or selectable
# hin_Deva: कार्रवाई योग्य% s ध्यान केंद्रित करने योग्य या चयन योग्य नहीं है
# eng_Latn: interactive% s is not actionable
# hin_Deva: अंतःक्रियात्मक% s कार्रवाई योग्य नहीं है
# eng_Latn: more than one focused widget
# hin_Deva: एक से अधिक केंद्रित विजेट
# eng_Latn: % s has no text interface
# hin_Deva: % s का कोई पाठ इंटरफेस नहीं है
# eng_Latn: % s index in parent does not match child index
# hin_Deva: माता-पिता में% s सूचकांक बाल सूचकांक से मेल नहीं खाता है
# eng_Latn: Missing reciprocal for% s relation
# hin_Deva: % s संबंध के लिए पारस्परिक गायब है
# eng_Latn: % s missing name or label
# hin_Deva: % s नाम या लेबल गायब है
# eng_Latn: focusable% s has table interface, no selection interface
# hin_Deva: ध्यान केंद्रित करने योग्य% s में टेबल इंटरफेस है, कोई चयन इंटरफेस नहीं है
# eng_Latn: % s has% s state without% s state
# hin_Deva: % s में% s अवस्था बिना% s अवस्था के है
# eng_Latn: % s does not belong to a set
# hin_Deva: % s किसी समूह से संबंधित नहीं है
# eng_Latn: % (rolename) s index% (num) d does not match row and column
# hin_Deva: % (रोलनाम) s सूचकांक% (num) d पंक्ति और स्तंभ से मेल नहीं खाता है
# eng_Latn: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# hin_Deva: % (रोलनाम) का मूल सूचकांक% (num1) d पंक्ति और स्तंभ सूचकांक% (num2) d से मेल नहीं खाता है
# eng_Latn: % s has no name or description
# hin_Deva: % s का कोई नाम या विवरण नहीं है
# eng_Latn: _ Preferences...
# hin_Deva: वरीयताएँ... (_ P)
# eng_Latn: _ Contents
# hin_Deva: सामग्री (_ C)
# eng_Latn: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# hin_Deva: एक्सर्साइज़र आपके डेस्कटॉप पर अनुप्रयोगों को नहीं देख सका। आपको इस समस्या को ठीक करने के लिए डेस्कटॉप पहुँच को सक्षम करना होगा। क्या आप इसे अभी सक्षम करना चाहते हैं?
# eng_Latn: Note: Changes only take effect after logout.
# hin_Deva: नोटः परिवर्तन लॉगआउट के बाद ही प्रभावी होते हैं।
# eng_Latn: Children
# hin_Deva: बच्चे।
# eng_Latn: _ Refresh Registry
# hin_Deva: रजिस्ट्री ताज़ा करें (_ R)
# eng_Latn: Refresh all
# hin_Deva: सब ताज़ा करें
# eng_Latn: Refresh _ Node
# hin_Deva: नोड ताज़ा करें (_ N)
# eng_Latn: Refresh selected node 's children
# hin_Deva: चयनित नोड के बच्चों को ताज़ा करें
# eng_Latn: Component
# hin_Deva: घटक
# eng_Latn: Task
# hin_Deva: कार्य
# eng_Latn: Key
# hin_Deva: कुंजी
# eng_Latn: Alt
# hin_Deva: ऑल्ट
# eng_Latn: Ctrl
# hin_Deva: सी. टी. आर. एल.
# eng_Latn: Shift
# hin_Deva: स्थानांतरण
# eng_Latn: Top panel
# hin_Deva: शीर्ष पैनल
# eng_Latn: Bottom panel
# hin_Deva: निचला पैनल
# eng_Latn: accerciser Preferences
# hin_Deva: ऐक्सरसाइज़र वरीयताएँ
# eng_Latn: Plugins
# hin_Deva: प्लगइन
# eng_Latn: Global Hotkeys
# hin_Deva: वैश्विक हॉटकी
# eng_Latn: Highlighting
# hin_Deva: हाइलाइटिंग
# eng_Latn: Highlight duration:
# hin_Deva: समयावधि पर प्रकाश डालेंः
# eng_Latn: Border color:
# hin_Deva: किनारों का रंगः
# eng_Latn: The border color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का सीमा रंग
# eng_Latn: Fill color:
# hin_Deva: रंग भरेंः
# eng_Latn: The fill color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का रंग भरें
# eng_Latn: translator - credits
# hin_Deva: अनुवादक-श्रेय
# eng_Latn: An interactive Python accessibility explorer
# hin_Deva: एक इंटरैक्टिव पायथन एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# hin_Deva: ऐक्सरसाइजर कॉपीराइट © 2006,2007 आई. बी. एम. कॉर्पोरेशन (बी. एस. डी.)
# eng_Latn: The New BSD License See the COPYING and NOTICE files for details.
# hin_Deva: नया बीएसडी लाइसेंस विवरण के लिए प्रतिलिपि और सूचना फ़ाइलों को देखें।
# eng_Latn: Web site
# hin_Deva: वेबसाइट
# eng_Latn: _ Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें... (_ A)
# eng_Latn: Bookmark selected accessible.
# hin_Deva: बुकमार्क को उपलब्ध चुना गया है।
# eng_Latn: _ Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें... (_ E)
# eng_Latn: Manage bookmarks.
# hin_Deva: बुकमार्क प्रबंधित करें।
# eng_Latn: Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें...
# eng_Latn: Title
# hin_Deva: शीर्षक
# eng_Latn: Application
# hin_Deva: आवेदन
# eng_Latn: Path
# hin_Deva: रास्ता
# eng_Latn: Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें...
# eng_Latn: Title:
# hin_Deva: शीर्षकः
# eng_Latn: Application:
# hin_Deva: आवेदनः
# eng_Latn: Path:
# hin_Deva: मार्गः
# eng_Latn: Plugin Errors
# hin_Deva: प्लगइन त्रुटियाँ
# eng_Latn: View
# hin_Deva: देखें
# eng_Latn: No view
# hin_Deva: कोई दृश्य नहीं
# eng_Latn: _ Single plugins view
# hin_Deva: एकल प्लगइन दृश्य (_ A)
# eng_Latn: Plugin View
# hin_Deva: प्लगइन दृश्य
# eng_Latn: Plugin View (% d)
# hin_Deva: प्लगइन दृश्य (% d)
# eng_Latn: _ New view...
# hin_Deva: नया दृश्य... (_ N)
# eng_Latn: New View...
# hin_Deva: नया दृश्य...
# eng_Latn: _ File
# hin_Deva: फाइल (_ F)
# eng_Latn: _ Edit
# hin_Deva: संपादित करें (_ E)
# eng_Latn: _ Bookmarks
# hin_Deva: बुकमार्क (_ B)
# eng_Latn: _ View
# hin_Deva: देखें (_ V)
# eng_Latn: _ Help
# hin_Deva: मदद करें (_ M)
# eng_Latn: Full name
# hin_Deva: पूरा नाम
# eng_Latn: Key binding
# hin_Deva: कुंजी बंधन
# eng_Latn: Content type
# hin_Deva: सामग्री का प्रकार
# eng_Latn: Give your application an accessibility workout
# hin_Deva: अपने अनुप्रयोग को एक सुलभता अभ्यास दें
# eng_Latn: Accerciser Accessibility Explorer
# hin_Deva: एक्सर्साइज़र एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: The default plugin layout for the bottom panel
# hin_Deva: निचला पैनल के लिए डिफ़ॉल्ट प्लगइन लेआउट
# eng_Latn: The default plugin layout for the top panel
# hin_Deva: शीर्ष पटल के लिए पूर्वनिर्धारित प्लगइन लेआउट
# eng_Latn: A list of plugins that are disabled by default
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
# eng_Latn: Highlight duration
# hin_Deva: समयावधि को हाइलाइट करें
# eng_Latn: The duration of the highlight box when selecting accessible nodes
# hin_Deva: सुलभ नोड्स का चयन करते समय हाइलाइट बॉक्स की अवधि
# eng_Latn: Highlight border color
# hin_Deva: सीमा रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight border.
# hin_Deva: हाइलाइट बॉर्डर का रंग और अपारदर्शिता।
# eng_Latn: Highlight fill color
# hin_Deva: भरने के रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight fill.
# hin_Deva: हाइलाइट भरने का रंग और अपारदर्शिता।
# eng_Latn: API Browser
# hin_Deva: एपीआई ब्राउज़र
# eng_Latn: Browse the various methods of the current accessible
# hin_Deva: वर्तमान सुलभ के विभिन्न तरीकों को ब्राउज़ करें।
# eng_Latn: Hide private attributes
# hin_Deva: निजी विशेषताओं को छुपाएँ
# eng_Latn: Method
# hin_Deva: विधि
# eng_Latn: Property
# hin_Deva: संपत्ति
# eng_Latn: Value
# hin_Deva: मूल्य
# eng_Latn: IPython Console
# hin_Deva: IPython कंसोल
# eng_Latn: Interactive console for manipulating currently selected accessible
# hin_Deva: वर्तमान में चयनित सुलभ हेरफेर के लिए अंतःक्रियात्मक कंसोल
# eng_Latn: Event monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: _ Monitor Events
# hin_Deva: घटनाओं की निगरानी करें (_ M)
# eng_Latn: C _ lear Selection
# hin_Deva: सी लीयर चयन (_ l)
# eng_Latn: Everything
# hin_Deva: सब कुछ
# eng_Latn: Selected application
# hin_Deva: चयनित अनुप्रयोग
# eng_Latn: Selected accessible
# hin_Deva: चयनित सुलभ
# eng_Latn: Source
# hin_Deva: स्रोत
# eng_Latn: Event Monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: Shows events as they occur from selected types and sources
# hin_Deva: चयनित प्रकारों और स्रोतों से घटित होने वाली घटनाओं को दिखाता है
# eng_Latn: Highlight last event entry
# hin_Deva: अंतिम कार्यक्रम प्रविष्टि को हाइलाइट करें
# eng_Latn: Start / stop event recording
# hin_Deva: घटना रिकॉर्डिंग शुरू/बंद करें
# eng_Latn: Clear event log
# hin_Deva: इवेंट लॉग साफ़ करें
# eng_Latn: (no description)
# hin_Deva: (कोई विवरण नहीं)
# eng_Latn: Description
# hin_Deva: वर्णन
# eng_Latn: Show
# hin_Deva: दिखाएँ
# eng_Latn: _ Accessible
# hin_Deva: सुलभ (_ A)
# eng_Latn: Perform action
# hin_Deva: क्रिया करें
# eng_Latn: Acti _ on
# hin_Deva: सक्रिय करें (_ o)
# eng_Latn: ID
# hin_Deva: आई. डी.
# eng_Latn: Toolkit
# hin_Deva: टूलकिट
# eng_Latn: Version
# hin_Deva: संस्करण
# eng_Latn: Ap _ plication
# hin_Deva: ए. पी. प्लिकेशन (_ p)
# eng_Latn: Col _ lection
# hin_Deva: कॉल लेक्शन (_ l)
# eng_Latn: 0, 0
# hin_Deva: 0, 0
# eng_Latn: Relative position
# hin_Deva: सापेक्षिक स्थिति
# eng_Latn: Size
# hin_Deva: आकार.
# eng_Latn: WIDGET
# hin_Deva: WIDGET
# eng_Latn: Layer
# hin_Deva: परत
# eng_Latn: MDI - Z - order
# hin_Deva: एम. डी. आई.-जेड.-क्रम
# eng_Latn: Alpha
# hin_Deva: अल्फा
# eng_Latn: Absolute position
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Co _ mponent
# hin_Deva: सह-घटक (_ m)
# eng_Latn: Des _ ktop
# hin_Deva: डेसकॉटॉप (_ k)
# eng_Latn: Locale:
# hin_Deva: स्थानः
# eng_Latn: _ Document
# hin_Deva: दस्तावेज़ (_ D)
# eng_Latn: Hyperlink
# hin_Deva: हाइपरलिंक
# eng_Latn: H _ ypertext
# hin_Deva: H _ yपरटेक्स्ट
# eng_Latn: Position
# hin_Deva: पोजीशन
# eng_Latn: Description
# hin_Deva: वर्णन
# eng_Latn: Locale
# hin_Deva: स्थानीय
# eng_Latn: _ Image
# hin_Deva: छवि (_ I)
# eng_Latn: Lo _ gin Helper
# hin_Deva: लो-जिन सहायक (_ g)
# eng_Latn: Select All
# hin_Deva: सभी चुनें
# eng_Latn: _ Selection
# hin_Deva: चयन (_ S)
# eng_Latn: St _ reamable Content
# hin_Deva: एस. टी. रीमेबल सामग्री (_ r)
# eng_Latn: Selected columns
# hin_Deva: चयनित स्तंभ
# eng_Latn: Selected rows
# hin_Deva: चुनी हुई पंक्तियाँ
# eng_Latn: Columns
# hin_Deva: कॉलम
# eng_Latn: Rows
# hin_Deva: पंक्तियाँ
# eng_Latn: Table Information
# hin_Deva: तालिका की जानकारी
# eng_Latn: name (x, y)
# hin_Deva: नाम (x, y)
# eng_Latn: Header:
# hin_Deva: शीर्षकः
# eng_Latn: Extents:
# hin_Deva: विस्तारः
# eng_Latn: Row
# hin_Deva: पंक्ति
# eng_Latn: Column
# hin_Deva: स्तम्भ
# eng_Latn: Selected Cell
# hin_Deva: चयनित कक्ष
# eng_Latn: _ Table
# hin_Deva: तालिका (_ T)
# eng_Latn: Offset
# hin_Deva: ऑफसेट
# eng_Latn: Include defaults
# hin_Deva: डिफ़ॉल्ट शामिल करें
# eng_Latn: Te _ xt
# hin_Deva: टी. ई. एक्स. टी.
# eng_Latn: Current value
# hin_Deva: वर्तमान मूल्य
# eng_Latn: Minimum increment
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Maximum value
# hin_Deva: अधिकतम मूल्य
# eng_Latn: Minimum value
# hin_Deva: न्यूनतम मूल्य
# eng_Latn: Val _ ue
# hin_Deva: वैल _ यूई
# eng_Latn: Interface Viewer
# hin_Deva: इंटरफेस दर्शक
# eng_Latn: Allows viewing of various interface properties
# hin_Deva: विभिन्न इंटरफेस गुणों को देखने की अनुमति देता है
# eng_Latn: (not implemented)
# hin_Deva: (लागू नहीं किया गया)
# eng_Latn: Name
# hin_Deva: नाम
# eng_Latn: URI
# hin_Deva: यू. आर. आई.
# eng_Latn: Start
# hin_Deva: आरंभ करें।
# eng_Latn: End
# hin_Deva: अंत।
# eng_Latn: Too many selectable children
# hin_Deva: बहुत सारे चुनने योग्य बच्चे
# eng_Latn: Quick Select
# hin_Deva: त्वरित चयन
# eng_Latn: Plugin with various methods of selecting accessibles quickly.
# hin_Deva: जल्दी से एक्सेसिबल चुनने के विभिन्न तरीकों के साथ प्लगइन करें।
# eng_Latn: Inspect last focused accessible
# hin_Deva: अंतिम ध्यान केंद्रित सुलभ का निरीक्षण करें
# eng_Latn: Inspect accessible under mouse
# hin_Deva: माउस के नीचे उपलब्ध निरीक्षण करें
# eng_Latn: Native
# hin_Deva: देशी
# eng_Latn: Dogtail
# hin_Deva: डॉगटेल
# eng_Latn: LDTP
# hin_Deva: एल. डी. टी. पी.
# eng_Latn: Script Type
# hin_Deva: स्क्रिप्टक प्रकार
# eng_Latn: Script Recorder
# hin_Deva: स्क्रिप्ट रिकॉर्डर
# eng_Latn: Creates dogtail style scripts
# hin_Deva: डॉगटेल शैली की लिपियाँ बनाता है
# eng_Latn: The current script will be lost.
# hin_Deva: वर्तमान लिपि खो जाएगी।
# eng_Latn: Confirm clear
# hin_Deva: साफ तौर पर पुष्टि करें
# eng_Latn: Sche _ ma:
# hin_Deva: योजना _ माः
# eng_Latn: V _ alidate
# hin_Deva: वी अलाइडेट (_ a)
# eng_Latn: Idle
# hin_Deva: निष्क्रिय।
# eng_Latn: No description
# hin_Deva: कोई विवरण नहीं
# eng_Latn: AT - SPI Validator
# hin_Deva: ए. टी.-एस. पी. आई. वैलिडेटर
# eng_Latn: Validates application accessibility
# hin_Deva: अनुप्रयोग सुलभता को प्रमाणित करता है
# eng_Latn: Level
# hin_Deva: स्तर
# eng_Latn: Role
# hin_Deva: भूमिका
# eng_Latn: Saving
# hin_Deva: बचत करना।
# eng_Latn: Validating
# hin_Deva: मान्य कर रहे हैं।
# eng_Latn: EXCEPT
# hin_Deva: इसके अलावा
# eng_Latn: ERROR
# hin_Deva: त्रुटि
# eng_Latn: WARN
# hin_Deva: चेतावनी
# eng_Latn: INFO
# hin_Deva: जानकारी
# eng_Latn: DEBUG
# hin_Deva: डी. ई. बी. यू. जी.
# eng_Latn: Basic
# hin_Deva: बुनियादी
# eng_Latn: Tests fundamental GUI application accessibility
# hin_Deva: मौलिक जी. यू. आई. अनुप्रयोग अभिगम्यता का परीक्षण करता है
# eng_Latn: actionable% s is not focusable or selectable
# hin_Deva: कार्रवाई योग्य% s ध्यान केंद्रित करने योग्य या चयन योग्य नहीं है
# eng_Latn: interactive% s is not actionable
# hin_Deva: अंतःक्रियात्मक% s कार्रवाई योग्य नहीं है
# eng_Latn: more than one focused widget
# hin_Deva: एक से अधिक केंद्रित विजेट
# eng_Latn: % s has no text interface
# hin_Deva: % s का कोई पाठ इंटरफेस नहीं है
# eng_Latn: % s index in parent does not match child index
# hin_Deva: माता-पिता में% s सूचकांक बाल सूचकांक से मेल नहीं खाता है
# eng_Latn: Missing reciprocal for% s relation
# hin_Deva: % s संबंध के लिए पारस्परिक गायब है
# eng_Latn: % s missing name or label
# hin_Deva: % s नाम या लेबल गायब है
# eng_Latn: focusable% s has table interface, no selection interface
# hin_Deva: ध्यान केंद्रित करने योग्य% s में टेबल इंटरफेस है, कोई चयन इंटरफेस नहीं है
# eng_Latn: % s has% s state without% s state
# hin_Deva: % s में% s अवस्था बिना% s अवस्था के है
# eng_Latn: % s does not belong to a set
# hin_Deva: % s किसी समूह से संबंधित नहीं है
# eng_Latn: % (rolename) s index% (num) d does not match row and column
# hin_Deva: % (रोलनाम) s सूचकांक% (num) d पंक्ति और स्तंभ से मेल नहीं खाता है
# eng_Latn: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# hin_Deva: % (रोलनाम) का मूल सूचकांक% (num1) d पंक्ति और स्तंभ सूचकांक% (num2) d से मेल नहीं खाता है
# eng_Latn: % s has no name or description
# hin_Deva: % s का कोई नाम या विवरण नहीं है
# eng_Latn: _ Preferences...
# hin_Deva: वरीयताएँ... (_ P)
# eng_Latn: _ Contents
# hin_Deva: सामग्री (_ C)
# eng_Latn: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# hin_Deva: एक्सर्साइज़र आपके डेस्कटॉप पर अनुप्रयोगों को नहीं देख सका। आपको इस समस्या को ठीक करने के लिए डेस्कटॉप पहुँच को सक्षम करना होगा। क्या आप इसे अभी सक्षम करना चाहते हैं?
# eng_Latn: Note: Changes only take effect after logout.
# hin_Deva: नोटः परिवर्तन लॉगआउट के बाद ही प्रभावी होते हैं।
# eng_Latn: Children
# hin_Deva: बच्चे।
# eng_Latn: _ Refresh Registry
# hin_Deva: रजिस्ट्री ताज़ा करें (_ R)
# eng_Latn: Refresh all
# hin_Deva: सब ताज़ा करें
# eng_Latn: Refresh _ Node
# hin_Deva: नोड ताज़ा करें (_ N)
# eng_Latn: Refresh selected node 's children
# hin_Deva: चयनित नोड के बच्चों को ताज़ा करें
# eng_Latn: Component
# hin_Deva: घटक
# eng_Latn: Task
# hin_Deva: कार्य
# eng_Latn: Key
# hin_Deva: कुंजी
# eng_Latn: Alt
# hin_Deva: ऑल्ट
# eng_Latn: Ctrl
# hin_Deva: सी. टी. आर. एल.
# eng_Latn: Shift
# hin_Deva: स्थानांतरण
# eng_Latn: Top panel
# hin_Deva: शीर्ष पैनल
# eng_Latn: Bottom panel
# hin_Deva: निचला पैनल
# eng_Latn: accerciser Preferences
# hin_Deva: ऐक्सरसाइज़र वरीयताएँ
# eng_Latn: Plugins
# hin_Deva: प्लगइन
# eng_Latn: Global Hotkeys
# hin_Deva: वैश्विक हॉटकी
# eng_Latn: Highlighting
# hin_Deva: हाइलाइटिंग
# eng_Latn: Highlight duration:
# hin_Deva: समयावधि पर प्रकाश डालेंः
# eng_Latn: Border color:
# hin_Deva: किनारों का रंगः
# eng_Latn: The border color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का सीमा रंग
# eng_Latn: Fill color:
# hin_Deva: रंग भरेंः
# eng_Latn: The fill color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का रंग भरें
# eng_Latn: translator - credits
# hin_Deva: अनुवादक-श्रेय
# eng_Latn: An interactive Python accessibility explorer
# hin_Deva: एक इंटरैक्टिव पायथन एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# hin_Deva: ऐक्सरसाइजर कॉपीराइट © 2006,2007 आई. बी. एम. कॉर्पोरेशन (बी. एस. डी.)
# eng_Latn: The New BSD License See the COPYING and NOTICE files for details.
# hin_Deva: नया बीएसडी लाइसेंस विवरण के लिए प्रतिलिपि और सूचना फ़ाइलों को देखें।
# eng_Latn: Web site
# hin_Deva: वेबसाइट
# eng_Latn: _ Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें... (_ A)
# eng_Latn: Bookmark selected accessible.
# hin_Deva: बुकमार्क को उपलब्ध चुना गया है।
# eng_Latn: _ Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें... (_ E)
# eng_Latn: Manage bookmarks.
# hin_Deva: बुकमार्क प्रबंधित करें।
# eng_Latn: Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें...
# eng_Latn: Title
# hin_Deva: शीर्षक
# eng_Latn: Application
# hin_Deva: आवेदन
# eng_Latn: Path
# hin_Deva: रास्ता
# eng_Latn: Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें...
# eng_Latn: Title:
# hin_Deva: शीर्षकः
# eng_Latn: Application:
# hin_Deva: आवेदनः
# eng_Latn: Path:
# hin_Deva: मार्गः
# eng_Latn: Plugin Errors
# hin_Deva: प्लगइन त्रुटियाँ
# eng_Latn: View
# hin_Deva: देखें
# eng_Latn: No view
# hin_Deva: कोई दृश्य नहीं
# eng_Latn: _ Single plugins view
# hin_Deva: एकल प्लगइन दृश्य (_ A)
# eng_Latn: Plugin View
# hin_Deva: प्लगइन दृश्य
# eng_Latn: Plugin View (% d)
# hin_Deva: प्लगइन दृश्य (% d)
# eng_Latn: _ New view...
# hin_Deva: नया दृश्य... (_ N)
# eng_Latn: New View...
# hin_Deva: नया दृश्य...
# eng_Latn: _ File
# hin_Deva: फाइल (_ F)
# eng_Latn: _ Edit
# hin_Deva: संपादित करें (_ E)
# eng_Latn: _ Bookmarks
# hin_Deva: बुकमार्क (_ B)
# eng_Latn: _ View
# hin_Deva: देखें (_ V)
# eng_Latn: _ Help
# hin_Deva: मदद करें (_ M)
# eng_Latn: Full name
# hin_Deva: पूरा नाम
# eng_Latn: Key binding
# hin_Deva: कुंजी बंधन
# eng_Latn: Content type
# hin_Deva: सामग्री का प्रकार
# eng_Latn: Accerciser
# hin_Deva: एक्सर्साइज़र
# eng_Latn: Give your application an accessibility workout
# hin_Deva: अपने अनुप्रयोग को एक सुलभता अभ्यास दें
# eng_Latn: Accerciser Accessibility Explorer
# hin_Deva: एक्सर्साइज़र एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: A list of plugins that are disabled by default
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
# eng_Latn: A list of plugins that are disabled by default.
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं।
# eng_Latn: Highlight duration
# hin_Deva: समयावधि को हाइलाइट करें
# eng_Latn: The duration of the highlight box when selecting accessible nodes.
# hin_Deva: सुलभ नोड्स का चयन करते समय हाइलाइट बॉक्स की अवधि।
# eng_Latn: Highlight fill color
# hin_Deva: भरने के रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight fill.
# hin_Deva: हाइलाइट भरने का रंग और अपारदर्शिता।
# eng_Latn: Highlight border color
# hin_Deva: सीमा रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight border.
# hin_Deva: हाइलाइट बॉर्डर का रंग और अपारदर्शिता।
# eng_Latn: The layout for the bottom panel
# hin_Deva: निचले पैनल के लिए लेआउट
# eng_Latn: The layout for the bottom panel pluginview.
# hin_Deva: निचला पैनल प्लगइनव्यू के लिए लेआउट।
# eng_Latn: The layout for the top panel
# hin_Deva: शीर्ष पटल के लिए लेआउट
# eng_Latn: The layout for the top panel pluginview.
# hin_Deva: शीर्ष पैनल प्लगइनव्यू के लिए लेआउट।
# eng_Latn: Single layout view
# hin_Deva: एकल लेआउट दृश्य
# eng_Latn: Available new pluginviews
# hin_Deva: उपलब्ध नए प्लगइन दृश्य
# eng_Latn: The default plugin layout for the top panel.
# hin_Deva: शीर्ष पटल के लिए डिफ़ॉल्ट प्लगइन लेआउट।
# eng_Latn: API Browser
# hin_Deva: एपीआई ब्राउज़र
# eng_Latn: Browse the various methods of the current accessible
# hin_Deva: वर्तमान सुलभ के विभिन्न तरीकों को ब्राउज़ करें।
# eng_Latn: Hide private attributes
# hin_Deva: निजी विशेषताओं को छुपाएँ
# eng_Latn: Method
# hin_Deva: विधि
# eng_Latn: Property
# hin_Deva: संपत्ति
# eng_Latn: Value
# hin_Deva: मूल्य
# eng_Latn: IPython Console
# hin_Deva: IPython कंसोल
# eng_Latn: Interactive console for manipulating currently selected accessible
# hin_Deva: वर्तमान में चयनित सुलभ हेरफेर के लिए अंतःक्रियात्मक कंसोल
# eng_Latn: Event monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: _ Monitor Events
# hin_Deva: घटनाओं की निगरानी करें (_ M)
# eng_Latn: C _ lear Selection
# hin_Deva: सी लीयर चयन (_ l)
# eng_Latn: Everything
# hin_Deva: सब कुछ
# eng_Latn: Selected application
# hin_Deva: चयनित अनुप्रयोग
# eng_Latn: Selected accessible
# hin_Deva: चयनित सुलभ
# eng_Latn: Source
# hin_Deva: स्रोत
# eng_Latn: Event Monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: Shows events as they occur from selected types and sources
# hin_Deva: चयनित प्रकारों और स्रोतों से घटित होने वाली घटनाओं को दिखाता है
# eng_Latn: Highlight last event entry
# hin_Deva: अंतिम कार्यक्रम प्रविष्टि को हाइलाइट करें
# eng_Latn: Start / stop event recording
# hin_Deva: घटना रिकॉर्डिंग शुरू/बंद करें
# eng_Latn: Clear event log
# hin_Deva: इवेंट लॉग साफ़ करें
# eng_Latn: Child count
# hin_Deva: बच्चों की गिनती
# eng_Latn: Description
# hin_Deva: वर्णन
# eng_Latn: States
# hin_Deva: राज्यों
# eng_Latn: Attributes
# hin_Deva: विशेषताएँ
# eng_Latn: Show
# hin_Deva: दिखाएँ
# eng_Latn: Relations
# hin_Deva: संबंध
# eng_Latn: _ Accessible
# hin_Deva: सुलभ (_ A)
# eng_Latn: Perform action
# hin_Deva: क्रिया करें
# eng_Latn: Acti _ on
# hin_Deva: सक्रिय करें (_ o)
# eng_Latn: ID
# hin_Deva: आई. डी.
# eng_Latn: Toolkit
# hin_Deva: टूलकिट
# eng_Latn: Version
# hin_Deva: संस्करण
# eng_Latn: Ap _ plication
# hin_Deva: ए. पी. प्लिकेशन (_ p)
# eng_Latn: Col _ lection
# hin_Deva: कॉल लेक्शन (_ l)
# eng_Latn: 0, 0
# hin_Deva: 0, 0
# eng_Latn: Relative position
# hin_Deva: सापेक्षिक स्थिति
# eng_Latn: Size
# hin_Deva: आकार.
# eng_Latn: WIDGET
# hin_Deva: WIDGET
# eng_Latn: Layer
# hin_Deva: परत
# eng_Latn: MDI - Z - order
# hin_Deva: एम. डी. आई.-जेड.-क्रम
# eng_Latn: Alpha
# hin_Deva: अल्फा
# eng_Latn: Absolute position
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Co _ mponent
# hin_Deva: सह-घटक (_ m)
# eng_Latn: Des _ ktop
# hin_Deva: डेसकॉटॉप (_ k)
# eng_Latn: Locale:
# hin_Deva: स्थानः
# eng_Latn: _ Document
# hin_Deva: दस्तावेज़ (_ D)
# eng_Latn: Hyperlink
# hin_Deva: हाइपरलिंक
# eng_Latn: H _ ypertext
# hin_Deva: H _ yपरटेक्स्ट
# eng_Latn: Position
# hin_Deva: पोजीशन
# eng_Latn: Locale
# hin_Deva: स्थानीय
# eng_Latn: _ Image
# hin_Deva: छवि (_ I)
# eng_Latn: Lo _ gin Helper
# hin_Deva: लो-जिन सहायक (_ g)
# eng_Latn: Select All
# hin_Deva: सभी चुनें
# eng_Latn: _ Selection
# hin_Deva: चयन (_ S)
# eng_Latn: St _ reamable Content
# hin_Deva: एस. टी. रीमेबल सामग्री (_ r)
# eng_Latn: Caption:
# hin_Deva: शीर्षकः
# eng_Latn: Summary:
# hin_Deva: सारांशः
# eng_Latn: Selected columns
# hin_Deva: चयनित स्तंभ
# eng_Latn: Selected rows
# hin_Deva: चुनी हुई पंक्तियाँ
# eng_Latn: Columns
# hin_Deva: कॉलम
# eng_Latn: Rows
# hin_Deva: पंक्तियाँ
# eng_Latn: Table Information
# hin_Deva: तालिका की जानकारी
# eng_Latn: name (x, y)
# hin_Deva: नाम (x, y)
# eng_Latn: Header:
# hin_Deva: शीर्षकः
# eng_Latn: Extents:
# hin_Deva: विस्तारः
# eng_Latn: Row
# hin_Deva: पंक्ति
# eng_Latn: Column
# hin_Deva: स्तम्भ
# eng_Latn: Selected Cell
# hin_Deva: चयनित कक्ष
# eng_Latn: _ Table
# hin_Deva: तालिका (_ T)
# eng_Latn: Offset
# hin_Deva: ऑफसेट
# eng_Latn: Include defaults
# hin_Deva: डिफ़ॉल्ट शामिल करें
# eng_Latn: Start: 0
# hin_Deva: प्रारम्भः 0
# eng_Latn: End: 0
# hin_Deva: अन्तः 0
# eng_Latn: Te _ xt
# hin_Deva: टी. ई. एक्स. टी.
# eng_Latn: Current value
# hin_Deva: वर्तमान मूल्य
# eng_Latn: Minimum increment
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Maximum value
# hin_Deva: अधिकतम मूल्य
# eng_Latn: Minimum value
# hin_Deva: न्यूनतम मूल्य
# eng_Latn: Val _ ue
# hin_Deva: वैल _ यूई
# eng_Latn: unknown
# hin_Deva: अज्ञात
# eng_Latn: Interface Viewer
# hin_Deva: इंटरफेस दर्शक
# eng_Latn: Allows viewing of various interface properties
# hin_Deva: विभिन्न इंटरफेस गुणों को देखने की अनुमति देता है
# eng_Latn: (not implemented)
# hin_Deva: (लागू नहीं किया गया)
# eng_Latn: Name
# hin_Deva: नाम
# eng_Latn: URI
# hin_Deva: यू. आर. आई.
# eng_Latn: Start
# hin_Deva: आरंभ करें।
# eng_Latn: End
# hin_Deva: अंत।
# eng_Latn: Too many selectable children
# hin_Deva: बहुत सारे चुनने योग्य बच्चे
# eng_Latn: (Editable)
# hin_Deva: (संपादन योग्य)
# eng_Latn: Start:% d
# hin_Deva: शुरुआतः% d
# eng_Latn: Quick Select
# hin_Deva: त्वरित चयन
# eng_Latn: Plugin with various methods of selecting accessibles quickly.
# hin_Deva: जल्दी से एक्सेसिबल चुनने के विभिन्न तरीकों के साथ प्लगइन करें।
# eng_Latn: Inspect last focused accessible
# hin_Deva: अंतिम ध्यान केंद्रित सुलभ का निरीक्षण करें
# eng_Latn: Inspect accessible under mouse
# hin_Deva: माउस के नीचे उपलब्ध निरीक्षण करें
# eng_Latn: Sche _ ma:
# hin_Deva: योजना _ माः
# eng_Latn: V _ alidate
# hin_Deva: वी अलाइडेट (_ a)
# eng_Latn: Idle
# hin_Deva: निष्क्रिय।
# eng_Latn: No description
# hin_Deva: कोई विवरण नहीं
# eng_Latn: AT - SPI Validator
# hin_Deva: ए. टी.-एस. पी. आई. वैलिडेटर
# eng_Latn: Validates application accessibility
# hin_Deva: अनुप्रयोग सुलभता को प्रमाणित करता है
# eng_Latn: Level
# hin_Deva: स्तर
# eng_Latn: Role
# hin_Deva: भूमिका
# eng_Latn: Saving
# hin_Deva: बचत करना।
# eng_Latn: Validating
# hin_Deva: मान्य कर रहे हैं।
# eng_Latn: EXCEPT
# hin_Deva: इसके अलावा
# eng_Latn: ERROR
# hin_Deva: त्रुटि
# eng_Latn: WARN
# hin_Deva: चेतावनी
# eng_Latn: INFO
# hin_Deva: जानकारी
# eng_Latn: DEBUG
# hin_Deva: डी. ई. बी. यू. जी.
# eng_Latn: Basic
# hin_Deva: बुनियादी
# eng_Latn: Tests fundamental GUI application accessibility
# hin_Deva: मौलिक जी. यू. आई. अनुप्रयोग अभिगम्यता का परीक्षण करता है
# eng_Latn: actionable% s is not focusable or selectable
# hin_Deva: कार्रवाई योग्य% s ध्यान केंद्रित करने योग्य या चयन योग्य नहीं है
# eng_Latn: interactive% s is not actionable
# hin_Deva: अंतःक्रियात्मक% s कार्रवाई योग्य नहीं है
# eng_Latn: more than one focused widget
# hin_Deva: एक से अधिक केंद्रित विजेट
# eng_Latn: % s has no text interface
# hin_Deva: % s का कोई पाठ इंटरफेस नहीं है
# eng_Latn: % s index in parent does not match child index
# hin_Deva: माता-पिता में% s सूचकांक बाल सूचकांक से मेल नहीं खाता है
# eng_Latn: Missing reciprocal for% s relation
# hin_Deva: % s संबंध के लिए पारस्परिक गायब है
# eng_Latn: % s missing name or label
# hin_Deva: % s नाम या लेबल गायब है
# eng_Latn: focusable% s has a table interface, but not a selection interface
# hin_Deva: ध्यान केंद्रित करने योग्य% s में एक टेबल इंटरफेस है, लेकिन एक चयन इंटरफेस नहीं है
# eng_Latn: % s has% s state without% s state
# hin_Deva: % s में% s अवस्था बिना% s अवस्था के है
# eng_Latn: % s does not belong to a set
# hin_Deva: % s किसी समूह से संबंधित नहीं है
# eng_Latn: % (rolename) s index% (num) d does not match row and column
# hin_Deva: % (रोलनाम) s सूचकांक% (num) d पंक्ति और स्तंभ से मेल नहीं खाता है
# eng_Latn: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# hin_Deva: % (रोलनाम) का मूल सूचकांक% (num1) d पंक्ति और स्तंभ सूचकांक% (num2) d से मेल नहीं खाता है
# eng_Latn: % s has no name or description
# hin_Deva: % s का कोई नाम या विवरण नहीं है
# eng_Latn: _ Preferences...
# hin_Deva: वरीयताएँ... (_ P)
# eng_Latn: _ Contents
# hin_Deva: सामग्री (_ C)
# eng_Latn: < dead >
# hin_Deva: <मृत>
# eng_Latn: Children
# hin_Deva: बच्चे।
# eng_Latn: _ Hide / Show Applications without children
# hin_Deva: बच्चों के बिना अनुप्रयोग छुपाएँ/दिखाएँ (_ H)
# eng_Latn: _ Refresh Registry
# hin_Deva: रजिस्ट्री ताज़ा करें (_ R)
# eng_Latn: Refresh all
# hin_Deva: सब ताज़ा करें
# eng_Latn: Refresh _ Node
# hin_Deva: नोड ताज़ा करें (_ N)
# eng_Latn: Refresh selected node 's children
# hin_Deva: चयनित नोड के बच्चों को ताज़ा करें
# eng_Latn: Component
# hin_Deva: घटक
# eng_Latn: Task
# hin_Deva: कार्य
# eng_Latn: Key
# hin_Deva: कुंजी
# eng_Latn: Alt
# hin_Deva: ऑल्ट
# eng_Latn: Ctrl
# hin_Deva: सी. टी. आर. एल.
# eng_Latn: Shift
# hin_Deva: स्थानांतरण
# eng_Latn: Top panel
# hin_Deva: शीर्ष पैनल
# eng_Latn: Bottom panel
# hin_Deva: निचला पैनल
# eng_Latn: accerciser Preferences
# hin_Deva: ऐक्सरसाइज़र वरीयताएँ
# eng_Latn: Plugins
# hin_Deva: प्लगइन
# eng_Latn: Global Hotkeys
# hin_Deva: वैश्विक हॉटकी
# eng_Latn: Highlighting
# hin_Deva: हाइलाइटिंग
# eng_Latn: Highlight duration:
# hin_Deva: समयावधि पर प्रकाश डालेंः
# eng_Latn: Border color:
# hin_Deva: किनारों का रंगः
# eng_Latn: The border color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का सीमा रंग
# eng_Latn: Fill color:
# hin_Deva: रंग भरेंः
# eng_Latn: The fill color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का रंग भरें
# eng_Latn: translator - credits
# hin_Deva: अनुवादक-श्रेय
# eng_Latn: An interactive Python accessibility explorer
# hin_Deva: एक इंटरैक्टिव पायथन एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: accerciser Copyright (c) 2006, 2007 IBM Corporation (BSD)
# hin_Deva: ऐक्सरसाइजर कॉपीराइट (सी) 2006,2007 आईबीएम कॉर्पोरेशन (बीएसडी)
# eng_Latn: The New BSD License See the COPYING and NOTICE files for details.
# hin_Deva: नया बीएसडी लाइसेंस विवरण के लिए प्रतिलिपि और सूचना फ़ाइलों को देखें।
# eng_Latn: Web site
# hin_Deva: वेबसाइट
# eng_Latn: _ Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें... (_ A)
# eng_Latn: Bookmark selected accessible.
# hin_Deva: बुकमार्क को उपलब्ध चुना गया है।
# eng_Latn: _ Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें... (_ E)
# eng_Latn: Manage bookmarks.
# hin_Deva: बुकमार्क प्रबंधित करें।
# eng_Latn: Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें...
# eng_Latn: Title
# hin_Deva: शीर्षक
# eng_Latn: Application
# hin_Deva: आवेदन
# eng_Latn: Path
# hin_Deva: रास्ता
# eng_Latn: Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें...
# eng_Latn: Title:
# hin_Deva: शीर्षकः
# eng_Latn: Application:
# hin_Deva: आवेदनः
# eng_Latn: Path:
# hin_Deva: मार्गः
# eng_Latn: Plugin Errors
# hin_Deva: प्लगइन त्रुटियाँ
# eng_Latn: View
# hin_Deva: देखें
# eng_Latn: No view
# hin_Deva: कोई दृश्य नहीं
# eng_Latn: _ Single plugins view
# hin_Deva: एकल प्लगइन दृश्य (_ A)
# eng_Latn: Plugin View
# hin_Deva: प्लगइन दृश्य
# eng_Latn: Plugin View (% d)
# hin_Deva: प्लगइन दृश्य (% d)
# eng_Latn: _ New view...
# hin_Deva: नया दृश्य... (_ N)
# eng_Latn: New View...
# hin_Deva: नया दृश्य...
# eng_Latn: _ File
# hin_Deva: फाइल (_ F)
# eng_Latn: _ Edit
# hin_Deva: संपादित करें (_ E)
# eng_Latn: _ Bookmarks
# hin_Deva: बुकमार्क (_ B)
# eng_Latn: _ View
# hin_Deva: देखें (_ V)
# eng_Latn: _ Help
# hin_Deva: मदद करें (_ M)
# eng_Latn: (no description)
# hin_Deva: (कोई विवरण नहीं)
# eng_Latn: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# hin_Deva: एक्सर्साइज़र आपके डेस्कटॉप पर अनुप्रयोगों को नहीं देख सका। आपको इस समस्या को ठीक करने के लिए डेस्कटॉप पहुँच को सक्षम करना होगा। क्या आप इसे अभी सक्षम करना चाहते हैं?
# eng_Latn: Note: Changes only take effect after logout.
# hin_Deva: नोटः परिवर्तन लॉगआउट के बाद ही प्रभावी होते हैं।
# eng_Latn: _ New view...
# hin_Deva: नया दृश्य... (_ N)
# eng_Latn: Give your application an accessibility workout
# hin_Deva: अपने अनुप्रयोग को एक सुलभता अभ्यास दें
# eng_Latn: Accerciser Accessibility Explorer
# hin_Deva: एक्सर्साइज़र एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: A list of plugins that are disabled by default
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
# eng_Latn: A list of plugins that are disabled by default.
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं।
# eng_Latn: Highlight duration
# hin_Deva: समयावधि को हाइलाइट करें
# eng_Latn: The duration of the highlight box when selecting accessible nodes.
# hin_Deva: सुलभ नोड्स का चयन करते समय हाइलाइट बॉक्स की अवधि।
# eng_Latn: Highlight fill color
# hin_Deva: भरने के रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight fill.
# hin_Deva: हाइलाइट भरने का रंग और अपारदर्शिता।
# eng_Latn: Highlight border color
# hin_Deva: सीमा रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight border.
# hin_Deva: हाइलाइट बॉर्डर का रंग और अपारदर्शिता।
# eng_Latn: The layout for the bottom panel
# hin_Deva: निचले पैनल के लिए लेआउट
# eng_Latn: The layout for the bottom panel pluginview.
# hin_Deva: निचला पैनल प्लगइनव्यू के लिए लेआउट।
# eng_Latn: The layout for the top panel
# hin_Deva: शीर्ष पटल के लिए लेआउट
# eng_Latn: The layout for the top panel pluginview.
# hin_Deva: शीर्ष पैनल प्लगइनव्यू के लिए लेआउट।
# eng_Latn: Single layout view
# hin_Deva: एकल लेआउट दृश्य
# eng_Latn: Available new pluginviews
# hin_Deva: उपलब्ध नए प्लगइन दृश्य
# eng_Latn: The default plugin layout for the top panel.
# hin_Deva: शीर्ष पटल के लिए डिफ़ॉल्ट प्लगइन लेआउट।
# eng_Latn: API Browser
# hin_Deva: एपीआई ब्राउज़र
# eng_Latn: Browse the various methods of the current accessible
# hin_Deva: वर्तमान सुलभ के विभिन्न तरीकों को ब्राउज़ करें।
# eng_Latn: Hide private attributes
# hin_Deva: निजी विशेषताओं को छुपाएँ
# eng_Latn: Method
# hin_Deva: विधि
# eng_Latn: Property
# hin_Deva: संपत्ति
# eng_Latn: Value
# hin_Deva: मूल्य
# eng_Latn: IPython Console
# hin_Deva: IPython कंसोल
# eng_Latn: Interactive console for manipulating currently selected accessible
# hin_Deva: वर्तमान में चयनित सुलभ हेरफेर के लिए अंतःक्रियात्मक कंसोल
# eng_Latn: Event monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: _ Monitor Events
# hin_Deva: घटनाओं की निगरानी करें (_ M)
# eng_Latn: C _ lear Selection
# hin_Deva: सी लीयर चयन (_ l)
# eng_Latn: Everything
# hin_Deva: सब कुछ
# eng_Latn: Selected application
# hin_Deva: चयनित अनुप्रयोग
# eng_Latn: Selected accessible
# hin_Deva: चयनित सुलभ
# eng_Latn: Source
# hin_Deva: स्रोत
# eng_Latn: Event Monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: Shows events as they occur from selected types and sources
# hin_Deva: चयनित प्रकारों और स्रोतों से घटित होने वाली घटनाओं को दिखाता है
# eng_Latn: Highlight last event entry
# hin_Deva: अंतिम कार्यक्रम प्रविष्टि को हाइलाइट करें
# eng_Latn: Start / stop event recording
# hin_Deva: घटना रिकॉर्डिंग शुरू/बंद करें
# eng_Latn: Clear event log
# hin_Deva: इवेंट लॉग साफ़ करें
# eng_Latn: (no description)
# hin_Deva: (कोई विवरण नहीं)
# eng_Latn: Description
# hin_Deva: वर्णन
# eng_Latn: Show
# hin_Deva: दिखाएँ
# eng_Latn: _ Accessible
# hin_Deva: सुलभ (_ A)
# eng_Latn: Perform action
# hin_Deva: क्रिया करें
# eng_Latn: Acti _ on
# hin_Deva: सक्रिय करें (_ o)
# eng_Latn: ID
# hin_Deva: आई. डी.
# eng_Latn: Toolkit
# hin_Deva: टूलकिट
# eng_Latn: Version
# hin_Deva: संस्करण
# eng_Latn: Ap _ plication
# hin_Deva: ए. पी. प्लिकेशन (_ p)
# eng_Latn: Col _ lection
# hin_Deva: कॉल लेक्शन (_ l)
# eng_Latn: 0, 0
# hin_Deva: 0, 0
# eng_Latn: Relative position
# hin_Deva: सापेक्षिक स्थिति
# eng_Latn: Size
# hin_Deva: आकार.
# eng_Latn: WIDGET
# hin_Deva: WIDGET
# eng_Latn: Layer
# hin_Deva: परत
# eng_Latn: MDI - Z - order
# hin_Deva: एम. डी. आई.-जेड.-क्रम
# eng_Latn: Alpha
# hin_Deva: अल्फा
# eng_Latn: Absolute position
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Co _ mponent
# hin_Deva: सह-घटक (_ m)
# eng_Latn: Des _ ktop
# hin_Deva: डेसकॉटॉप (_ k)
# eng_Latn: Locale:
# hin_Deva: स्थानः
# eng_Latn: _ Document
# hin_Deva: दस्तावेज़ (_ D)
# eng_Latn: Hyperlink
# hin_Deva: हाइपरलिंक
# eng_Latn: H _ ypertext
# hin_Deva: H _ yपरटेक्स्ट
# eng_Latn: Position
# hin_Deva: पोजीशन
# eng_Latn: Description
# hin_Deva: वर्णन
# eng_Latn: Locale
# hin_Deva: स्थानीय
# eng_Latn: _ Image
# hin_Deva: छवि (_ I)
# eng_Latn: Lo _ gin Helper
# hin_Deva: लो-जिन सहायक (_ g)
# eng_Latn: Select All
# hin_Deva: सभी चुनें
# eng_Latn: _ Selection
# hin_Deva: चयन (_ S)
# eng_Latn: St _ reamable Content
# hin_Deva: एस. टी. रीमेबल सामग्री (_ r)
# eng_Latn: Selected columns
# hin_Deva: चयनित स्तंभ
# eng_Latn: Selected rows
# hin_Deva: चुनी हुई पंक्तियाँ
# eng_Latn: Columns
# hin_Deva: कॉलम
# eng_Latn: Rows
# hin_Deva: पंक्तियाँ
# eng_Latn: Table Information
# hin_Deva: तालिका की जानकारी
# eng_Latn: name (x, y)
# hin_Deva: नाम (x, y)
# eng_Latn: Header:
# hin_Deva: शीर्षकः
# eng_Latn: Extents:
# hin_Deva: विस्तारः
# eng_Latn: Row
# hin_Deva: पंक्ति
# eng_Latn: Column
# hin_Deva: स्तम्भ
# eng_Latn: Selected Cell
# hin_Deva: चयनित कक्ष
# eng_Latn: _ Table
# hin_Deva: तालिका (_ T)
# eng_Latn: Offset
# hin_Deva: ऑफसेट
# eng_Latn: Include defaults
# hin_Deva: डिफ़ॉल्ट शामिल करें
# eng_Latn: Te _ xt
# hin_Deva: टी. ई. एक्स. टी.
# eng_Latn: Current value
# hin_Deva: वर्तमान मूल्य
# eng_Latn: Minimum increment
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Maximum value
# hin_Deva: अधिकतम मूल्य
# eng_Latn: Minimum value
# hin_Deva: न्यूनतम मूल्य
# eng_Latn: Val _ ue
# hin_Deva: वैल _ यूई
# eng_Latn: Interface Viewer
# hin_Deva: इंटरफेस दर्शक
# eng_Latn: Allows viewing of various interface properties
# hin_Deva: विभिन्न इंटरफेस गुणों को देखने की अनुमति देता है
# eng_Latn: (not implemented)
# hin_Deva: (लागू नहीं किया गया)
# eng_Latn: Name
# hin_Deva: नाम
# eng_Latn: URI
# hin_Deva: यू. आर. आई.
# eng_Latn: Start
# hin_Deva: आरंभ करें।
# eng_Latn: End
# hin_Deva: अंत।
# eng_Latn: Too many selectable children
# hin_Deva: बहुत सारे चुनने योग्य बच्चे
# eng_Latn: Quick Select
# hin_Deva: त्वरित चयन
# eng_Latn: Plugin with various methods of selecting accessibles quickly.
# hin_Deva: जल्दी से एक्सेसिबल चुनने के विभिन्न तरीकों के साथ प्लगइन करें।
# eng_Latn: Inspect last focused accessible
# hin_Deva: अंतिम ध्यान केंद्रित सुलभ का निरीक्षण करें
# eng_Latn: Inspect accessible under mouse
# hin_Deva: माउस के नीचे उपलब्ध निरीक्षण करें
# eng_Latn: Sche _ ma:
# hin_Deva: योजना _ माः
# eng_Latn: V _ alidate
# hin_Deva: वी अलाइडेट (_ a)
# eng_Latn: Idle
# hin_Deva: निष्क्रिय।
# eng_Latn: No description
# hin_Deva: कोई विवरण नहीं
# eng_Latn: AT - SPI Validator
# hin_Deva: ए. टी.-एस. पी. आई. वैलिडेटर
# eng_Latn: Validates application accessibility
# hin_Deva: अनुप्रयोग सुलभता को प्रमाणित करता है
# eng_Latn: Level
# hin_Deva: स्तर
# eng_Latn: Role
# hin_Deva: भूमिका
# eng_Latn: Saving
# hin_Deva: बचत करना।
# eng_Latn: Validating
# hin_Deva: मान्य कर रहे हैं।
# eng_Latn: EXCEPT
# hin_Deva: इसके अलावा
# eng_Latn: ERROR
# hin_Deva: त्रुटि
# eng_Latn: WARN
# hin_Deva: चेतावनी
# eng_Latn: INFO
# hin_Deva: जानकारी
# eng_Latn: DEBUG
# hin_Deva: डी. ई. बी. यू. जी.
# eng_Latn: Basic
# hin_Deva: बुनियादी
# eng_Latn: Tests fundamental GUI application accessibility
# hin_Deva: मौलिक जी. यू. आई. अनुप्रयोग अभिगम्यता का परीक्षण करता है
# eng_Latn: actionable% s is not focusable or selectable
# hin_Deva: कार्रवाई योग्य% s ध्यान केंद्रित करने योग्य या चयन योग्य नहीं है
# eng_Latn: interactive% s is not actionable
# hin_Deva: अंतःक्रियात्मक% s कार्रवाई योग्य नहीं है
# eng_Latn: more than one focused widget
# hin_Deva: एक से अधिक केंद्रित विजेट
# eng_Latn: % s has no text interface
# hin_Deva: % s का कोई पाठ इंटरफेस नहीं है
# eng_Latn: % s index in parent does not match child index
# hin_Deva: माता-पिता में% s सूचकांक बाल सूचकांक से मेल नहीं खाता है
# eng_Latn: Missing reciprocal for% s relation
# hin_Deva: % s संबंध के लिए पारस्परिक गायब है
# eng_Latn: % s missing name or label
# hin_Deva: % s नाम या लेबल गायब है
# eng_Latn: focusable% s has a table interface, but not a selection interface
# hin_Deva: ध्यान केंद्रित करने योग्य% s में एक टेबल इंटरफेस है, लेकिन एक चयन इंटरफेस नहीं है
# eng_Latn: % s has% s state without% s state
# hin_Deva: % s में% s अवस्था बिना% s अवस्था के है
# eng_Latn: % s does not belong to a set
# hin_Deva: % s किसी समूह से संबंधित नहीं है
# eng_Latn: % (rolename) s index% (num) d does not match row and column
# hin_Deva: % (रोलनाम) s सूचकांक% (num) d पंक्ति और स्तंभ से मेल नहीं खाता है
# eng_Latn: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# hin_Deva: % (रोलनाम) का मूल सूचकांक% (num1) d पंक्ति और स्तंभ सूचकांक% (num2) d से मेल नहीं खाता है
# eng_Latn: % s has no name or description
# hin_Deva: % s का कोई नाम या विवरण नहीं है
# eng_Latn: _ Preferences...
# hin_Deva: वरीयताएँ... (_ P)
# eng_Latn: _ Contents
# hin_Deva: सामग्री (_ C)
# eng_Latn: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# hin_Deva: एक्सर्साइज़र आपके डेस्कटॉप पर अनुप्रयोगों को नहीं देख सका। आपको इस समस्या को ठीक करने के लिए डेस्कटॉप पहुँच को सक्षम करना होगा। क्या आप इसे अभी सक्षम करना चाहते हैं?
# eng_Latn: Note: Changes only take effect after logout.
# hin_Deva: नोटः परिवर्तन लॉगआउट के बाद ही प्रभावी होते हैं।
# eng_Latn: Children
# hin_Deva: बच्चे।
# eng_Latn: _ Refresh Registry
# hin_Deva: रजिस्ट्री ताज़ा करें (_ R)
# eng_Latn: Refresh all
# hin_Deva: सब ताज़ा करें
# eng_Latn: Refresh _ Node
# hin_Deva: नोड ताज़ा करें (_ N)
# eng_Latn: Refresh selected node 's children
# hin_Deva: चयनित नोड के बच्चों को ताज़ा करें
# eng_Latn: Component
# hin_Deva: घटक
# eng_Latn: Task
# hin_Deva: कार्य
# eng_Latn: Key
# hin_Deva: कुंजी
# eng_Latn: Alt
# hin_Deva: ऑल्ट
# eng_Latn: Ctrl
# hin_Deva: सी. टी. आर. एल.
# eng_Latn: Shift
# hin_Deva: स्थानांतरण
# eng_Latn: Top panel
# hin_Deva: शीर्ष पैनल
# eng_Latn: Bottom panel
# hin_Deva: निचला पैनल
# eng_Latn: accerciser Preferences
# hin_Deva: ऐक्सरसाइज़र वरीयताएँ
# eng_Latn: Plugins
# hin_Deva: प्लगइन
# eng_Latn: Global Hotkeys
# hin_Deva: वैश्विक हॉटकी
# eng_Latn: Highlighting
# hin_Deva: हाइलाइटिंग
# eng_Latn: Highlight duration:
# hin_Deva: समयावधि पर प्रकाश डालेंः
# eng_Latn: Border color:
# hin_Deva: किनारों का रंगः
# eng_Latn: The border color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का सीमा रंग
# eng_Latn: Fill color:
# hin_Deva: रंग भरेंः
# eng_Latn: The fill color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का रंग भरें
# eng_Latn: translator - credits
# hin_Deva: अनुवादक-श्रेय
# eng_Latn: An interactive Python accessibility explorer
# hin_Deva: एक इंटरैक्टिव पायथन एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: accerciser Copyright (c) 2006, 2007 IBM Corporation (BSD)
# hin_Deva: ऐक्सरसाइजर कॉपीराइट (सी) 2006,2007 आईबीएम कॉर्पोरेशन (बीएसडी)
# eng_Latn: The New BSD License See the COPYING and NOTICE files for details.
# hin_Deva: नया बीएसडी लाइसेंस विवरण के लिए प्रतिलिपि और सूचना फ़ाइलों को देखें।
# eng_Latn: Web site
# hin_Deva: वेबसाइट
# eng_Latn: _ Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें... (_ A)
# eng_Latn: Bookmark selected accessible.
# hin_Deva: बुकमार्क को उपलब्ध चुना गया है।
# eng_Latn: _ Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें... (_ E)
# eng_Latn: Manage bookmarks.
# hin_Deva: बुकमार्क प्रबंधित करें।
# eng_Latn: Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें...
# eng_Latn: Title
# hin_Deva: शीर्षक
# eng_Latn: Application
# hin_Deva: आवेदन
# eng_Latn: Path
# hin_Deva: रास्ता
# eng_Latn: Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें...
# eng_Latn: Title:
# hin_Deva: शीर्षकः
# eng_Latn: Application:
# hin_Deva: आवेदनः
# eng_Latn: Path:
# hin_Deva: मार्गः
# eng_Latn: Plugin Errors
# hin_Deva: प्लगइन त्रुटियाँ
# eng_Latn: View
# hin_Deva: देखें
# eng_Latn: No view
# hin_Deva: कोई दृश्य नहीं
# eng_Latn: _ Single plugins view
# hin_Deva: एकल प्लगइन दृश्य (_ A)
# eng_Latn: Plugin View
# hin_Deva: प्लगइन दृश्य
# eng_Latn: Plugin View (% d)
# hin_Deva: प्लगइन दृश्य (% d)
# eng_Latn: _ New view...
# hin_Deva: नया दृश्य... (_ N)
# eng_Latn: New View...
# hin_Deva: नया दृश्य...
# eng_Latn: _ File
# hin_Deva: फाइल (_ F)
# eng_Latn: _ Edit
# hin_Deva: संपादित करें (_ E)
# eng_Latn: _ Bookmarks
# hin_Deva: बुकमार्क (_ B)
# eng_Latn: _ View
# hin_Deva: देखें (_ V)
# eng_Latn: _ Help
# hin_Deva: मदद करें (_ M)
# eng_Latn: Accerciser
# hin_Deva: एक्सर्साइज़र
# eng_Latn: Give your application an accessibility workout
# hin_Deva: अपने अनुप्रयोग को एक सुलभता अभ्यास दें
# eng_Latn: Accerciser Accessibility Explorer
# hin_Deva: एक्सर्साइज़र एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: A list of plugins that are disabled by default
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
# eng_Latn: A list of plugins that are disabled by default.
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं।
# eng_Latn: Highlight duration
# hin_Deva: समयावधि को हाइलाइट करें
# eng_Latn: The duration of the highlight box when selecting accessible nodes.
# hin_Deva: सुलभ नोड्स का चयन करते समय हाइलाइट बॉक्स की अवधि।
# eng_Latn: Highlight fill color
# hin_Deva: भरने के रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight fill.
# hin_Deva: हाइलाइट भरने का रंग और अपारदर्शिता।
# eng_Latn: Highlight border color
# hin_Deva: सीमा रंग को हाइलाइट करें
# eng_Latn: The color and opacity of the highlight border.
# hin_Deva: हाइलाइट बॉर्डर का रंग और अपारदर्शिता।
# eng_Latn: Horizontal split
# hin_Deva: क्षैतिज विभाजन
# eng_Latn: Position of the horizontal split of the main window.
# hin_Deva: मुख्य खिड़की के क्षैतिज विभाजन की स्थिति।
# eng_Latn: Vertical split
# hin_Deva: ऊर्ध्वाधर विभाजन
# eng_Latn: Position of the vertical split of the main window.
# hin_Deva: मुख्य खिड़की के ऊर्ध्वाधर विभाजन की स्थिति।
# eng_Latn: Default window height
# hin_Deva: डिफ़ॉल्ट विंडो ऊँचाई
# eng_Latn: The window height value.
# hin_Deva: खिड़की की ऊँचाई का मान।
# eng_Latn: Default window width
# hin_Deva: डिफ़ॉल्ट विंडो चौड़ाई
# eng_Latn: The window width value.
# hin_Deva: विंडो चौड़ाई मान।
# eng_Latn: The layout for the bottom panel
# hin_Deva: निचले पैनल के लिए लेआउट
# eng_Latn: The layout for the bottom panel pluginview.
# hin_Deva: निचला पैनल प्लगइनव्यू के लिए लेआउट।
# eng_Latn: The layout for the top panel
# hin_Deva: शीर्ष पटल के लिए लेआउट
# eng_Latn: The layout for the top panel pluginview.
# hin_Deva: शीर्ष पैनल प्लगइनव्यू के लिए लेआउट।
# eng_Latn: Single layout view
# hin_Deva: एकल लेआउट दृश्य
# eng_Latn: View plugins in a single layout.
# hin_Deva: एकल लेआउट में प्लगइन देखें।
# eng_Latn: Available new pluginviews
# hin_Deva: उपलब्ध नए प्लगइन दृश्य
# eng_Latn: This list contains all the new available pluginviews
# hin_Deva: इस सूची में सभी नए उपलब्ध प्लगइन दृश्य शामिल हैं।
# eng_Latn: The pluginview layout
# hin_Deva: प्लगइनव्यू लेआउट
# eng_Latn: The default plugin layout for the top panel.
# hin_Deva: शीर्ष पटल के लिए डिफ़ॉल्ट प्लगइन लेआउट।
# eng_Latn: Window height
# hin_Deva: खिड़की की ऊँचाई
# eng_Latn: Window height value.
# hin_Deva: खिड़की की ऊँचाई का मान।
# eng_Latn: Window width
# hin_Deva: खिड़की की चौड़ाई
# eng_Latn: Window width value.
# hin_Deva: विंडो चौड़ाई मान।
# eng_Latn: Hotkey combination
# hin_Deva: हॉटकी संयोजन
# eng_Latn: Hotkey combination for related action.
# hin_Deva: संबंधित कार्रवाई के लिए हॉटकी संयोजन।
# eng_Latn: API Browser
# hin_Deva: एपीआई ब्राउज़र
# eng_Latn: Browse the various methods of the current accessible
# hin_Deva: वर्तमान सुलभ के विभिन्न तरीकों को ब्राउज़ करें।
# eng_Latn: Hide private attributes
# hin_Deva: निजी विशेषताओं को छुपाएँ
# eng_Latn: Method
# hin_Deva: विधि
# eng_Latn: Property
# hin_Deva: संपत्ति
# eng_Latn: Value
# hin_Deva: मूल्य
# eng_Latn: IPython Console
# hin_Deva: IPython कंसोल
# eng_Latn: Interactive console for manipulating currently selected accessible
# hin_Deva: वर्तमान में चयनित सुलभ हेरफेर के लिए अंतःक्रियात्मक कंसोल
# eng_Latn: Event monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: _ Monitor Events
# hin_Deva: घटनाओं की निगरानी करें (_ M)
# eng_Latn: C _ lear Selection
# hin_Deva: सी लीयर चयन (_ l)
# eng_Latn: Everything
# hin_Deva: सब कुछ
# eng_Latn: Selected application
# hin_Deva: चयनित अनुप्रयोग
# eng_Latn: Selected accessible
# hin_Deva: चयनित सुलभ
# eng_Latn: Source
# hin_Deva: स्रोत
# eng_Latn: Event Monitor
# hin_Deva: इवेंट मॉनिटर
# eng_Latn: Shows events as they occur from selected types and sources
# hin_Deva: चयनित प्रकारों और स्रोतों से घटित होने वाली घटनाओं को दिखाता है
# eng_Latn: Highlight last event entry
# hin_Deva: अंतिम कार्यक्रम प्रविष्टि को हाइलाइट करें
# eng_Latn: Start / stop event recording
# hin_Deva: घटना रिकॉर्डिंग शुरू/बंद करें
# eng_Latn: Clear event log
# hin_Deva: इवेंट लॉग साफ़ करें
# eng_Latn: Child count
# hin_Deva: बच्चों की गिनती
# eng_Latn: (no description)
# hin_Deva: (कोई विवरण नहीं)
# eng_Latn: Description
# hin_Deva: वर्णन
# eng_Latn: States
# hin_Deva: राज्यों
# eng_Latn: Show
# hin_Deva: दिखाएँ
# eng_Latn: Relations
# hin_Deva: संबंध
# eng_Latn: Attributes
# hin_Deva: विशेषताएँ
# eng_Latn: _ Accessible
# hin_Deva: सुलभ (_ A)
# eng_Latn: Perform action
# hin_Deva: क्रिया करें
# eng_Latn: Acti _ on
# hin_Deva: सक्रिय करें (_ o)
# eng_Latn: ID
# hin_Deva: आई. डी.
# eng_Latn: Toolkit
# hin_Deva: टूलकिट
# eng_Latn: Version
# hin_Deva: संस्करण
# eng_Latn: Ap _ plication
# hin_Deva: ए. पी. प्लिकेशन (_ p)
# eng_Latn: Col _ lection
# hin_Deva: कॉल लेक्शन (_ l)
# eng_Latn: 0, 0
# hin_Deva: 0, 0
# eng_Latn: Relative position
# hin_Deva: सापेक्षिक स्थिति
# eng_Latn: Size
# hin_Deva: आकार.
# eng_Latn: WIDGET
# hin_Deva: WIDGET
# eng_Latn: Layer
# hin_Deva: परत
# eng_Latn: MDI - Z - order
# hin_Deva: एम. डी. आई.-जेड.-क्रम
# eng_Latn: Alpha
# hin_Deva: अल्फा
# eng_Latn: Absolute position
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Co _ mponent
# hin_Deva: सह-घटक (_ m)
# eng_Latn: Des _ ktop
# hin_Deva: डेसकॉटॉप (_ k)
# eng_Latn: Locale:
# hin_Deva: स्थानः
# eng_Latn: _ Document
# hin_Deva: दस्तावेज़ (_ D)
# eng_Latn: Hyperlink
# hin_Deva: हाइपरलिंक
# eng_Latn: H _ ypertext
# hin_Deva: H _ yपरटेक्स्ट
# eng_Latn: Position
# hin_Deva: पोजीशन
# eng_Latn: Description
# hin_Deva: वर्णन
# eng_Latn: Locale
# hin_Deva: स्थानीय
# eng_Latn: _ Image
# hin_Deva: छवि (_ I)
# eng_Latn: Lo _ gin Helper
# hin_Deva: लो-जिन सहायक (_ g)
# eng_Latn: Select All
# hin_Deva: सभी चुनें
# eng_Latn: _ Selection
# hin_Deva: चयन (_ S)
# eng_Latn: St _ reamable Content
# hin_Deva: एस. टी. रीमेबल सामग्री (_ r)
# eng_Latn: Caption:
# hin_Deva: शीर्षकः
# eng_Latn: Summary:
# hin_Deva: सारांशः
# eng_Latn: Selected columns
# hin_Deva: चयनित स्तंभ
# eng_Latn: Selected rows
# hin_Deva: चुनी हुई पंक्तियाँ
# eng_Latn: Columns
# hin_Deva: कॉलम
# eng_Latn: Rows
# hin_Deva: पंक्तियाँ
# eng_Latn: Table Information
# hin_Deva: तालिका की जानकारी
# eng_Latn: name (x, y)
# hin_Deva: नाम (x, y)
# eng_Latn: Header:
# hin_Deva: शीर्षकः
# eng_Latn: Extents:
# hin_Deva: विस्तारः
# eng_Latn: Row
# hin_Deva: पंक्ति
# eng_Latn: Column
# hin_Deva: स्तम्भ
# eng_Latn: Selected Cell
# hin_Deva: चयनित कक्ष
# eng_Latn: _ Table
# hin_Deva: तालिका (_ T)
# eng_Latn: Text
# hin_Deva: पाठ
# eng_Latn: Offset
# hin_Deva: ऑफसेट
# eng_Latn: Include defaults
# hin_Deva: डिफ़ॉल्ट शामिल करें
# eng_Latn: Start: 0
# hin_Deva: प्रारम्भः 0
# eng_Latn: End: 0
# hin_Deva: अन्तः 0
# eng_Latn: Te _ xt
# hin_Deva: टी. ई. एक्स. टी.
# eng_Latn: Current value
# hin_Deva: वर्तमान मूल्य
# eng_Latn: Minimum increment
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Maximum value
# hin_Deva: अधिकतम मूल्य
# eng_Latn: Minimum value
# hin_Deva: न्यूनतम मूल्य
# eng_Latn: Val _ ue
# hin_Deva: वैल _ यूई
# eng_Latn: unknown
# hin_Deva: अज्ञात
# eng_Latn: Interface Viewer
# hin_Deva: इंटरफेस दर्शक
# eng_Latn: Allows viewing of various interface properties
# hin_Deva: विभिन्न इंटरफेस गुणों को देखने की अनुमति देता है
# eng_Latn: (not implemented)
# hin_Deva: (लागू नहीं किया गया)
# eng_Latn: Name
# hin_Deva: नाम
# eng_Latn: URI
# hin_Deva: यू. आर. आई.
# eng_Latn: Start
# hin_Deva: आरंभ करें।
# eng_Latn: End
# hin_Deva: अंत।
# eng_Latn: Too many selectable children
# hin_Deva: बहुत सारे चुनने योग्य बच्चे
# eng_Latn: (Editable)
# hin_Deva: (संपादन योग्य)
# eng_Latn: Quick Select
# hin_Deva: त्वरित चयन
# eng_Latn: Plugin with various methods of selecting accessibles quickly.
# hin_Deva: जल्दी से एक्सेसिबल चुनने के विभिन्न तरीकों के साथ प्लगइन करें।
# eng_Latn: Inspect last focused accessible
# hin_Deva: अंतिम ध्यान केंद्रित सुलभ का निरीक्षण करें
# eng_Latn: Inspect accessible under mouse
# hin_Deva: माउस के नीचे उपलब्ध निरीक्षण करें
# eng_Latn: Sche _ ma:
# hin_Deva: योजना _ माः
# eng_Latn: V _ alidate
# hin_Deva: वी अलाइडेट (_ a)
# eng_Latn: Idle
# hin_Deva: निष्क्रिय।
# eng_Latn: No description
# hin_Deva: कोई विवरण नहीं
# eng_Latn: AT - SPI Validator
# hin_Deva: ए. टी.-एस. पी. आई. वैलिडेटर
# eng_Latn: Validates application accessibility
# hin_Deva: अनुप्रयोग सुलभता को प्रमाणित करता है
# eng_Latn: Level
# hin_Deva: स्तर
# eng_Latn: Role
# hin_Deva: भूमिका
# eng_Latn: Saving
# hin_Deva: बचत करना।
# eng_Latn: Validating
# hin_Deva: मान्य कर रहे हैं।
# eng_Latn: EXCEPT
# hin_Deva: इसके अलावा
# eng_Latn: ERROR
# hin_Deva: त्रुटि
# eng_Latn: WARN
# hin_Deva: चेतावनी
# eng_Latn: INFO
# hin_Deva: जानकारी
# eng_Latn: DEBUG
# hin_Deva: डी. ई. बी. यू. जी.
# eng_Latn: Basic
# hin_Deva: बुनियादी
# eng_Latn: Tests fundamental GUI application accessibility
# hin_Deva: मौलिक जी. यू. आई. अनुप्रयोग अभिगम्यता का परीक्षण करता है
# eng_Latn: actionable% s is not focusable or selectable
# hin_Deva: कार्रवाई योग्य% s ध्यान केंद्रित करने योग्य या चयन योग्य नहीं है
# eng_Latn: interactive% s is not actionable
# hin_Deva: अंतःक्रियात्मक% s कार्रवाई योग्य नहीं है
# eng_Latn: more than one focused widget
# hin_Deva: एक से अधिक केंद्रित विजेट
# eng_Latn: % s has no text interface
# hin_Deva: % s का कोई पाठ इंटरफेस नहीं है
# eng_Latn: % s index in parent does not match child index
# hin_Deva: माता-पिता में% s सूचकांक बाल सूचकांक से मेल नहीं खाता है
# eng_Latn: Missing reciprocal for% s relation
# hin_Deva: % s संबंध के लिए पारस्परिक गायब है
# eng_Latn: % s missing name or label
# hin_Deva: % s नाम या लेबल गायब है
# eng_Latn: focusable% s has a table interface, but not a selection interface
# hin_Deva: ध्यान केंद्रित करने योग्य% s में एक टेबल इंटरफेस है, लेकिन एक चयन इंटरफेस नहीं है
# eng_Latn: % s has% s state without% s state
# hin_Deva: % s में% s अवस्था बिना% s अवस्था के है
# eng_Latn: % s does not belong to a set
# hin_Deva: % s किसी समूह से संबंधित नहीं है
# eng_Latn: % (rolename) s index% (num) d does not match row and column
# hin_Deva: % (रोलनाम) s सूचकांक% (num) d पंक्ति और स्तंभ से मेल नहीं खाता है
# eng_Latn: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# hin_Deva: % (रोलनाम) का मूल सूचकांक% (num1) d पंक्ति और स्तंभ सूचकांक% (num2) d से मेल नहीं खाता है
# eng_Latn: % s has no name or description
# hin_Deva: % s का कोई नाम या विवरण नहीं है
# eng_Latn: _ Preferences...
# hin_Deva: वरीयताएँ... (_ P)
# eng_Latn: _ Contents
# hin_Deva: सामग्री (_ C)
# eng_Latn: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# hin_Deva: एक्सर्साइज़र आपके डेस्कटॉप पर अनुप्रयोगों को नहीं देख सका। आपको इस समस्या को ठीक करने के लिए डेस्कटॉप पहुँच को सक्षम करना होगा। क्या आप इसे अभी सक्षम करना चाहते हैं?
# eng_Latn: Note: Changes only take effect after logout.
# hin_Deva: नोटः परिवर्तन लॉगआउट के बाद ही प्रभावी होते हैं।
# eng_Latn: < dead >
# hin_Deva: <मृत>
# eng_Latn: Children
# hin_Deva: बच्चे।
# eng_Latn: _ Hide / Show Applications without children
# hin_Deva: बच्चों के बिना अनुप्रयोग छुपाएँ/दिखाएँ (_ H)
# eng_Latn: _ Refresh Registry
# hin_Deva: रजिस्ट्री ताज़ा करें (_ R)
# eng_Latn: Refresh all
# hin_Deva: सब ताज़ा करें
# eng_Latn: Refresh _ Node
# hin_Deva: नोड ताज़ा करें (_ N)
# eng_Latn: Refresh selected node 's children
# hin_Deva: चयनित नोड के बच्चों को ताज़ा करें
# eng_Latn: Component
# hin_Deva: घटक
# eng_Latn: Task
# hin_Deva: कार्य
# eng_Latn: Key
# hin_Deva: कुंजी
# eng_Latn: Alt
# hin_Deva: ऑल्ट
# eng_Latn: Ctrl
# hin_Deva: सी. टी. आर. एल.
# eng_Latn: Shift
# hin_Deva: स्थानांतरण
# eng_Latn: Top panel
# hin_Deva: शीर्ष पैनल
# eng_Latn: Bottom panel
# hin_Deva: निचला पैनल
# eng_Latn: accerciser Preferences
# hin_Deva: ऐक्सरसाइज़र वरीयताएँ
# eng_Latn: Plugins
# hin_Deva: प्लगइन
# eng_Latn: Global Hotkeys
# hin_Deva: वैश्विक हॉटकी
# eng_Latn: Highlighting
# hin_Deva: हाइलाइटिंग
# eng_Latn: Highlight duration:
# hin_Deva: समयावधि पर प्रकाश डालेंः
# eng_Latn: Border color:
# hin_Deva: किनारों का रंगः
# eng_Latn: The border color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का सीमा रंग
# eng_Latn: Fill color:
# hin_Deva: रंग भरेंः
# eng_Latn: The fill color of the highlight box
# hin_Deva: हाइलाइट बॉक्स का रंग भरें
# eng_Latn: translator - credits
# hin_Deva: अनुवादक-श्रेय
# eng_Latn: An interactive Python accessibility explorer
# hin_Deva: एक इंटरैक्टिव पायथन एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: accerciser Copyright (c) 2006, 2007 IBM Corporation (BSD)
# hin_Deva: ऐक्सरसाइजर कॉपीराइट (सी) 2006,2007 आईबीएम कॉर्पोरेशन (बीएसडी)
# eng_Latn: The New BSD License See the COPYING and NOTICE files for details.
# hin_Deva: नया बीएसडी लाइसेंस विवरण के लिए प्रतिलिपि और सूचना फ़ाइलों को देखें।
# eng_Latn: Web site
# hin_Deva: वेबसाइट
# eng_Latn: _ Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें... (_ A)
# eng_Latn: Bookmark selected accessible.
# hin_Deva: बुकमार्क को उपलब्ध चुना गया है।
# eng_Latn: _ Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें... (_ E)
# eng_Latn: Manage bookmarks.
# hin_Deva: बुकमार्क प्रबंधित करें।
# eng_Latn: Edit Bookmarks...
# hin_Deva: बुकमार्क संपादित करें...
# eng_Latn: Title
# hin_Deva: शीर्षक
# eng_Latn: Application
# hin_Deva: आवेदन
# eng_Latn: Path
# hin_Deva: रास्ता
# eng_Latn: Add Bookmark...
# hin_Deva: बुकमार्क जोड़ें...
# eng_Latn: Title:
# hin_Deva: शीर्षकः
# eng_Latn: Application:
# hin_Deva: आवेदनः
# eng_Latn: Path:
# hin_Deva: मार्गः
# eng_Latn: Plugin Errors
# hin_Deva: प्लगइन त्रुटियाँ
# eng_Latn: View
# hin_Deva: देखें
# eng_Latn: No view
# hin_Deva: कोई दृश्य नहीं
# eng_Latn: _ Single plugins view
# hin_Deva: एकल प्लगइन दृश्य (_ A)
# eng_Latn: Plugin View
# hin_Deva: प्लगइन दृश्य
# eng_Latn: Plugin View (% d)
# hin_Deva: प्लगइन दृश्य (% d)
# eng_Latn: _ New view...
# hin_Deva: नया दृश्य... (_ N)
# eng_Latn: New View...
# hin_Deva: नया दृश्य...
# eng_Latn: _ File
# hin_Deva: फाइल (_ F)
# eng_Latn: _ Edit
# hin_Deva: संपादित करें (_ E)
# eng_Latn: _ Bookmarks
# hin_Deva: बुकमार्क (_ B)
# eng_Latn: _ View
# hin_Deva: देखें (_ V)
# eng_Latn: _ Help
# hin_Deva: मदद करें (_ M)
# eng_Latn: Accerciser
# hin_Deva: एक्सर्साइज़र
# eng_Latn: Give your application an accessibility workout
# hin_Deva: अपने अनुप्रयोग को एक सुलभता अभ्यास दें
# eng_Latn: Accerciser Accessibility Explorer
# hin_Deva: एक्सर्साइज़र एक्सेसिबिलिटी एक्सप्लोरर
# eng_Latn: A list of plugins that are disabled by default
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
# eng_Latn: A list of plugins that are disabled by default.
# hin_Deva: प्लगइनों की एक सूची जो डिफ़ॉल्ट रूप से अक्षम हैं।

# %%
import numpy as np
import tensorflow as tf
import csv
import nltk
import torch
import time
from nltk.translate.bleu_score import corpus_bleu
from sentence_transformers import SentenceTransformer, util
from sacrebleu.metrics import CHRF
from nltk.translate.meteor_score import meteor_score
from nltk.lm import KneserNeyInterpolated
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.util import ngrams

# %%
#BLEU Score
references = [[hindi] for hindi in hindi_sentences]  # Create reference list of lists
candidates = translation_hindi  # Model translations
bleu_score = corpus_bleu(references, candidates)
print(f"BLEU score: {bleu_score:.4f}")
# Out:
# BLEU score: 0.4971

# %%
# STS Score
# Load the pre-trained model
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
model = model.to('cuda' if torch.cuda.is_available() else 'cpu')

# Encode the original Hindi sentences and the translated sentences
embeddings1 = model.encode(hindi_sentences, convert_to_tensor=True, device=model.device)
embeddings2 = model.encode(translation_hindi, convert_to_tensor=True, device=model.device)

# Compute cosine similarities between the embeddings
cosine_scores = util.cos_sim(embeddings1, embeddings2)

# Calculate the average STS score
sts_score = cosine_scores.diag().mean().item()
print(f"STS score: {sts_score:.4f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# STS score: 0.7781

# %%
# CHRF
# Initialize CHRF metric
chrf = CHRF(word_order=1)

# Calculate CHRF score
chrf_score = chrf.corpus_score(translation_hindi, [[hindi] for hindi in hindi_sentences]).score
print(f"CHRF score: {chrf_score:.4f}")
# Out:
# CHRF score: 56.6218

# %%
# METEOR Score
# Download required NLTK data (if not already downloaded)
nltk.download('punkt')  # Download the 'punkt' resource for sentence tokenization
nltk.download('wordnet')

# Tokenize the sentences if they're not already tokenized
hindi_sentences_tokenized = [nltk.word_tokenize(sent) for sent in hindi_sentences]
translatedHinEng_tokenized = [nltk.word_tokenize(sent) for sent in translation_hindi]

# Calculate METEOR score
from nltk.translate.meteor_score import meteor_score # Import the meteor_score function
meteor_scores = [meteor_score([ref], hyp) for ref, hyp in zip(hindi_sentences_tokenized, translatedHinEng_tokenized)]
average_meteor_score = sum(meteor_scores) / len(meteor_scores)

print(f"METEOR score: {average_meteor_score:.4f}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# METEOR score: 0.3181

# %% [markdown]
# Hindi to English

# %%
indic_en_ckpt_dir = "ai4bharat/indictrans2-indic-en-1B"  # ai4bharat/indictrans2-indic-en-dist-200M
indic_en_tokenizer, indic_en_model = initialize_model_and_tokenizer(indic_en_ckpt_dir, quantization)

ip = IndicProcessor(inference=True)

hi_sents = hindi_sentences
translation_eng=[]
src_lang, tgt_lang = "hin_Deva", "eng_Latn"
en_translations = batch_translate(hi_sents, src_lang, tgt_lang, indic_en_model, indic_en_tokenizer, ip)


print(f"\n{src_lang} - {tgt_lang}")
for input_sentence, translation in zip(hi_sents, en_translations):
    print(f"{src_lang}: {input_sentence}")
    print(f"{tgt_lang}: {translation}")
    translation_eng.append(translation)

# flush the models to free the GPU memory
del indic_en_tokenizer, indic_en_model
# Out:
# hin_Deva - eng_Latn
# hin_Deva: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# eng_Latn: Give your application the benefit of the accessibility exercise.
# hin_Deva: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# eng_Latn: Accessor accessibility tracker
# hin_Deva: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# eng_Latn: Default plugin layout for the lower panel
# hin_Deva: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# eng_Latn: Default plugin layout for the top panel
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default
# hin_Deva: अवधि को हाइलाइट रकें
# eng_Latn: Highlight the duration
# hin_Deva: पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# eng_Latn: The duration of the highlight box when selecting a reachable node
# hin_Deva: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the border (boarder)
# hin_Deva: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# eng_Latn: Color and opacity of highlighted marginalia.
# hin_Deva: भराई के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the filling
# hin_Deva: हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# eng_Latn: Highlighted fill color and transparency.
# hin_Deva: एपीआई विचरक
# eng_Latn: API Variator
# hin_Deva: इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# eng_Latn: Distribute what has been received at this time into different methods.
# hin_Deva: निजी गुणों को छिपाएं
# eng_Latn: Hide Personal Attributes
# hin_Deva: विधि
# eng_Latn: method
# hin_Deva: गुणधर्म
# eng_Latn: Properties
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: आईपाइथन कन्सोल
# eng_Latn: iPython Console
# hin_Deva: इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# eng_Latn: Interactive console to work with the currently selected Accessible
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: घटनाओं को मानिटर करें (_ M)
# eng_Latn: _ Monitor Events
# hin_Deva: चुनाव को हटाएं (C _)
# eng_Latn: Delete Selection (C _)
# hin_Deva: सभी
# eng_Latn: All
# hin_Deva: चुने गए अनुप्रयोग
# eng_Latn: Selected Applications
# hin_Deva: चुने गए एक्सेसेबेल
# eng_Latn: Selected Accessables
# hin_Deva: स्रोत
# eng_Latn: Source
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# eng_Latn: Shows events as they occur, from selected types and sources.
# hin_Deva: अंतिम प्रविष्ट घटना को हाइलाइट करो
# eng_Latn: Highlight the last entered event
# hin_Deva: घटना रेकोर्डिंग शुरू करो/रोको
# eng_Latn: Start / Stop event recording
# hin_Deva: घटना रोजनामचा मिटाओ
# eng_Latn: delete event routine
# hin_Deva: कोई विवरण नहीं
# eng_Latn: No details
# hin_Deva: वर्णन
# eng_Latn: Description
# hin_Deva: दिखाएं
# eng_Latn: Show
# hin_Deva: पहुंचनीय
# eng_Latn: accessible
# hin_Deva: कार्रवाई संपन्न करें
# eng_Latn: Complete the action
# hin_Deva: कार्रवाई (_ o)
# eng_Latn: _ action
# hin_Deva: आईडी
# eng_Latn: ID
# hin_Deva: औजार बक्सा
# eng_Latn: Toolbox
# hin_Deva: संस्करण
# eng_Latn: Version
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: संग्रह
# eng_Latn: collection
# hin_Deva: 0, 0
# eng_Latn: 0, 0
# hin_Deva: सापेक्ष स्थिति
# eng_Latn: Relative position
# hin_Deva: आकार
# eng_Latn: Size
# hin_Deva: विडजेट
# eng_Latn: Widget
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: एमडीआई-जेड-क्रम
# eng_Latn: MDI-Z-order
# hin_Deva: अल्फा
# eng_Latn: Alpha
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Absolute position
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: डेस्कटोप
# eng_Latn: Desktop
# hin_Deva: स्थान-विशिष्टः
# eng_Latn: Location-specific:
# hin_Deva: प्रलेख
# eng_Latn: document
# hin_Deva: हाइपरकड़ी
# eng_Latn: Hypercord
# hin_Deva: हाइपरपाठ
# eng_Latn: Hypertext
# hin_Deva: स्थिति
# eng_Latn: Situation
# hin_Deva: वर्णन
# eng_Latn: Description
# hin_Deva: स्थान-विशिष्ट
# eng_Latn: Location-specific
# hin_Deva: छवि (_ I)
# eng_Latn: _ Image
# hin_Deva: प्रवेश सहायक
# eng_Latn: Entry Assistant
# hin_Deva: सभी चुनें
# eng_Latn: Select All
# hin_Deva: चयन (_ S)
# eng_Latn: _ Selection
# hin_Deva: प्रवाहित करनेयोग्य विषयवस्तु
# eng_Latn: Flowable content
# hin_Deva: चुने गए स्तंभ
# eng_Latn: Selected columns
# hin_Deva: चुनी गई पंक्तियां
# eng_Latn: Selected Lines
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: पंक्तियां
# eng_Latn: Lines
# hin_Deva: & lt; bgt; सारणी सूचनाlt;/bgt;
# eng_Latn: & lt; bgt; table information lt; / bgt;
# hin_Deva: नाम (x, y)
# eng_Latn: Name (x, y)
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: विस्तारः
# eng_Latn: Expansion:
# hin_Deva: पंक्ति
# eng_Latn: Row
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# eng_Latn: & lt; bgt; selected cell lt; / bgt;
# hin_Deva: सारणी (_ T)
# eng_Latn: _ Table
# hin_Deva: ओफसेट
# eng_Latn: Offset
# hin_Deva: डिफोल्टों को शामिल करें
# eng_Latn: Include defaults
# hin_Deva: पाठ (_ x)
# eng_Latn: Text _ x
# hin_Deva: मौजूदा मान
# eng_Latn: Current value
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Minimum increment
# hin_Deva: अधिकतम मान
# eng_Latn: Maximum value
# hin_Deva: न्यूनतम मान
# eng_Latn: Minimum value
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: अंतराफलक दर्शक
# eng_Latn: Interface Viewer
# hin_Deva: अंतराफलक के विभिन्न गुणों को देखने देता है
# eng_Latn: Allows viewing of various properties of the interface.
# hin_Deva: (क्रियान्वित नहीं हुआ है)
# eng_Latn: (Not implemented)
# hin_Deva: नाम
# eng_Latn: Name
# hin_Deva: यूआरआई
# eng_Latn: URI
# hin_Deva: प्रारंभ
# eng_Latn: Start
# hin_Deva: अंत
# eng_Latn: The end
# hin_Deva: बहुत अधिक चयनीय शिशु हैं
# eng_Latn: There are a lot of very selective babies
# hin_Deva: तेज चुनाव
# eng_Latn: Quick pick
# hin_Deva: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# eng_Latn: Plug-ins that have multiple methods for faster selection of accessibles
# hin_Deva: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# eng_Latn: Check Last Focused Accessible
# hin_Deva: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# eng_Latn: Check what is accessible under the mouse
# hin_Deva: वतनी
# eng_Latn: native
# hin_Deva: श्वानपुच्छ
# eng_Latn: dog poop
# hin_Deva: एलडीटीपी
# eng_Latn: LDTP
# hin_Deva: लिपि प्रकार
# eng_Latn: Script Type
# hin_Deva: लिपि रेकोर्डर
# eng_Latn: Script Recorder
# hin_Deva: श्वानपुच्छ शैली की लिपियां निर्मित करता है
# eng_Latn: Creates canine-style scripts.
# hin_Deva: वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
# eng_Latn: The current script will be lost.
# hin_Deva: मिटाने की पुष्टि करें
# eng_Latn: Confirm deletion
# hin_Deva: स्कीमाः
# eng_Latn: Scheme:
# hin_Deva: सत्यापन
# eng_Latn: Authentication
# hin_Deva: खाली
# eng_Latn: empty
# hin_Deva: कोई विवरण नहीं
# eng_Latn: No details
# hin_Deva: एटी-एसपीआई सत्यापक
# eng_Latn: AT-SPI Verifier
# hin_Deva: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# eng_Latn: Verifies the accessibility of the application
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: भूमिका
# eng_Latn: Role
# hin_Deva: सहेज रहे हैं
# eng_Latn: Saving
# hin_Deva: पुष्टि कर रहे हैं
# eng_Latn: Confirming
# hin_Deva: अपवाद
# eng_Latn: Exception
# hin_Deva: त्रुटि
# eng_Latn: Error
# hin_Deva: चेतावनी
# eng_Latn: Warning
# hin_Deva: सूचना
# eng_Latn: Information
# hin_Deva: दोषमुक्त करें
# eng_Latn: absolve
# hin_Deva: मूल
# eng_Latn: Original
# hin_Deva: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# eng_Latn: Tests basic GUI application accessibility
# hin_Deva: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# eng_Latn: % s that can be processed is neither focusable nor selectable
# hin_Deva: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# eng_Latn: Interactive% s is not actionable
# hin_Deva: एक से अधिक विडजेट फोकस में है
# eng_Latn: More than one widget is in focus.
# hin_Deva: % s का कोई पाठ अंतराफलक नहीं है
# eng_Latn: % s has no text interface
# hin_Deva: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# eng_Latn: The list% s in the parent does not match the child list
# hin_Deva: % s संबंध के लिए अन्योन्य गायब है
# eng_Latn: % s missing reciprocal for relation
# hin_Deva: % s गायब नाम या सूचक
# eng_Latn: % s Missing name or pointer
# hin_Deva: फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# eng_Latn: Focusable% s has a table interface, no selectable interface, button has focused state without focusable state
# hin_Deva: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# eng_Latn: % s has state% s, but does not have state% s with it
# hin_Deva: % s किसी समुच्चय का सदस्य नहीं है
# eng_Latn: % s is not a member of any set
# hin_Deva: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# eng_Latn: % (rollename) s list does not match% (num) d row and column index
# hin_Deva: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# eng_Latn: % (rollename) s does not match parent list% (num1) d row and column list% (num2) d
# hin_Deva: % s का कोई नाम या विवरण नहीं
# eng_Latn: % s has no name or description
# hin_Deva: पसंद (_ P)...
# eng_Latn: _ Preferences...
# hin_Deva: विषय सूची (_ C)
# eng_Latn: _ Subject List
# hin_Deva: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# eng_Latn: Exerciser could not see the application on your desktop. To fix this problem, you need to enable desktop accessibility. Do you want to enable it?
# hin_Deva: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# eng_Latn: Note: Changes will only take effect after the end of the session (logout).
# hin_Deva: शिशु
# eng_Latn: baby
# hin_Deva: पंजी ताजा करें (_ R)
# eng_Latn: _ Refresh Register
# hin_Deva: सभी को ताजा करें
# eng_Latn: refresh all
# hin_Deva: आसंधि (नोड) को ताजा करें (_ N)
# eng_Latn: _ Refresh Node
# hin_Deva: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# eng_Latn: Refresh the babies of the selected nodes.
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: कार्य
# eng_Latn: work
# hin_Deva: कुंजी
# eng_Latn: Key
# hin_Deva: आल्ट
# eng_Latn: Alt
# hin_Deva: कंट्रोल
# eng_Latn: Control
# hin_Deva: शिफ्ट
# eng_Latn: Shift
# hin_Deva: ऊपरी पटल
# eng_Latn: Upper panel
# hin_Deva: निचला पटल
# eng_Latn: Lower panel
# hin_Deva: एक्सेर्साइसर पसंद
# eng_Latn: Accessor Preferences
# hin_Deva: प्लगइन्स
# eng_Latn: Plugins
# hin_Deva: सार्वत्रिक फटाफट कुंजियां
# eng_Latn: Universal Quick Keys
# hin_Deva: हाइलाइटन
# eng_Latn: Highlight
# hin_Deva: हाइलाइट अवधिः
# eng_Latn: Highlight period:
# hin_Deva: सीमांत रंगः
# eng_Latn: Marginal color:
# hin_Deva: हाइलाइट बक्से का सीमांत रंग
# eng_Latn: Marginal color of highlight boxes
# hin_Deva: भराई का रंगः
# eng_Latn: Color of the filling:
# hin_Deva: हाइलाइट बक्से का भराई रंग
# eng_Latn: Fill color of highlight boxes
# hin_Deva: रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# eng_Latn: Ravishankar Srivastava (raviratlami @yahoo.com) Rajesh Ranjan (rajeshkajha @yahoo.com) L. Balasubramaniam (l.balasubramaniam @gmail.com)
# hin_Deva: एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# eng_Latn: An interactive Python accessibility tracker
# hin_Deva: एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
# eng_Latn: Accessor Copyright 2006, 2007 IBM Corporation (BSD)
# hin_Deva: नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# eng_Latn: For new BSD license details, see Copyright and Information Files.
# hin_Deva: जाल स्थल
# eng_Latn: Web site
# hin_Deva: पसंद जोड़ें... (_ A)
# eng_Latn: _ Add Preferences...
# hin_Deva: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# eng_Latn: Bookmark the selected accessibles
# hin_Deva: पुस्तक चिह्न संपादित करें (_ E)...
# eng_Latn: Edit _ Bookmark...
# hin_Deva: पुस्तक-चिह्नों को प्रबंधित करें।
# eng_Latn: Manage bookmarks.
# hin_Deva: पुस्तक चिह्नों को संपादित करें...
# eng_Latn: Edit Bookmarks...
# hin_Deva: शीर्षक
# eng_Latn: Title
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: पथ
# eng_Latn: Path
# hin_Deva: पुस्तक-चिह्न जोड़ें...
# eng_Latn: Add Bookmark...
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: अनुप्रयोगः
# eng_Latn: Application:
# hin_Deva: पथः
# eng_Latn: Path:
# hin_Deva: प्लग-इन त्रुटियां
# eng_Latn: Plug-in errors
# hin_Deva: दृश्य
# eng_Latn: view
# hin_Deva: कोई दृश्य नहीं है
# eng_Latn: There is no view
# hin_Deva: एकल प्लग-इन दृश्य
# eng_Latn: Single plug-in view
# hin_Deva: प्लग-इन दृश्य
# eng_Latn: Plug-in view
# hin_Deva: प्लग-इन दृश्य (% d)
# eng_Latn: Plugin view (% d)
# hin_Deva: नया दृश्य...
# eng_Latn: New View...
# hin_Deva: नया दृश्य...
# eng_Latn: New View...
# hin_Deva: फाइल (F)
# eng_Latn: File (F)
# hin_Deva: संपादित करें
# eng_Latn: Edit
# hin_Deva: पुस्तक-चिह्न संपादित करें (_ E)...
# eng_Latn: _ Edit Bookmark...
# hin_Deva: दृश्य _ (V)
# eng_Latn: View _ (V)
# hin_Deva: मदद
# eng_Latn: Help
# hin_Deva: पूरा नाम
# eng_Latn: Full name
# hin_Deva: कुंजी बंधन
# eng_Latn: Key binding
# hin_Deva: विषय प्रकार
# eng_Latn: Subject Type
# hin_Deva: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# eng_Latn: Give your application the benefit of the accessibility exercise.
# hin_Deva: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# eng_Latn: Accessor accessibility tracker
# hin_Deva: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# eng_Latn: Default plugin layout for the lower panel
# hin_Deva: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# eng_Latn: Default plugin layout for the top panel
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default
# hin_Deva: अवधि को हाइलाइट रकें
# eng_Latn: Highlight the duration
# hin_Deva: पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# eng_Latn: The duration of the highlight box when selecting a reachable node
# hin_Deva: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the border (boarder)
# hin_Deva: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# eng_Latn: Color and opacity of highlighted marginalia.
# hin_Deva: भराई के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the filling
# hin_Deva: हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# eng_Latn: Highlighted fill color and transparency.
# hin_Deva: एपीआई विचरक
# eng_Latn: API Variator
# hin_Deva: इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# eng_Latn: Distribute what has been received at this time into different methods.
# hin_Deva: निजी गुणों को छिपाएं
# eng_Latn: Hide Personal Attributes
# hin_Deva: विधि
# eng_Latn: method
# hin_Deva: गुणधर्म
# eng_Latn: Properties
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: आईपाइथन कन्सोल
# eng_Latn: iPython Console
# hin_Deva: इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# eng_Latn: Interactive console to work with the currently selected Accessible
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: घटनाओं को मानिटर करें (_ M)
# eng_Latn: _ Monitor Events
# hin_Deva: चुनाव को हटाएं (C _)
# eng_Latn: Delete Selection (C _)
# hin_Deva: सभी
# eng_Latn: All
# hin_Deva: चुने गए अनुप्रयोग
# eng_Latn: Selected Applications
# hin_Deva: चुने गए एक्सेसेबेल
# eng_Latn: Selected Accessables
# hin_Deva: स्रोत
# eng_Latn: Source
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# eng_Latn: Shows events as they occur, from selected types and sources.
# hin_Deva: अंतिम प्रविष्ट घटना को हाइलाइट करो
# eng_Latn: Highlight the last entered event
# hin_Deva: घटना रेकोर्डिंग शुरू करो/रोको
# eng_Latn: Start / Stop event recording
# hin_Deva: घटना रोजनामचा मिटाओ
# eng_Latn: delete event routine
# hin_Deva: कोई विवरण नहीं
# eng_Latn: No details
# hin_Deva: वर्णन
# eng_Latn: Description
# hin_Deva: दिखाएं
# eng_Latn: Show
# hin_Deva: पहुंचनीय
# eng_Latn: accessible
# hin_Deva: कार्रवाई संपन्न करें
# eng_Latn: Complete the action
# hin_Deva: कार्रवाई (_ o)
# eng_Latn: _ action
# hin_Deva: आईडी
# eng_Latn: ID
# hin_Deva: औजार बक्सा
# eng_Latn: Toolbox
# hin_Deva: संस्करण
# eng_Latn: Version
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: संग्रह
# eng_Latn: collection
# hin_Deva: 0, 0
# eng_Latn: 0, 0
# hin_Deva: सापेक्ष स्थिति
# eng_Latn: Relative position
# hin_Deva: आकार
# eng_Latn: Size
# hin_Deva: विडजेट
# eng_Latn: Widget
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: एमडीआई-जेड-क्रम
# eng_Latn: MDI-Z-order
# hin_Deva: अल्फा
# eng_Latn: Alpha
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Absolute position
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: डेस्कटोप
# eng_Latn: Desktop
# hin_Deva: स्थान-विशिष्टः
# eng_Latn: Location-specific:
# hin_Deva: प्रलेख
# eng_Latn: document
# hin_Deva: हाइपरकड़ी
# eng_Latn: Hypercord
# hin_Deva: हाइपरपाठ
# eng_Latn: Hypertext
# hin_Deva: स्थिति
# eng_Latn: Situation
# hin_Deva: वर्णन
# eng_Latn: Description
# hin_Deva: स्थान-विशिष्ट
# eng_Latn: Location-specific
# hin_Deva: छवि (_ I)
# eng_Latn: _ Image
# hin_Deva: प्रवेश सहायक
# eng_Latn: Entry Assistant
# hin_Deva: सभी चुनें
# eng_Latn: Select All
# hin_Deva: चयन (_ S)
# eng_Latn: _ Selection
# hin_Deva: प्रवाहित करनेयोग्य विषयवस्तु
# eng_Latn: Flowable content
# hin_Deva: चुने गए स्तंभ
# eng_Latn: Selected columns
# hin_Deva: चुनी गई पंक्तियां
# eng_Latn: Selected Lines
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: पंक्तियां
# eng_Latn: Lines
# hin_Deva: & lt; bgt; सारणी सूचनाlt;/bgt;
# eng_Latn: & lt; bgt; table information lt; / bgt;
# hin_Deva: नाम (x, y)
# eng_Latn: Name (x, y)
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: विस्तारः
# eng_Latn: Expansion:
# hin_Deva: पंक्ति
# eng_Latn: Row
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# eng_Latn: & lt; bgt; selected cell lt; / bgt;
# hin_Deva: सारणी (_ T)
# eng_Latn: _ Table
# hin_Deva: ओफसेट
# eng_Latn: Offset
# hin_Deva: डिफोल्टों को शामिल करें
# eng_Latn: Include defaults
# hin_Deva: पाठ (_ x)
# eng_Latn: Text _ x
# hin_Deva: मौजूदा मान
# eng_Latn: Current value
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Minimum increment
# hin_Deva: अधिकतम मान
# eng_Latn: Maximum value
# hin_Deva: न्यूनतम मान
# eng_Latn: Minimum value
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: अंतराफलक दर्शक
# eng_Latn: Interface Viewer
# hin_Deva: अंतराफलक के विभिन्न गुणों को देखने देता है
# eng_Latn: Allows viewing of various properties of the interface.
# hin_Deva: (क्रियान्वित नहीं हुआ है)
# eng_Latn: (Not implemented)
# hin_Deva: नाम
# eng_Latn: Name
# hin_Deva: यूआरआई
# eng_Latn: URI
# hin_Deva: प्रारंभ
# eng_Latn: Start
# hin_Deva: अंत
# eng_Latn: The end
# hin_Deva: बहुत अधिक चयनीय शिशु हैं
# eng_Latn: There are a lot of very selective babies
# hin_Deva: तेज चुनाव
# eng_Latn: Quick pick
# hin_Deva: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# eng_Latn: Plug-ins that have multiple methods for faster selection of accessibles
# hin_Deva: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# eng_Latn: Check Last Focused Accessible
# hin_Deva: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# eng_Latn: Check what is accessible under the mouse
# hin_Deva: वतनी
# eng_Latn: native
# hin_Deva: श्वानपुच्छ
# eng_Latn: dog poop
# hin_Deva: एलडीटीपी
# eng_Latn: LDTP
# hin_Deva: लिपि प्रकार
# eng_Latn: Script Type
# hin_Deva: लिपि रेकोर्डर
# eng_Latn: Script Recorder
# hin_Deva: श्वानपुच्छ शैली की लिपियां निर्मित करता है
# eng_Latn: Creates canine-style scripts.
# hin_Deva: वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
# eng_Latn: The current script will be lost.
# hin_Deva: मिटाने की पुष्टि करें
# eng_Latn: Confirm deletion
# hin_Deva: स्कीमाः
# eng_Latn: Scheme:
# hin_Deva: सत्यापन
# eng_Latn: Authentication
# hin_Deva: खाली
# eng_Latn: empty
# hin_Deva: कोई विवरण नहीं
# eng_Latn: No details
# hin_Deva: एटी-एसपीआई सत्यापक
# eng_Latn: AT-SPI Verifier
# hin_Deva: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# eng_Latn: Verifies the accessibility of the application
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: भूमिका
# eng_Latn: Role
# hin_Deva: सहेज रहे हैं
# eng_Latn: Saving
# hin_Deva: पुष्टि कर रहे हैं
# eng_Latn: Confirming
# hin_Deva: अपवाद
# eng_Latn: Exception
# hin_Deva: त्रुटि
# eng_Latn: Error
# hin_Deva: चेतावनी
# eng_Latn: Warning
# hin_Deva: सूचना
# eng_Latn: Information
# hin_Deva: दोषमुक्त करें
# eng_Latn: absolve
# hin_Deva: मूल
# eng_Latn: Original
# hin_Deva: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# eng_Latn: Tests basic GUI application accessibility
# hin_Deva: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# eng_Latn: % s that can be processed is neither focusable nor selectable
# hin_Deva: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# eng_Latn: Interactive% s is not actionable
# hin_Deva: एक से अधिक विडजेट फोकस में है
# eng_Latn: More than one widget is in focus.
# hin_Deva: % s का कोई पाठ अंतराफलक नहीं है
# eng_Latn: % s has no text interface
# hin_Deva: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# eng_Latn: The list% s in the parent does not match the child list
# hin_Deva: % s संबंध के लिए अन्योन्य गायब है
# eng_Latn: % s missing reciprocal for relation
# hin_Deva: % s गायब नाम या सूचक
# eng_Latn: % s Missing name or pointer
# hin_Deva: फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# eng_Latn: Focusable% s has a table interface, no selectable interface, button has focused state without focusable state
# hin_Deva: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# eng_Latn: % s has state% s, but does not have state% s with it
# hin_Deva: % s किसी समुच्चय का सदस्य नहीं है
# eng_Latn: % s is not a member of any set
# hin_Deva: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# eng_Latn: % (rollename) s list does not match% (num) d row and column index
# hin_Deva: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# eng_Latn: % (rollename) s does not match parent list% (num1) d row and column list% (num2) d
# hin_Deva: % s का कोई नाम या विवरण नहीं
# eng_Latn: % s has no name or description
# hin_Deva: पसंद (_ P)...
# eng_Latn: _ Preferences...
# hin_Deva: विषय सूची (_ C)
# eng_Latn: _ Subject List
# hin_Deva: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# eng_Latn: Exerciser could not see the application on your desktop. To fix this problem, you need to enable desktop accessibility. Do you want to enable it?
# hin_Deva: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# eng_Latn: Note: Changes will only take effect after the end of the session (logout).
# hin_Deva: शिशु
# eng_Latn: baby
# hin_Deva: पंजी ताजा करें (_ R)
# eng_Latn: _ Refresh Register
# hin_Deva: सभी को ताजा करें
# eng_Latn: refresh all
# hin_Deva: आसंधि (नोड) को ताजा करें (_ N)
# eng_Latn: _ Refresh Node
# hin_Deva: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# eng_Latn: Refresh the babies of the selected nodes.
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: कार्य
# eng_Latn: work
# hin_Deva: कुंजी
# eng_Latn: Key
# hin_Deva: आल्ट
# eng_Latn: Alt
# hin_Deva: कंट्रोल
# eng_Latn: Control
# hin_Deva: शिफ्ट
# eng_Latn: Shift
# hin_Deva: ऊपरी पटल
# eng_Latn: Upper panel
# hin_Deva: निचला पटल
# eng_Latn: Lower panel
# hin_Deva: एक्सेर्साइसर पसंद
# eng_Latn: Accessor Preferences
# hin_Deva: प्लगइन्स
# eng_Latn: Plugins
# hin_Deva: सार्वत्रिक फटाफट कुंजियां
# eng_Latn: Universal Quick Keys
# hin_Deva: हाइलाइटन
# eng_Latn: Highlight
# hin_Deva: हाइलाइट अवधिः
# eng_Latn: Highlight period:
# hin_Deva: सीमांत रंगः
# eng_Latn: Marginal color:
# hin_Deva: हाइलाइट बक्से का सीमांत रंग
# eng_Latn: Marginal color of highlight boxes
# hin_Deva: भराई का रंगः
# eng_Latn: Color of the filling:
# hin_Deva: हाइलाइट बक्से का भराई रंग
# eng_Latn: Fill color of highlight boxes
# hin_Deva: रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# eng_Latn: Ravishankar Srivastava (raviratlami @yahoo.com) Rajesh Ranjan (rajeshkajha @yahoo.com) L. Balasubramaniam (l.balasubramaniam @gmail.com)
# hin_Deva: एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# eng_Latn: An interactive Python accessibility tracker
# hin_Deva: एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
# eng_Latn: Accessor Copyright 2006, 2007 IBM Corporation (BSD)
# hin_Deva: नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# eng_Latn: For new BSD license details, see Copyright and Information Files.
# hin_Deva: जाल स्थल
# eng_Latn: Web site
# hin_Deva: पसंद जोड़ें... (_ A)
# eng_Latn: _ Add Preferences...
# hin_Deva: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# eng_Latn: Bookmark the selected accessibles
# hin_Deva: पुस्तक चिह्न संपादित करें (_ E)...
# eng_Latn: Edit _ Bookmark...
# hin_Deva: पुस्तक-चिह्नों को प्रबंधित करें।
# eng_Latn: Manage bookmarks.
# hin_Deva: पुस्तक चिह्नों को संपादित करें...
# eng_Latn: Edit Bookmarks...
# hin_Deva: शीर्षक
# eng_Latn: Title
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: पथ
# eng_Latn: Path
# hin_Deva: पुस्तक-चिह्न जोड़ें...
# eng_Latn: Add Bookmark...
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: अनुप्रयोगः
# eng_Latn: Application:
# hin_Deva: पथः
# eng_Latn: Path:
# hin_Deva: प्लग-इन त्रुटियां
# eng_Latn: Plug-in errors
# hin_Deva: दृश्य
# eng_Latn: view
# hin_Deva: कोई दृश्य नहीं है
# eng_Latn: There is no view
# hin_Deva: एकल प्लग-इन दृश्य
# eng_Latn: Single plug-in view
# hin_Deva: प्लग-इन दृश्य
# eng_Latn: Plug-in view
# hin_Deva: प्लग-इन दृश्य (% d)
# eng_Latn: Plugin view (% d)
# hin_Deva: नया दृश्य...
# eng_Latn: New View...
# hin_Deva: नया दृश्य...
# eng_Latn: New View...
# hin_Deva: फाइल (F)
# eng_Latn: File (F)
# hin_Deva: संपादित करें
# eng_Latn: Edit
# hin_Deva: पुस्तक-चिह्न संपादित करें (_ E)...
# eng_Latn: _ Edit Bookmark...
# hin_Deva: दृश्य _ (V)
# eng_Latn: View _ (V)
# hin_Deva: मदद
# eng_Latn: Help
# hin_Deva: पूरा नाम
# eng_Latn: Full name
# hin_Deva: कुंजी बंधन
# eng_Latn: Key binding
# hin_Deva: विषय प्रकार
# eng_Latn: Subject Type
# hin_Deva: एक्सेर्साइसर
# eng_Latn: Accessorizer
# hin_Deva: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# eng_Latn: Give your application the benefit of the accessibility exercise.
# hin_Deva: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# eng_Latn: Accessor accessibility tracker
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default
# hin_Deva: अवधि को हाइलाइट रकें
# eng_Latn: Highlight the duration
# hin_Deva: पहुंचनीय आसंधि नोड को चुनते समय हाइलाइट बक्से की अवधि.
# eng_Latn: The duration of the highlight boxes when selecting a reachable attachment node.
# hin_Deva: भराई के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the filling
# hin_Deva: हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# eng_Latn: Highlighted fill color and transparency.
# hin_Deva: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the border (boarder)
# hin_Deva: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# eng_Latn: Color and opacity of highlighted marginalia.
# hin_Deva: नीचे के पैनल के लिए लेआउट
# eng_Latn: Layout for the bottom panel
# hin_Deva: नीचे पैनल pluginview के लिए लेआउट.
# eng_Latn: Layout for the bottom panel pluginview.
# hin_Deva: ऊपरी पटल के लिए खाका
# eng_Latn: The layout for the top panel
# hin_Deva: शीर्ष पैनल pluginview के लिए लेआउट.
# eng_Latn: Layout for the top panel pluginview.
# hin_Deva: एकल लेआउट दृश्य
# eng_Latn: Single Layout View
# hin_Deva: नई pluginviews उपलब्ध है
# eng_Latn: New pluginviews are available
# hin_Deva: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका.
# eng_Latn: Default plug-in layout for the top panel.
# hin_Deva: एपीआई विचरक
# eng_Latn: API Variator
# hin_Deva: इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# eng_Latn: Distribute what has been received at this time into different methods.
# hin_Deva: निजी गुणों को छिपाएं
# eng_Latn: Hide Personal Attributes
# hin_Deva: विधि
# eng_Latn: method
# hin_Deva: गुणधर्म
# eng_Latn: Properties
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: आईपाइथन कन्सोल
# eng_Latn: iPython Console
# hin_Deva: इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# eng_Latn: Interactive console to work with the currently selected Accessible
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: घटनाओं को मानिटर करें (_ M)
# eng_Latn: _ Monitor Events
# hin_Deva: चुनाव को हटाएं (C _)
# eng_Latn: Delete Selection (C _)
# hin_Deva: सभी
# eng_Latn: All
# hin_Deva: चुने गए अनुप्रयोग
# eng_Latn: Selected Applications
# hin_Deva: चुने गए एक्सेसेबेल
# eng_Latn: Selected Accessables
# hin_Deva: स्रोत
# eng_Latn: Source
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# eng_Latn: Shows events as they occur, from selected types and sources.
# hin_Deva: अंतिम प्रविष्ट घटना को हाइलाइट करो
# eng_Latn: Highlight the last entered event
# hin_Deva: घटना रेकोर्डिंग शुरू करो/रोको
# eng_Latn: Start / Stop event recording
# hin_Deva: घटना रोजनामचा मिटाओ
# eng_Latn: delete event routine
# hin_Deva: बाल गणना
# eng_Latn: Child Calculation
# hin_Deva: वर्णन
# eng_Latn: Description
# hin_Deva: राज्य
# eng_Latn: the State
# hin_Deva: गुणधर्म
# eng_Latn: Properties
# hin_Deva: दिखाएं
# eng_Latn: Show
# hin_Deva: संबंध
# eng_Latn: Relationship
# hin_Deva: पहुंचनीय
# eng_Latn: accessible
# hin_Deva: कार्रवाई संपन्न करें
# eng_Latn: Complete the action
# hin_Deva: कार्रवाई (_ o)
# eng_Latn: _ action
# hin_Deva: आईडी
# eng_Latn: ID
# hin_Deva: औजार बक्सा
# eng_Latn: Toolbox
# hin_Deva: संस्करण
# eng_Latn: Version
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: संग्रह
# eng_Latn: collection
# hin_Deva: 0, 0
# eng_Latn: 0, 0
# hin_Deva: सापेक्ष स्थिति
# eng_Latn: Relative position
# hin_Deva: आकार
# eng_Latn: Size
# hin_Deva: विडजेट
# eng_Latn: Widget
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: एमडीआई-जेड-क्रम
# eng_Latn: MDI-Z-order
# hin_Deva: अल्फा
# eng_Latn: Alpha
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Absolute position
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: डेस्कटोप
# eng_Latn: Desktop
# hin_Deva: स्थान-विशिष्टः
# eng_Latn: Location-specific:
# hin_Deva: प्रलेख
# eng_Latn: document
# hin_Deva: हाइपरकड़ी
# eng_Latn: Hypercord
# hin_Deva: हाइपरपाठ
# eng_Latn: Hypertext
# hin_Deva: स्थिति
# eng_Latn: Situation
# hin_Deva: स्थान-विशिष्ट
# eng_Latn: Location-specific
# hin_Deva: छवि (_ I)
# eng_Latn: _ Image
# hin_Deva: प्रवेश सहायक
# eng_Latn: Entry Assistant
# hin_Deva: सभी चुनें
# eng_Latn: Select All
# hin_Deva: चयन (_ S)
# eng_Latn: _ Selection
# hin_Deva: प्रवाहित करनेयोग्य विषयवस्तु
# eng_Latn: Flowable content
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: सारांशः
# eng_Latn: Summary:
# hin_Deva: चुने गए स्तंभ
# eng_Latn: Selected columns
# hin_Deva: चुनी गई पंक्तियां
# eng_Latn: Selected Lines
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: पंक्तियां
# eng_Latn: Lines
# hin_Deva: सारणी सूचना
# eng_Latn: Table Information
# hin_Deva: नाम (x, y)
# eng_Latn: Name (x, y)
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: विस्तारः
# eng_Latn: Expansion:
# hin_Deva: पंक्ति
# eng_Latn: Row
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: चुनी गई कोशिका
# eng_Latn: The selected cell
# hin_Deva: सारणी (_ T)
# eng_Latn: _ Table
# hin_Deva: ओफसेट
# eng_Latn: Offset
# hin_Deva: डिफोल्टों को शामिल करें
# eng_Latn: Include defaults
# hin_Deva: प्रारंभ
# eng_Latn: Start
# hin_Deva: अंतः 0
# eng_Latn: End: 0
# hin_Deva: पाठ (_ x)
# eng_Latn: Text _ x
# hin_Deva: मौजूदा मान
# eng_Latn: Current value
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Minimum increment
# hin_Deva: अधिकतम मान
# eng_Latn: Maximum value
# hin_Deva: न्यूनतम मान
# eng_Latn: Minimum value
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: अज्ञात
# eng_Latn: Unknown
# hin_Deva: अंतराफलक दर्शक
# eng_Latn: Interface Viewer
# hin_Deva: अंतराफलक के विभिन्न गुणों को देखने देता है
# eng_Latn: Allows viewing of various properties of the interface.
# hin_Deva: (क्रियान्वित नहीं हुआ है)
# eng_Latn: (Not implemented)
# hin_Deva: नाम
# eng_Latn: Name
# hin_Deva: यूआरआई
# eng_Latn: URI
# hin_Deva: प्रारंभ
# eng_Latn: Start
# hin_Deva: अंत
# eng_Latn: The end
# hin_Deva: बहुत अधिक चयनीय शिशु हैं
# eng_Latn: There are a lot of very selective babies
# hin_Deva: (संशोधनीय) Start
# eng_Latn: (Modifiable) Start
# hin_Deva: प्रारंभEnd
# eng_Latn: StartEnd
# hin_Deva: तेज चुनाव
# eng_Latn: Quick pick
# hin_Deva: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# eng_Latn: Plug-ins that have multiple methods for faster selection of accessibles
# hin_Deva: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# eng_Latn: Check Last Focused Accessible
# hin_Deva: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# eng_Latn: Check what is accessible under the mouse
# hin_Deva: स्कीमाः
# eng_Latn: Scheme:
# hin_Deva: सत्यापन
# eng_Latn: Authentication
# hin_Deva: खाली
# eng_Latn: empty
# hin_Deva: कोई विवरण नहीं
# eng_Latn: No details
# hin_Deva: एटी-एसपीआई सत्यापक
# eng_Latn: AT-SPI Verifier
# hin_Deva: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# eng_Latn: Verifies the accessibility of the application
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: भूमिका
# eng_Latn: Role
# hin_Deva: सहेज रहे हैं
# eng_Latn: Saving
# hin_Deva: पुष्टि कर रहे हैं
# eng_Latn: Confirming
# hin_Deva: अपवाद
# eng_Latn: Exception
# hin_Deva: त्रुटि
# eng_Latn: Error
# hin_Deva: चेतावनी
# eng_Latn: Warning
# hin_Deva: सूचना
# eng_Latn: Information
# hin_Deva: दोषमुक्त करें
# eng_Latn: absolve
# hin_Deva: मूल
# eng_Latn: Original
# hin_Deva: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# eng_Latn: Tests basic GUI application accessibility
# hin_Deva: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# eng_Latn: % s that can be processed is neither focusable nor selectable
# hin_Deva: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# eng_Latn: Interactive% s is not actionable
# hin_Deva: एक से अधिक विडजेट फोकस में है
# eng_Latn: More than one widget is in focus.
# hin_Deva: % s का कोई पाठ अंतराफलक नहीं है
# eng_Latn: % s has no text interface
# hin_Deva: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# eng_Latn: The list% s in the parent does not match the child list
# hin_Deva: % s संबंध के लिए अन्योन्य गायब है
# eng_Latn: % s missing reciprocal for relation
# hin_Deva: % s गायब नाम या सूचक
# eng_Latn: % s Missing name or pointer
# hin_Deva: फोकस योग्य% s में सारणी अंतराफलक है, लेकिन कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# eng_Latn: Focusable% s has a table interface, but no selectable interface. Button has focused state without focusable state.
# hin_Deva: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# eng_Latn: % s has state% s, but does not have state% s with it
# hin_Deva: % s किसी समुच्चय का सदस्य नहीं है
# eng_Latn: % s is not a member of any set
# hin_Deva: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# eng_Latn: % (rollename) s list does not match% (num) d row and column index
# hin_Deva: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# eng_Latn: % (rollename) s does not match parent list% (num1) d row and column list% (num2) d
# hin_Deva: % s का कोई नाम या विवरण नहीं
# eng_Latn: % s has no name or description
# hin_Deva: पसंद (_ P)...
# eng_Latn: _ Preferences...
# hin_Deva: विषय सूची (_ C)
# eng_Latn: _ Subject List
# hin_Deva: <dead>
# eng_Latn: < dead >
# hin_Deva: शिशु
# eng_Latn: baby
# hin_Deva: बच्चों के बिना अनुप्रयोग छिपाएँ/दिखाएँ (_ H)
# eng_Latn: _ Hide / Show applications without children
# hin_Deva: पंजी ताजा करें (_ R)
# eng_Latn: _ Refresh Register
# hin_Deva: सभी को ताजा करें
# eng_Latn: refresh all
# hin_Deva: आसंधि (नोड) को ताजा करें (_ N)
# eng_Latn: _ Refresh Node
# hin_Deva: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# eng_Latn: Refresh the babies of the selected nodes.
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: कार्य
# eng_Latn: work
# hin_Deva: कुंजी
# eng_Latn: Key
# hin_Deva: आल्ट
# eng_Latn: Alt
# hin_Deva: कंट्रोल
# eng_Latn: Control
# hin_Deva: शिफ्ट
# eng_Latn: Shift
# hin_Deva: ऊपरी पटल
# eng_Latn: Upper panel
# hin_Deva: निचला पटल
# eng_Latn: Lower panel
# hin_Deva: एक्सेर्साइसर पसंद
# eng_Latn: Accessor Preferences
# hin_Deva: प्लगइन्स
# eng_Latn: Plugins
# hin_Deva: सार्वत्रिक फटाफट कुंजियां
# eng_Latn: Universal Quick Keys
# hin_Deva: हाइलाइटन
# eng_Latn: Highlight
# hin_Deva: हाइलाइट अवधिः
# eng_Latn: Highlight period:
# hin_Deva: सीमांत रंगः
# eng_Latn: Marginal color:
# hin_Deva: हाइलाइट बक्से का सीमांत रंग
# eng_Latn: Marginal color of highlight boxes
# hin_Deva: भराई का रंगः
# eng_Latn: Color of the filling:
# hin_Deva: हाइलाइट बक्से का भराई रंग
# eng_Latn: Fill color of highlight boxes
# hin_Deva: रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# eng_Latn: Ravishankar Srivastava (raviratlami @yahoo.com) Rajesh Ranjan (rajeshkajha @yahoo.com) L. Balasubramaniam (l.balasubramaniam @gmail.com)
# hin_Deva: एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# eng_Latn: An interactive Python accessibility tracker
# hin_Deva: एक्सेर्साइसर सर्वाधिकार (c) 2006,2007 आईबीएम निगम (बीएसडी)
# eng_Latn: Accessor Copyright (c) 2006, 2007 IBM Corporation (BSD)
# hin_Deva: नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# eng_Latn: For new BSD license details, see Copyright and Information Files.
# hin_Deva: जाल स्थल
# eng_Latn: Web site
# hin_Deva: पसंद जोड़ें... (_ A)
# eng_Latn: _ Add Preferences...
# hin_Deva: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# eng_Latn: Bookmark the selected accessibles
# hin_Deva: पुस्तक चिह्न संपादित करें (_ E)...
# eng_Latn: Edit _ Bookmark...
# hin_Deva: पुस्तक-चिह्नों को प्रबंधित करें।
# eng_Latn: Manage bookmarks.
# hin_Deva: पुस्तक चिह्नों को संपादित करें...
# eng_Latn: Edit Bookmarks...
# hin_Deva: शीर्षक
# eng_Latn: Title
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: पथ
# eng_Latn: Path
# hin_Deva: पुस्तक-चिह्न जोड़ें...
# eng_Latn: Add Bookmark...
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: अनुप्रयोगः
# eng_Latn: Application:
# hin_Deva: पथः
# eng_Latn: Path:
# hin_Deva: प्लग-इन त्रुटियांviewport
# eng_Latn: Plug-in errors viewport
# hin_Deva: दृश्य
# eng_Latn: view
# hin_Deva: कोई दृश्य नहीं है
# eng_Latn: There is no view
# hin_Deva: एकल प्लग-इन दृश्य
# eng_Latn: Single plug-in view
# hin_Deva: प्लग-इन दृश्य
# eng_Latn: Plug-in view
# hin_Deva: प्लग-इन दृश्य (% d)
# eng_Latn: Plugin view (% d)
# hin_Deva: नया दृश्य...
# eng_Latn: New View...
# hin_Deva: नया दृश्य...
# eng_Latn: New View...
# hin_Deva: फाइल (F)
# eng_Latn: File (F)
# hin_Deva: संपादित करेंmenu
# eng_Latn: Edit menu
# hin_Deva: पसंद (_ B) menu
# eng_Latn: _ Preferences menu
# hin_Deva: दृश्य _ (V)
# eng_Latn: View _ (V)
# hin_Deva: मदद
# eng_Latn: Help
# hin_Deva: (कोई विवरण नहीं)
# eng_Latn: (No details)
# hin_Deva: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# eng_Latn: Exerciser could not see the application on your desktop. To fix this problem, you need to enable desktop accessibility. Do you want to enable it?
# hin_Deva: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# eng_Latn: Note: Changes will only take effect after the end of the session (logout).
# hin_Deva: नया दृश्य... (_ N)
# eng_Latn: _ New View...
# hin_Deva: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# eng_Latn: Give your application the benefit of the accessibility exercise.
# hin_Deva: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# eng_Latn: Accessor accessibility tracker
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default
# hin_Deva: अवधि को हाइलाइट रकें
# eng_Latn: Highlight the duration
# hin_Deva: पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# eng_Latn: The duration of the highlight box when selecting a reachable node
# hin_Deva: भराई के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the filling
# hin_Deva: हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# eng_Latn: Highlighted fill color and transparency.
# hin_Deva: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the border (boarder)
# hin_Deva: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# eng_Latn: Color and opacity of highlighted marginalia.
# hin_Deva: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# eng_Latn: Default plugin layout for the lower panel
# hin_Deva: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# eng_Latn: Default plugin layout for the lower panel
# hin_Deva: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# eng_Latn: Default plugin layout for the top panel
# hin_Deva: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# eng_Latn: Default plugin layout for the top panel
# hin_Deva: एकल प्लग-इन दृश्य
# eng_Latn: Single plug-in view
# hin_Deva: एकल प्लग-इन दृश्य
# eng_Latn: Single plug-in view
# hin_Deva: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# eng_Latn: Default plugin layout for the top panel
# hin_Deva: एपीआई विचरक
# eng_Latn: API Variator
# hin_Deva: इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# eng_Latn: Distribute what has been received at this time into different methods.
# hin_Deva: निजी गुणों को छिपाएं
# eng_Latn: Hide Personal Attributes
# hin_Deva: विधि
# eng_Latn: method
# hin_Deva: गुणधर्म
# eng_Latn: Properties
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: आईपाइथन कन्सोल
# eng_Latn: iPython Console
# hin_Deva: इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# eng_Latn: Interactive console to work with the currently selected Accessible
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: घटनाओं को मानिटर करें (_ M)
# eng_Latn: _ Monitor Events
# hin_Deva: चुनाव को हटाएं (C _)
# eng_Latn: Delete Selection (C _)
# hin_Deva: सभी
# eng_Latn: All
# hin_Deva: चुने गए अनुप्रयोग
# eng_Latn: Selected Applications
# hin_Deva: चुने गए एक्सेसेबेल
# eng_Latn: Selected Accessables
# hin_Deva: स्रोत
# eng_Latn: Source
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# eng_Latn: Shows events as they occur, from selected types and sources.
# hin_Deva: अंतिम प्रविष्ट घटना को हाइलाइट करो
# eng_Latn: Highlight the last entered event
# hin_Deva: घटना रेकोर्डिंग शुरू करो/रोको
# eng_Latn: Start / Stop event recording
# hin_Deva: घटना रोजनामचा मिटाओ
# eng_Latn: delete event routine
# hin_Deva: कोई विवरण नहीं
# eng_Latn: No details
# hin_Deva: वर्णन
# eng_Latn: Description
# hin_Deva: दिखाएं
# eng_Latn: Show
# hin_Deva: पहुंचनीय
# eng_Latn: accessible
# hin_Deva: कार्रवाई संपन्न करें
# eng_Latn: Complete the action
# hin_Deva: कार्रवाई (_ o)
# eng_Latn: _ action
# hin_Deva: आईडी
# eng_Latn: ID
# hin_Deva: औजार बक्सा
# eng_Latn: Toolbox
# hin_Deva: संस्करण
# eng_Latn: Version
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: संग्रह
# eng_Latn: collection
# hin_Deva: 0, 0
# eng_Latn: 0, 0
# hin_Deva: सापेक्ष स्थिति
# eng_Latn: Relative position
# hin_Deva: आकार
# eng_Latn: Size
# hin_Deva: विडजेट
# eng_Latn: Widget
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: एमडीआई-जेड-क्रम
# eng_Latn: MDI-Z-order
# hin_Deva: अल्फा
# eng_Latn: Alpha
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Absolute position
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: डेस्कटोप
# eng_Latn: Desktop
# hin_Deva: स्थान-विशिष्टः
# eng_Latn: Location-specific:
# hin_Deva: प्रलेख
# eng_Latn: document
# hin_Deva: हाइपरकड़ी
# eng_Latn: Hypercord
# hin_Deva: हाइपरपाठ
# eng_Latn: Hypertext
# hin_Deva: स्थिति
# eng_Latn: Situation
# hin_Deva: वर्णन
# eng_Latn: Description
# hin_Deva: स्थान-विशिष्ट
# eng_Latn: Location-specific
# hin_Deva: छवि (_ I)
# eng_Latn: _ Image
# hin_Deva: प्रवेश सहायक
# eng_Latn: Entry Assistant
# hin_Deva: सभी चुनें
# eng_Latn: Select All
# hin_Deva: चयन (_ S)
# eng_Latn: _ Selection
# hin_Deva: प्रवाहित करनेयोग्य विषयवस्तु
# eng_Latn: Flowable content
# hin_Deva: चुने गए स्तंभ
# eng_Latn: Selected columns
# hin_Deva: चुनी गई पंक्तियां
# eng_Latn: Selected Lines
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: पंक्तियां
# eng_Latn: Lines
# hin_Deva: & lt; bgt; सारणी सूचनाlt;/bgt;
# eng_Latn: & lt; bgt; table information lt; / bgt;
# hin_Deva: नाम (x, y)
# eng_Latn: Name (x, y)
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: विस्तारः
# eng_Latn: Expansion:
# hin_Deva: पंक्ति
# eng_Latn: Row
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# eng_Latn: & lt; bgt; selected cell lt; / bgt;
# hin_Deva: सारणी (_ T)
# eng_Latn: _ Table
# hin_Deva: ओफसेट
# eng_Latn: Offset
# hin_Deva: डिफोल्टों को शामिल करें
# eng_Latn: Include defaults
# hin_Deva: पाठ (_ x)
# eng_Latn: Text _ x
# hin_Deva: मौजूदा मान
# eng_Latn: Current value
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Minimum increment
# hin_Deva: अधिकतम मान
# eng_Latn: Maximum value
# hin_Deva: न्यूनतम मान
# eng_Latn: Minimum value
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: अंतराफलक दर्शक
# eng_Latn: Interface Viewer
# hin_Deva: अंतराफलक के विभिन्न गुणों को देखने देता है
# eng_Latn: Allows viewing of various properties of the interface.
# hin_Deva: (क्रियान्वित नहीं हुआ है)
# eng_Latn: (Not implemented)
# hin_Deva: नाम
# eng_Latn: Name
# hin_Deva: यूआरआई
# eng_Latn: URI
# hin_Deva: प्रारंभ
# eng_Latn: Start
# hin_Deva: अंत
# eng_Latn: The end
# hin_Deva: बहुत अधिक चयनीय शिशु हैं
# eng_Latn: There are a lot of very selective babies
# hin_Deva: तेज चुनाव
# eng_Latn: Quick pick
# hin_Deva: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# eng_Latn: Plug-ins that have multiple methods for faster selection of accessibles
# hin_Deva: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# eng_Latn: Check Last Focused Accessible
# hin_Deva: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# eng_Latn: Check what is accessible under the mouse
# hin_Deva: स्कीमाः
# eng_Latn: Scheme:
# hin_Deva: सत्यापन
# eng_Latn: Authentication
# hin_Deva: खाली
# eng_Latn: empty
# hin_Deva: कोई विवरण नहीं
# eng_Latn: No details
# hin_Deva: एटी-एसपीआई सत्यापक
# eng_Latn: AT-SPI Verifier
# hin_Deva: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# eng_Latn: Verifies the accessibility of the application
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: भूमिका
# eng_Latn: Role
# hin_Deva: सहेज रहे हैं
# eng_Latn: Saving
# hin_Deva: पुष्टि कर रहे हैं
# eng_Latn: Confirming
# hin_Deva: अपवाद
# eng_Latn: Exception
# hin_Deva: त्रुटि
# eng_Latn: Error
# hin_Deva: चेतावनी
# eng_Latn: Warning
# hin_Deva: सूचना
# eng_Latn: Information
# hin_Deva: दोषमुक्त करें
# eng_Latn: absolve
# hin_Deva: मूल
# eng_Latn: Original
# hin_Deva: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# eng_Latn: Tests basic GUI application accessibility
# hin_Deva: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# eng_Latn: % s that can be processed is neither focusable nor selectable
# hin_Deva: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# eng_Latn: Interactive% s is not actionable
# hin_Deva: एक से अधिक विडजेट फोकस में है
# eng_Latn: More than one widget is in focus.
# hin_Deva: % s का कोई पाठ अंतराफलक नहीं है
# eng_Latn: % s has no text interface
# hin_Deva: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# eng_Latn: The list% s in the parent does not match the child list
# hin_Deva: % s संबंध के लिए अन्योन्य गायब है
# eng_Latn: % s missing reciprocal for relation
# hin_Deva: % s गायब नाम या सूचक
# eng_Latn: % s Missing name or pointer
# hin_Deva: फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# eng_Latn: Focusable% s has a table interface, no selectable interface, button has focused state without focusable state
# hin_Deva: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# eng_Latn: % s has state% s, but does not have state% s with it
# hin_Deva: % s किसी समुच्चय का सदस्य नहीं है
# eng_Latn: % s is not a member of any set
# hin_Deva: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# eng_Latn: % (rollename) s list does not match% (num) d row and column index
# hin_Deva: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# eng_Latn: % (rollename) s does not match parent list% (num1) d row and column list% (num2) d
# hin_Deva: % s का कोई नाम या विवरण नहीं
# eng_Latn: % s has no name or description
# hin_Deva: पसंद (_ P)...
# eng_Latn: _ Preferences...
# hin_Deva: विषय सूची (_ C)
# eng_Latn: _ Subject List
# hin_Deva: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# eng_Latn: Exerciser could not see the application on your desktop. To fix this problem, you need to enable desktop accessibility. Do you want to enable it?
# hin_Deva: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# eng_Latn: Note: Changes will only take effect after the end of the session (logout).
# hin_Deva: शिशु
# eng_Latn: baby
# hin_Deva: पंजी ताजा करें (_ R)
# eng_Latn: _ Refresh Register
# hin_Deva: सभी को ताजा करें
# eng_Latn: refresh all
# hin_Deva: आसंधि (नोड) को ताजा करें (_ N)
# eng_Latn: _ Refresh Node
# hin_Deva: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# eng_Latn: Refresh the babies of the selected nodes.
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: कार्य
# eng_Latn: work
# hin_Deva: कुंजी
# eng_Latn: Key
# hin_Deva: आल्ट
# eng_Latn: Alt
# hin_Deva: कंट्रोल
# eng_Latn: Control
# hin_Deva: शिफ्ट
# eng_Latn: Shift
# hin_Deva: ऊपरी पटल
# eng_Latn: Upper panel
# hin_Deva: निचला पटल
# eng_Latn: Lower panel
# hin_Deva: एक्सेर्साइसर पसंद
# eng_Latn: Accessor Preferences
# hin_Deva: प्लगइन्स
# eng_Latn: Plugins
# hin_Deva: सार्वत्रिक फटाफट कुंजियां
# eng_Latn: Universal Quick Keys
# hin_Deva: हाइलाइटन
# eng_Latn: Highlight
# hin_Deva: हाइलाइट अवधिः
# eng_Latn: Highlight period:
# hin_Deva: सीमांत रंगः
# eng_Latn: Marginal color:
# hin_Deva: हाइलाइट बक्से का सीमांत रंग
# eng_Latn: Marginal color of highlight boxes
# hin_Deva: भराई का रंगः
# eng_Latn: Color of the filling:
# hin_Deva: हाइलाइट बक्से का भराई रंग
# eng_Latn: Fill color of highlight boxes
# ...
# hin_Deva: जाल स्थल
# eng_Latn: Web site
# hin_Deva: पसंद जोड़ें... (_ A)
# eng_Latn: _ Add Preferences...
# hin_Deva: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# eng_Latn: Bookmark the selected accessibles
# hin_Deva: पुस्तक चिह्न संपादित करें (_ E)...
# eng_Latn: Edit _ Bookmark...
# hin_Deva: पुस्तक-चिह्नों को प्रबंधित करें।
# eng_Latn: Manage bookmarks.
# hin_Deva: पुस्तक चिह्नों को संपादित करें...
# eng_Latn: Edit Bookmarks...
# hin_Deva: शीर्षक
# eng_Latn: Title
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: पथ
# eng_Latn: Path
# hin_Deva: पुस्तक-चिह्न जोड़ें...
# eng_Latn: Add Bookmark...
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: अनुप्रयोगः
# eng_Latn: Application:
# hin_Deva: पथः
# eng_Latn: Path:
# hin_Deva: प्लग-इन त्रुटियां
# eng_Latn: Plug-in errors
# hin_Deva: दृश्य
# eng_Latn: view
# hin_Deva: कोई दृश्य नहीं है
# eng_Latn: There is no view
# hin_Deva: एकल प्लग-इन दृश्य
# eng_Latn: Single plug-in view
# hin_Deva: प्लग-इन दृश्य
# eng_Latn: Plug-in view
# hin_Deva: प्लग-इन दृश्य (% d)
# eng_Latn: Plugin view (% d)
# hin_Deva: नया दृश्य...
# eng_Latn: New View...
# hin_Deva: नया दृश्य...
# eng_Latn: New View...
# hin_Deva: फाइल (F)
# eng_Latn: File (F)
# hin_Deva: संपादित करें
# eng_Latn: Edit
# hin_Deva: पुस्तक-चिह्न संपादित करें (_ E)...
# eng_Latn: _ Edit Bookmark...
# hin_Deva: दृश्य _ (V)
# eng_Latn: View _ (V)
# hin_Deva: मदद
# eng_Latn: Help
# hin_Deva: एक्सेर्साइसर
# eng_Latn: Accessorizer
# hin_Deva: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# eng_Latn: Give your application the benefit of the accessibility exercise.
# hin_Deva: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# eng_Latn: Accessor accessibility tracker
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default
# hin_Deva: अवधि को हाइलाइट रकें
# eng_Latn: Highlight the duration
# hin_Deva: पहुंचनीय आसंधि नोड को चुनते समय हाइलाइट बक्से की अवधि.
# eng_Latn: The duration of the highlight boxes when selecting a reachable attachment node.
# hin_Deva: भराई के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the filling
# hin_Deva: हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# eng_Latn: Highlighted fill color and transparency.
# hin_Deva: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# eng_Latn: Highlight the color of the border (boarder)
# hin_Deva: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# eng_Latn: Color and opacity of highlighted marginalia.
# hin_Deva: क्षैतिज विभाजन
# eng_Latn: Horizontal division
# hin_Deva: मुख्य विंडो की क्षैतिज विभाजन की स्थिति.
# eng_Latn: The position of the horizontal partition of the main window.
# hin_Deva: अनुलंब विभाजित
# eng_Latn: vertically divided
# hin_Deva: मुख्य विंडो की अनुलंब विभाजित की स्थिति.
# eng_Latn: The position of the vertical partition of the main window.
# hin_Deva: तयशुदा विंडो ऊंचाई
# eng_Latn: Default window height
# hin_Deva: विंडो की ऊंचाई का मान.
# eng_Latn: The value of the window height.
# hin_Deva: तयशुदा विंडो चौड़ाई
# eng_Latn: Default window width
# hin_Deva: विंडो चौड़ाई मान.
# eng_Latn: Window width value.
# hin_Deva: नीचे के पैनल के लिए लेआउट
# eng_Latn: Layout for the bottom panel
# hin_Deva: नीचे पैनल pluginview के लिए लेआउट.
# eng_Latn: Layout for the bottom panel pluginview.
# hin_Deva: ऊपरी पटल के लिए खाका
# eng_Latn: The layout for the top panel
# hin_Deva: शीर्ष पैनल pluginview के लिए लेआउट.
# eng_Latn: Layout for the top panel pluginview.
# hin_Deva: एकल लेआउट दृश्य
# eng_Latn: Single Layout View
# hin_Deva: एक ही खाका में प्लगिन देखें.
# eng_Latn: Look for plugins in the same layout.
# hin_Deva: नई pluginviews उपलब्ध है
# eng_Latn: New pluginviews are available
# hin_Deva: इस सूची में सभी नई उपलब्ध pluginviews शामिल हैं
# eng_Latn: This list includes all newly available pluginviews.
# hin_Deva: pluginview लेआउट
# eng_Latn: Pluginview Layout
# hin_Deva: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका.
# eng_Latn: Default plug-in layout for the top panel.
# hin_Deva: विंडो की ऊँचाई
# eng_Latn: Window height
# hin_Deva: विंडो की ऊंचाई का मान.
# eng_Latn: The value of the window height.
# hin_Deva: विंडो की चौड़ाई
# eng_Latn: Width of the window
# hin_Deva: विंडो चौड़ाई मान.
# eng_Latn: Window width value.
# hin_Deva: hotkey संयोजन
# eng_Latn: hotkey combination
# hin_Deva: संबंधित कार्रवाई के लिए hotkey संयोजन.
# eng_Latn: Hotkey combination for the corresponding action.
# hin_Deva: एपीआई विचरक
# eng_Latn: API Variator
# hin_Deva: इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# eng_Latn: Distribute what has been received at this time into different methods.
# hin_Deva: निजी गुणों को छिपाएं
# eng_Latn: Hide Personal Attributes
# hin_Deva: विधि
# eng_Latn: method
# hin_Deva: गुणधर्म
# eng_Latn: Properties
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: आईपाइथन कन्सोल
# eng_Latn: iPython Console
# hin_Deva: इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# eng_Latn: Interactive console to work with the currently selected Accessible
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: घटनाओं को मानिटर करें (_ M)
# eng_Latn: _ Monitor Events
# hin_Deva: चुनाव को हटाएं (C _)
# eng_Latn: Delete Selection (C _)
# hin_Deva: सभी
# eng_Latn: All
# hin_Deva: चुने गए अनुप्रयोग
# eng_Latn: Selected Applications
# hin_Deva: चुने गए एक्सेसेबेल
# eng_Latn: Selected Accessables
# hin_Deva: स्रोत
# eng_Latn: Source
# hin_Deva: घटना मानिटर
# eng_Latn: Event Monitor
# hin_Deva: चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# eng_Latn: Shows events as they occur, from selected types and sources.
# hin_Deva: अंतिम प्रविष्ट घटना को हाइलाइट करो
# eng_Latn: Highlight the last entered event
# hin_Deva: घटना रेकोर्डिंग शुरू करो/रोको
# eng_Latn: Start / Stop event recording
# hin_Deva: घटना रोजनामचा मिटाओ
# eng_Latn: delete event routine
# hin_Deva: बाल गणना
# eng_Latn: Child Calculation
# hin_Deva: (कोई विवरण नहीं)
# eng_Latn: (No details)
# hin_Deva: वर्णन
# eng_Latn: Description
# hin_Deva: राज्य
# eng_Latn: the State
# hin_Deva: दिखाएं
# eng_Latn: Show
# hin_Deva: संबंध
# eng_Latn: Relationship
# hin_Deva: गुणधर्म
# eng_Latn: Properties
# hin_Deva: पहुंचनीय
# eng_Latn: accessible
# hin_Deva: कार्रवाई संपन्न करें
# eng_Latn: Complete the action
# hin_Deva: कार्रवाई (_ o)
# eng_Latn: _ action
# hin_Deva: आईडी
# eng_Latn: ID
# hin_Deva: औजार बक्सा
# eng_Latn: Toolbox
# hin_Deva: संस्करण
# eng_Latn: Version
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: संग्रह
# eng_Latn: collection
# hin_Deva: 0, 0
# eng_Latn: 0, 0
# hin_Deva: सापेक्ष स्थिति
# eng_Latn: Relative position
# hin_Deva: आकार
# eng_Latn: Size
# hin_Deva: विडजेट
# eng_Latn: Widget
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: एमडीआई-जेड-क्रम
# eng_Latn: MDI-Z-order
# hin_Deva: अल्फा
# eng_Latn: Alpha
# hin_Deva: निरपेक्ष स्थिति
# eng_Latn: Absolute position
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: डेस्कटोप
# eng_Latn: Desktop
# hin_Deva: स्थान-विशिष्टः
# eng_Latn: Location-specific:
# hin_Deva: प्रलेख
# eng_Latn: document
# hin_Deva: हाइपरकड़ी
# eng_Latn: Hypercord
# hin_Deva: हाइपरपाठ
# eng_Latn: Hypertext
# hin_Deva: स्थिति
# eng_Latn: Situation
# hin_Deva: वर्णन
# eng_Latn: Description
# hin_Deva: स्थान-विशिष्ट
# eng_Latn: Location-specific
# hin_Deva: छवि (_ I)
# eng_Latn: _ Image
# hin_Deva: प्रवेश सहायक
# eng_Latn: Entry Assistant
# hin_Deva: सभी चुनें
# eng_Latn: Select All
# hin_Deva: चयन (_ S)
# eng_Latn: _ Selection
# hin_Deva: प्रवाहित करनेयोग्य विषयवस्तु
# eng_Latn: Flowable content
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: सारांशः
# eng_Latn: Summary:
# hin_Deva: चुने गए स्तंभ
# eng_Latn: Selected columns
# hin_Deva: चुनी गई पंक्तियां
# eng_Latn: Selected Lines
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: पंक्तियां
# eng_Latn: Lines
# hin_Deva: सारणी सूचना
# eng_Latn: Table Information
# hin_Deva: नाम (x, y)
# eng_Latn: Name (x, y)
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: विस्तारः
# eng_Latn: Expansion:
# hin_Deva: पंक्ति
# eng_Latn: Row
# hin_Deva: स्तंभ
# eng_Latn: column
# hin_Deva: चुनी गई कोशिका
# eng_Latn: The selected cell
# hin_Deva: सारणी (_ T)
# eng_Latn: _ Table
# hin_Deva: पाठ
# eng_Latn: Text
# hin_Deva: ओफसेट
# eng_Latn: Offset
# hin_Deva: डिफोल्टों को शामिल करें
# eng_Latn: Include defaults
# hin_Deva: प्रारंभः 0
# eng_Latn: Start: 0
# hin_Deva: अंतः 0
# eng_Latn: End: 0
# hin_Deva: पाठ (_ x)
# eng_Latn: Text _ x
# hin_Deva: मौजूदा मान
# eng_Latn: Current value
# hin_Deva: न्यूनतम वृद्धि
# eng_Latn: Minimum increment
# hin_Deva: अधिकतम मान
# eng_Latn: Maximum value
# hin_Deva: न्यूनतम मान
# eng_Latn: Minimum value
# hin_Deva: मान
# eng_Latn: Value
# hin_Deva: अज्ञात
# eng_Latn: Unknown
# hin_Deva: अंतराफलक दर्शक
# eng_Latn: Interface Viewer
# hin_Deva: अंतराफलक के विभिन्न गुणों को देखने देता है
# eng_Latn: Allows viewing of various properties of the interface.
# hin_Deva: (क्रियान्वित नहीं हुआ है)
# eng_Latn: (Not implemented)
# hin_Deva: नाम
# eng_Latn: Name
# hin_Deva: यूआरआई
# eng_Latn: URI
# hin_Deva: प्रारंभ
# eng_Latn: Start
# hin_Deva: अंत
# eng_Latn: The end
# hin_Deva: बहुत अधिक चयनीय शिशु हैं
# eng_Latn: There are a lot of very selective babies
# hin_Deva: (संशोधनीय)
# eng_Latn: (Amendable)
# hin_Deva: तेज चुनाव
# eng_Latn: Quick pick
# hin_Deva: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# eng_Latn: Plug-ins that have multiple methods for faster selection of accessibles
# hin_Deva: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# eng_Latn: Check Last Focused Accessible
# hin_Deva: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# eng_Latn: Check what is accessible under the mouse
# hin_Deva: स्कीमाः
# eng_Latn: Scheme:
# hin_Deva: सत्यापन
# eng_Latn: Authentication
# hin_Deva: खाली
# eng_Latn: empty
# hin_Deva: कोई विवरण नहीं
# eng_Latn: No details
# hin_Deva: एटी-एसपीआई सत्यापक
# eng_Latn: AT-SPI Verifier
# hin_Deva: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# eng_Latn: Verifies the accessibility of the application
# hin_Deva: स्तर
# eng_Latn: level
# hin_Deva: भूमिका
# eng_Latn: Role
# hin_Deva: सहेज रहे हैं
# eng_Latn: Saving
# hin_Deva: पुष्टि कर रहे हैं
# eng_Latn: Confirming
# hin_Deva: अपवाद
# eng_Latn: Exception
# hin_Deva: त्रुटि
# eng_Latn: Error
# hin_Deva: चेतावनी
# eng_Latn: Warning
# hin_Deva: सूचना
# eng_Latn: Information
# hin_Deva: दोषमुक्त करें
# eng_Latn: absolve
# hin_Deva: मूल
# eng_Latn: Original
# hin_Deva: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# eng_Latn: Tests basic GUI application accessibility
# hin_Deva: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# eng_Latn: % s that can be processed is neither focusable nor selectable
# hin_Deva: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# eng_Latn: Interactive% s is not actionable
# hin_Deva: एक से अधिक विडजेट फोकस में है
# eng_Latn: More than one widget is in focus.
# hin_Deva: % s का कोई पाठ अंतराफलक नहीं है
# eng_Latn: % s has no text interface
# hin_Deva: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# eng_Latn: The list% s in the parent does not match the child list
# hin_Deva: % s संबंध के लिए अन्योन्य गायब है
# eng_Latn: % s missing reciprocal for relation
# hin_Deva: % s गायब नाम या सूचक
# eng_Latn: % s Missing name or pointer
# hin_Deva: फोकस योग्य% s में सारणी अंतराफलक है, लेकिन कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# eng_Latn: Focusable% s has a table interface, but no selectable interface. Button has focused state without focusable state.
# hin_Deva: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# eng_Latn: % s has state% s, but does not have state% s with it
# hin_Deva: % s किसी समुच्चय का सदस्य नहीं है
# eng_Latn: % s is not a member of any set
# hin_Deva: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# eng_Latn: % (rollename) s list does not match% (num) d row and column index
# hin_Deva: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# eng_Latn: % (rollename) s does not match parent list% (num1) d row and column list% (num2) d
# hin_Deva: % s का कोई नाम या विवरण नहीं
# eng_Latn: % s has no name or description
# hin_Deva: पसंद (_ P)...
# eng_Latn: _ Preferences...
# hin_Deva: विषय सूची (_ C)
# eng_Latn: _ Subject List
# hin_Deva: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# eng_Latn: Exerciser could not see the application on your desktop. To fix this problem, you need to enable desktop accessibility. Do you want to enable it?
# hin_Deva: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# eng_Latn: Note: Changes will only take effect after the end of the session (logout).
# hin_Deva: <dead>
# eng_Latn: < dead >
# hin_Deva: शिशु
# eng_Latn: baby
# hin_Deva: बच्चों के बिना अनुप्रयोग छिपाएँ/दिखाएँ (_ H)
# eng_Latn: _ Hide / Show applications without children
# hin_Deva: पंजी ताजा करें (_ R)
# eng_Latn: _ Refresh Register
# hin_Deva: सभी को ताजा करें
# eng_Latn: refresh all
# hin_Deva: आसंधि (नोड) को ताजा करें (_ N)
# eng_Latn: _ Refresh Node
# hin_Deva: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# eng_Latn: Refresh the babies of the selected nodes.
# hin_Deva: घटक
# eng_Latn: component
# hin_Deva: कार्य
# eng_Latn: work
# hin_Deva: कुंजी
# eng_Latn: Key
# hin_Deva: आल्ट
# eng_Latn: Alt
# hin_Deva: कंट्रोल
# eng_Latn: Control
# hin_Deva: शिफ्ट
# eng_Latn: Shift
# hin_Deva: ऊपरी पटल
# eng_Latn: Upper panel
# hin_Deva: निचला पटल
# eng_Latn: Lower panel
# hin_Deva: एक्सेर्साइसर पसंद
# eng_Latn: Accessor Preferences
# hin_Deva: प्लगइन्स
# eng_Latn: Plugins
# hin_Deva: सार्वत्रिक फटाफट कुंजियां
# eng_Latn: Universal Quick Keys
# hin_Deva: हाइलाइटन
# eng_Latn: Highlight
# hin_Deva: हाइलाइट अवधिः
# eng_Latn: Highlight period:
# hin_Deva: सीमांत रंगः
# eng_Latn: Marginal color:
# hin_Deva: हाइलाइट बक्से का सीमांत रंग
# eng_Latn: Marginal color of highlight boxes
# hin_Deva: भराई का रंगः
# eng_Latn: Color of the filling:
# hin_Deva: हाइलाइट बक्से का भराई रंग
# eng_Latn: Fill color of highlight boxes
# hin_Deva: रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# eng_Latn: Ravishankar Srivastava (raviratlami @yahoo.com) Rajesh Ranjan (rajeshkajha @yahoo.com) L. Balasubramaniam (l.balasubramaniam @gmail.com)
# hin_Deva: एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# eng_Latn: An interactive Python accessibility tracker
# hin_Deva: एक्सेर्साइसर सर्वाधिकार (c) 2006,2007 आईबीएम निगम (बीएसडी)
# eng_Latn: Accessor Copyright (c) 2006, 2007 IBM Corporation (BSD)
# hin_Deva: नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# eng_Latn: For new BSD license details, see Copyright and Information Files.
# hin_Deva: जाल स्थल
# eng_Latn: Web site
# hin_Deva: पसंद जोड़ें... (_ A)
# eng_Latn: _ Add Preferences...
# hin_Deva: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# eng_Latn: Bookmark the selected accessibles
# hin_Deva: पुस्तक चिह्न संपादित करें (_ E)...
# eng_Latn: Edit _ Bookmark...
# hin_Deva: पुस्तक-चिह्नों को प्रबंधित करें।
# eng_Latn: Manage bookmarks.
# hin_Deva: पुस्तक चिह्नों को संपादित करें...
# eng_Latn: Edit Bookmarks...
# hin_Deva: शीर्षक
# eng_Latn: Title
# hin_Deva: अनुप्रयोग
# eng_Latn: Application
# hin_Deva: पथ
# eng_Latn: Path
# hin_Deva: पुस्तक-चिह्न जोड़ें...
# eng_Latn: Add Bookmark...
# hin_Deva: शीर्षकः
# eng_Latn: Title:
# hin_Deva: अनुप्रयोगः
# eng_Latn: Application:
# hin_Deva: पथः
# eng_Latn: Path:
# hin_Deva: प्लग-इन त्रुटियांviewport
# eng_Latn: Plug-in errors viewport
# hin_Deva: दृश्य
# eng_Latn: view
# hin_Deva: कोई दृश्य नहीं है
# eng_Latn: There is no view
# hin_Deva: एकल प्लग-इन दृश्य
# eng_Latn: Single plug-in view
# hin_Deva: प्लग-इन दृश्य
# eng_Latn: Plug-in view
# hin_Deva: प्लग-इन दृश्य (% d)
# eng_Latn: Plugin view (% d)
# hin_Deva: नया दृश्य... (_ N)
# eng_Latn: _ New View...
# hin_Deva: नया दृश्य...
# eng_Latn: New View...
# hin_Deva: फाइल (F)
# eng_Latn: File (F)
# hin_Deva: संपादित करेंmenu
# eng_Latn: Edit menu
# hin_Deva: पसंद (_ B) menu
# eng_Latn: _ Preferences menu
# hin_Deva: दृश्य _ (V)
# eng_Latn: View _ (V)
# hin_Deva: मदद
# eng_Latn: Help
# hin_Deva: एक्सेर्साइसर
# eng_Latn: Accessorizer
# hin_Deva: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# eng_Latn: Give your application the benefit of the accessibility exercise.
# hin_Deva: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# eng_Latn: Accessor accessibility tracker
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default
# hin_Deva: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# eng_Latn: List of plugins that are disabled by default

# %%
#BLEU Score
references = [[english] for english in english_sentences]  # Create reference list of lists
candidates = translation_eng  # Model translations
bleu_score = corpus_bleu(references, candidates)
print(f"BLEU score: {bleu_score:.4f}")
# Out:
# BLEU score: 0.6459

# %%
# STS Score
# Load the pre-trained model
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')
model = model.to('cuda' if torch.cuda.is_available() else 'cpu')

# Encode the original english sentences and the translated sentences
embeddings1 = model.encode(english_sentences, convert_to_tensor=True, device=model.device)
embeddings2 = model.encode(translation_eng, convert_to_tensor=True, device=model.device)

# Compute cosine similarities between the embeddings
cosine_scores = util.cos_sim(embeddings1, embeddings2)

# Calculate the average STS score
sts_score = cosine_scores.diag().mean().item()
print(f"STS score: {sts_score:.4f}")
# Out:
# STS score: 0.8453

# %%
# CHRF
# Initialize CHRF metric
chrf = CHRF(word_order=1)

# Calculate CHRF score
chrf_score = chrf.corpus_score(translation_eng, [[english] for english in english_sentences]).score
print(f"CHRF score: {chrf_score:.4f}")
# Out:
# CHRF score: 65.3206

# %%
# METEOR Score
# Download required NLTK data (if not already downloaded)
nltk.download('punkt')  # Download the 'punkt' resource for sentence tokenization
nltk.download('wordnet')

# Tokenize the sentences if they're not already tokenized
hindi_sentences_tokenized = [nltk.word_tokenize(sent) for sent in english_sentences]
translatedHinEng_tokenized = [nltk.word_tokenize(sent) for sent in translation_eng]

# Calculate METEOR score
from nltk.translate.meteor_score import meteor_score # Import the meteor_score function
meteor_scores = [meteor_score([ref], hyp) for ref, hyp in zip(hindi_sentences_tokenized, translatedHinEng_tokenized)]
average_meteor_score = sum(meteor_scores) / len(meteor_scores)

print(f"METEOR score: {average_meteor_score:.4f}")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# METEOR score: 0.5359
