# %%
# !pip install transformers
# !pip install datasets transformers[sentencepiece] sacrebleu
import pandas as pd
import numpy as np
from datasets import load_dataset
import tensorflow as tf
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, portalocker, dill, colorama, sacrebleu, multiprocess, datasets
# Successfully installed colorama-0.4.6 datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 portalocker-2.8.2 sacrebleu-2.4.2 xxhash-3.4.1

# %%
# Define dataset path
dataset_path = "cfilt/iitb-english-hindi"
train_dataset = load_dataset(dataset_path, split="train[:1000]")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/3.14k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/190M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/85.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1659083 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/520 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2507 [00:00<?, ? examples/s]

# %%
english_sentences = [item['en'] for item in train_dataset['translation']]
hindi_sentences = [item['hi'] for item in train_dataset['translation']]

# %%
len(english_sentences)
# Out:
# 1000

# %%
len(hindi_sentences)
# Out:
# 1000

# %%
from transformers import pipeline

pipe = pipeline("translation", model="facebook/nllb-200-distilled-600M")
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("facebook/nllb-200-distilled-600M")
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/nllb-200-distilled-600M")

# %%
translator = pipeline('translation', model=model, tokenizer=tokenizer, src_lang="eng_Latn", tgt_lang='hin_Deva', max_length = 400)

# %%
translatedEngHin = []
for (index, (eng, hin)) in enumerate(zip(english_sentences, hindi_sentences)):
    print(index+1)
    print("English:", eng)
    prediction = translator(eng)
    translation = prediction[0]['translation_text']
    print("Translated: ", translation)
    print("Original: ", hin)
    print("------------------------------")
    translatedEngHin.append(translation)
# Out:
# 1
# English: Give your application an accessibility workout
# Translated:  अपने आवेदन को सुलभता प्रशिक्षण दें
# Original:  अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# ------------------------------
# 2
# English: Accerciser Accessibility Explorer
# Translated:  एक्सरसाइज़र एक्सेसिबिलिटी एक्सप्लोरर
# Original:  एक्सेर्साइसर पहुंचनीयता अन्वेषक
# ------------------------------
# 3
# English: The default plugin layout for the bottom panel
# Translated:  नीचे पैनल के लिए डिफ़ॉल्ट प्लगइन लेआउट
# Original:  निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# ------------------------------
# 4
# English: The default plugin layout for the top panel
# Translated:  शीर्ष पैनल के लिए डिफ़ॉल्ट प्लगइन लेआउट
# Original:  ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# ------------------------------
# 5
# English: A list of plugins that are disabled by default
# Translated:  प्लगइन्स की सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
# Original:  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# ------------------------------
# 6
# English: Highlight duration
# Translated:  हाइलाइट अवधि
# Original:  अवधि को हाइलाइट रकें
# ------------------------------
# 7
# English: The duration of the highlight box when selecting accessible nodes
# Translated:  सुलभ नोड्स का चयन करते समय हाइलाइट बॉक्स की अवधि
# Original:  पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# ------------------------------
# 8
# English: Highlight border color
# Translated:  सीमा रंग को हाइलाइट करें
# Original:  सीमांत (बोर्डर) के रंग को हाइलाइट करें
# ------------------------------
# 9
# English: The color and opacity of the highlight border.
# Translated:  प्रकाश सीमा का रंग और अस्पष्टता।
# Original:  हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# ------------------------------
# 10
# English: Highlight fill color
# Translated:  भरने का रंग हाइलाइट करें
# Original:  भराई के रंग को हाइलाइट करें
# ------------------------------
# 11
# English: The color and opacity of the highlight fill.
# Translated:  हाइलाइट भरने का रंग और अस्पष्टता।
# Original:  हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# ------------------------------
# 12
# English: API Browser
# Translated:  एपीआई ब्राउज़र
# Original:  एपीआई विचरक
# ------------------------------
# 13
# English: Browse the various methods of the current accessible
# Translated:  वर्तमान उपलब्ध की विभिन्न विधियों ब्राउज़ करें
# Original:  इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# ------------------------------
# 14
# English: Hide private attributes
# Translated:  निजी गुणों को छिपाएँ
# Original:  निजी गुणों को छिपाएं
# ------------------------------
# 15
# English: Method
# Translated:  विधि
# Original:  विधि
# ------------------------------
# 16
# English: Property
# Translated:  संपत्ति
# Original:  गुणधर्म
# ------------------------------
# 17
# English: Value
# Translated:  मूल्य
# Original:  मान
# ------------------------------
# 18
# English: IPython Console
# Translated:  आइपयथन कंसोल
# Original:  आईपाइथन कन्सोल
# ------------------------------
# 19
# English: Interactive console for manipulating currently selected accessible
# Translated:  वर्तमान में चयनित सुलभ के लिए हेरफेर के लिए इंटरैक्टिव कंसोल
# Original:  इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# ------------------------------
# 20
# English: Event monitor
# Translated:  घटना मॉनिटर
# Original:  घटना मानिटर
# ------------------------------
# 21
# English: _ Monitor Events
# Translated:  _ घटनाओं की निगरानी
# Original:  घटनाओं को मानिटर करें (_ M)
# ------------------------------
# 22
# English: C _ lear Selection
# Translated:  C _ lear चयन
# Original:  चुनाव को हटाएं (C _)
# ------------------------------
# 23
# English: Everything
# Translated:  सब कुछ
# Original:  सभी
# ------------------------------
# 24
# English: Selected application
# Translated:  चयनित आवेदन
# Original:  चुने गए अनुप्रयोग
# ------------------------------
# 25
# English: Selected accessible
# Translated:  चयनित सुलभ
# Original:  चुने गए एक्सेसेबेल
# ------------------------------
# 26
# English: Source
# Translated:  स्रोत
# Original:  स्रोत
# ------------------------------
# 27
# English: Event Monitor
# Translated:  घटना मॉनिटर
# Original:  घटना मानिटर
# ------------------------------
# 28
# English: Shows events as they occur from selected types and sources
# Translated:  घटनाओं को प्रदर्शित करता है जैसे वे चयनित प्रकारों और स्रोतों से होती हैं
# Original:  चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# ------------------------------
# 29
# English: Highlight last event entry
# Translated:  अंतिम घटना प्रविष्टि को हाइलाइट करें
# Original:  अंतिम प्रविष्ट घटना को हाइलाइट करो
# ------------------------------
# 30
# English: Start / stop event recording
# Translated:  प्रारंभ / रोक घटना रिकॉर्डिंग
# Original:  घटना रेकोर्डिंग शुरू करो/रोको
# ------------------------------
# 31
# English: Clear event log
# Translated:  घटना लॉग स्पष्ट
# Original:  घटना रोजनामचा मिटाओ
# ------------------------------
# 32
# English: (no description)
# Translated:  (कोई विवरण नहीं)
# Original:  कोई विवरण नहीं
# ------------------------------
# 33
# English: Description
# Translated:  विवरण
# Original:  वर्णन
# ------------------------------
# 34
# English: Show
# Translated:  दिखाएँ
# Original:  दिखाएं
# ------------------------------
# 35
# English: _ Accessible
# Translated:  _ पहुँच योग्य
# Original:  पहुंचनीय
# ------------------------------
# 36
# English: Perform action
# Translated:  कार्य करें
# Original:  कार्रवाई संपन्न करें
# ------------------------------
# 37
# English: Acti _ on
# Translated:  एक्टि _ ऑन
# Original:  कार्रवाई (_ o)
# ------------------------------
# 38
# English: ID
# Translated:  पहचान पत्र
# Original:  आईडी
# ------------------------------
# 39
# English: Toolkit
# Translated:  उपकरण
# Original:  औजार बक्सा
# ------------------------------
# 40
# English: Version
# Translated:  संस्करण
# Original:  संस्करण
# ------------------------------
# 41
# English: Ap _ plication
# Translated:  एप्लिकेशन
# Original:  अनुप्रयोग
# ------------------------------
# 42
# English: Col _ lection
# Translated:  क _ लक्शन
# Original:  संग्रह
# ------------------------------
# 43
# English: 0, 0
# Translated:  0
# Original:  0, 0
# ------------------------------
# 44
# English: Relative position
# Translated:  सापेक्ष स्थिति
# Original:  सापेक्ष स्थिति
# ------------------------------
# 45
# English: Size
# Translated:  आकार
# Original:  आकार
# ------------------------------
# 46
# English: WIDGET
# Translated:  विडगेट
# Original:  विडजेट
# ------------------------------
# 47
# English: Layer
# Translated:  परत
# Original:  स्तर
# ------------------------------
# 48
# English: MDI - Z - order
# Translated:  एमडीआई - जेड - क्रम
# Original:  एमडीआई-जेड-क्रम
# ------------------------------
# 49
# English: Alpha
# Translated:  अल्फा
# Original:  अल्फा
# ------------------------------
# 50
# English: Absolute position
# Translated:  पूर्ण स्थिति
# Original:  निरपेक्ष स्थिति
# ------------------------------
# 51
# English: Co _ mponent
# Translated:  सह-संरक्षण
# Original:  घटक
# ------------------------------
# 52
# English: Des _ ktop
# Translated:  शीर्ष पर
# Original:  डेस्कटोप
# ------------------------------
# 53
# English: Locale:
# Translated:  स्थानीय:
# Original:  स्थान-विशिष्टः
# ------------------------------
# 54
# English: _ Document
# Translated:  दस्तावेज़
# Original:  प्रलेख
# ------------------------------
# 55
# English: Hyperlink
# Translated:  हाइपरलिंक
# Original:  हाइपरकड़ी
# ------------------------------
# 56
# English: H _ ypertext
# Translated:  H _ ypertext
# Original:  हाइपरपाठ
# ------------------------------
# 57
# English: Position
# Translated:  स्थिति
# Original:  स्थिति
# ------------------------------
# 58
# English: Description
# Translated:  विवरण
# Original:  वर्णन
# ------------------------------
# 59
# English: Locale
# Translated:  स्थानीय
# Original:  स्थान-विशिष्ट
# ------------------------------
# 60
# English: _ Image
# Translated:  छवि
# Original:  छवि (_ I)
# ------------------------------
# 61
# English: Lo _ gin Helper
# Translated:  लो _ जिन सहायक
# Original:  प्रवेश सहायक
# ------------------------------
# 62
# English: Select All
# Translated:  सभी का चयन करें
# Original:  सभी चुनें
# ------------------------------
# 63
# English: _ Selection
# Translated:  _ चयन
# Original:  चयन (_ S)
# ------------------------------
# 64
# English: St _ reamable Content
# Translated:  St _ reamable सामग्री
# Original:  प्रवाहित करनेयोग्य विषयवस्तु
# ------------------------------
# 65
# English: Selected columns
# Translated:  चयनित स्तंभ
# Original:  चुने गए स्तंभ
# ------------------------------
# 66
# English: Selected rows
# Translated:  चयनित पंक्तियाँ
# Original:  चुनी गई पंक्तियां
# ------------------------------
# 67
# English: Columns
# Translated:  स्तंभ
# Original:  स्तंभ
# ------------------------------
# 68
# English: Rows
# Translated:  पंक्तियाँ
# Original:  पंक्तियां
# ------------------------------
# 69
# English: Table Information
# Translated:  तालिका की जानकारी
# Original:  & lt; bgt; सारणी सूचनाlt;/bgt;
# ------------------------------
# 70
# English: name (x, y)
# Translated:  नाम (x, y)
# Original:  नाम (x, y)
# ------------------------------
# 71
# English: Header:
# Translated:  शीर्षक:
# Original:  शीर्षकः
# ------------------------------
# 72
# English: Extents:
# Translated:  विस्तारः
# Original:  विस्तारः
# ------------------------------
# 73
# English: Row
# Translated:  पंक्ति
# Original:  पंक्ति
# ------------------------------
# 74
# English: Column
# Translated:  स्तंभ
# Original:  स्तंभ
# ------------------------------
# 75
# English: Selected Cell
# Translated:  चयनित सेल
# Original:  & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# ------------------------------
# 76
# English: _ Table
# Translated:  तालिका
# Original:  सारणी (_ T)
# ------------------------------
# 77
# English: Offset
# Translated:  ऑफसेट
# Original:  ओफसेट
# ------------------------------
# 78
# English: Include defaults
# Translated:  डिफ़ॉल्ट को शामिल करें
# Original:  डिफोल्टों को शामिल करें
# ------------------------------
# 79
# English: Te _ xt
# Translated:  ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ्
# Original:  पाठ (_ x)
# ------------------------------
# 80
# English: Current value
# Translated:  वर्तमान मूल्य
# Original:  मौजूदा मान
# ------------------------------
# 81
# English: Minimum increment
# Translated:  न्यूनतम वृद्धि
# Original:  न्यूनतम वृद्धि
# ------------------------------
# 82
# English: Maximum value
# Translated:  अधिकतम मूल्य
# Original:  अधिकतम मान
# ------------------------------
# 83
# English: Minimum value
# Translated:  न्यूनतम मूल्य
# Original:  न्यूनतम मान
# ------------------------------
# 84
# English: Val _ ue
# Translated:  वॉल _ यूई
# Original:  मान
# ------------------------------
# 85
# English: Interface Viewer
# Translated:  इंटरफेस दर्शक
# Original:  अंतराफलक दर्शक
# ------------------------------
# 86
# English: Allows viewing of various interface properties
# Translated:  विभिन्न इंटरफ़ेस गुणों को देखने की अनुमति देता है
# Original:  अंतराफलक के विभिन्न गुणों को देखने देता है
# ------------------------------
# 87
# English: (not implemented)
# Translated:  (नहीं लागू किया गया)
# Original:  (क्रियान्वित नहीं हुआ है)
# ------------------------------
# 88
# English: Name
# Translated:  नाम
# Original:  नाम
# ------------------------------
# 89
# English: URI
# Translated:  यूआरआई
# Original:  यूआरआई
# ------------------------------
# 90
# English: Start
# Translated:  शुरू करें
# Original:  प्रारंभ
# ------------------------------
# 91
# English: End
# Translated:  अंत
# Original:  अंत
# ------------------------------
# 92
# English: Too many selectable children
# Translated:  बहुत से चयन योग्य बच्चे
# Original:  बहुत अधिक चयनीय शिशु हैं
# ------------------------------
# 93
# English: Quick Select
# Translated:  त्वरित चयन
# Original:  तेज चुनाव
# ------------------------------
# 94
# English: Plugin with various methods of selecting accessibles quickly.
# Translated:  जल्दी से सुलभ वस्तुओं का चयन करने के विभिन्न तरीकों के साथ प्लगइन।
# Original:  प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# ------------------------------
# 95
# English: Inspect last focused accessible
# Translated:  निरीक्षण अंतिम केंद्रित सुलभ
# Original:  अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# ------------------------------
# 96
# English: Inspect accessible under mouse
# Translated:  माउस के तहत सुलभ निरीक्षण
# Original:  माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# ------------------------------
# 97
# English: Native
# Translated:  मूल
# Original:  वतनी
# ------------------------------
# 98
# English: Dogtail
# Translated:  कुत्ता
# Original:  श्वानपुच्छ
# ------------------------------
# 99
# English: LDTP
# Translated:  एलडीटीपी
# Original:  एलडीटीपी
# ------------------------------
# 100
# English: Script Type
# Translated:  स्क्रिप्ट प्रकार
# Original:  लिपि प्रकार
# ------------------------------
# 101
# English: Script Recorder
# Translated:  स्क्रिप्ट रिकॉर्डर
# Original:  लिपि रेकोर्डर
# ------------------------------
# 102
# English: Creates dogtail style scripts
# Translated:  कुत्ते के शैली स्क्रिप्ट बनाता है
# Original:  श्वानपुच्छ शैली की लिपियां निर्मित करता है
# ------------------------------
# 103
# English: The current script will be lost.
# Translated:  वर्तमान पटकथा खो जाएगी।
# Original:  वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
# ------------------------------
# 104
# English: Confirm clear
# Translated:  स्पष्ट पुष्टि करें
# Original:  मिटाने की पुष्टि करें
# ------------------------------
# 105
# English: Sche _ ma:
# Translated:  स्केच _ मा:
# Original:  स्कीमाः
# ------------------------------
# 106
# English: V _ alidate
# Translated:  V _ alidate
# Original:  सत्यापन
# ------------------------------
# 107
# English: Idle
# Translated:  निष्क्रिय
# Original:  खाली
# ------------------------------
# 108
# English: No description
# Translated:  कोई विवरण नहीं
# Original:  कोई विवरण नहीं
# ------------------------------
# 109
# English: AT - SPI Validator
# Translated:  एटी - एसपीआई सत्यापनकर्ता
# Original:  एटी-एसपीआई सत्यापक
# ------------------------------
# 110
# English: Validates application accessibility
# Translated:  आवेदन की पहुंच को मान्य करता है
# Original:  अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# ------------------------------
# 111
# English: Level
# Translated:  स्तर
# Original:  स्तर
# ------------------------------
# 112
# English: Role
# Translated:  भूमिका
# Original:  भूमिका
# ------------------------------
# 113
# English: Saving
# Translated:  बचत
# Original:  सहेज रहे हैं
# ------------------------------
# 114
# English: Validating
# Translated:  सत्यापन
# Original:  पुष्टि कर रहे हैं
# ------------------------------
# 115
# English: EXCEPT
# Translated:  अपवाद
# Original:  अपवाद
# ------------------------------
# 116
# English: ERROR
# Translated:  त्रुटि
# Original:  त्रुटि
# ------------------------------
# 117
# English: WARN
# Translated:  चेतावनी
# Original:  चेतावनी
# ------------------------------
# 118
# English: INFO
# Translated:  सूचना
# Original:  सूचना
# ------------------------------
# 119
# English: DEBUG
# Translated:  डीईबीयूजी
# Original:  दोषमुक्त करें
# ------------------------------
# 120
# English: Basic
# Translated:  मूल
# Original:  मूल
# ------------------------------
# 121
# English: Tests fundamental GUI application accessibility
# Translated:  बुनियादी जीयूआई अनुप्रयोगों की पहुंच का परीक्षण
# Original:  मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# ------------------------------
# 122
# English: actionable% s is not focusable or selectable
# Translated:  निष्पादित करने योग्य% s फोकस या चयन योग्य नहीं है
# Original:  % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# ------------------------------
# 123
# English: interactive% s is not actionable
# Translated:  इंटरैक्टिव% s को निष्पादित नहीं किया जा सकता है
# Original:  अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# ------------------------------
# 124
# English: more than one focused widget
# Translated:  एक से अधिक फोकस विगेट
# Original:  एक से अधिक विडजेट फोकस में है
# ------------------------------
# 125
# English: % s has no text interface
# Translated:  % s में कोई पाठ इंटरफ़ेस नहीं है
# Original:  % s का कोई पाठ अंतराफलक नहीं है
# ------------------------------
# 126
# English: % s index in parent does not match child index
# Translated:  माता-पिता में % s सूचकांक बच्चे सूचकांक से मेल नहीं खाता
# Original:  अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# ------------------------------
# 127
# English: Missing reciprocal for% s relation
# Translated:  %s संबंध के लिए पारस्परिक अनुपस्थित
# Original:  % s संबंध के लिए अन्योन्य गायब है
# ------------------------------
# 128
# English: % s missing name or label
# Translated:  % s नाम या लेबल गायब
# Original:  % s गायब नाम या सूचक
# ------------------------------
# 129
# English: focusable% s has table interface, no selection interface
# Translated:  फोकस करने योग्य% s में तालिका इंटरफ़ेस है, कोई चयन इंटरफ़ेस नहीं है
# Original:  फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# ------------------------------
# 130
# English: % s has% s state without% s state
# Translated:  % s में% s स्टेटस के बिना% s स्टेटस है
# Original:  % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# ------------------------------
# 131
# English: % s does not belong to a set
# Translated:  % s किसी सेट से संबंधित नहीं है
# Original:  % s किसी समुच्चय का सदस्य नहीं है
# ------------------------------
# 132
# English: % (rolename) s index% (num) d does not match row and column
# Translated:  % (रोल नाम) का सूचकांक% (संख्या) d पंक्ति और स्तंभ से मेल नहीं खाता
# Original:  % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# ------------------------------
# 133
# English: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# Translated:  % (रोलनाम) का मूल सूचकांक% (संख्या1) d पंक्ति और स्तंभ सूचकांक% (संख्या2) d से मेल नहीं खाता
# Original:  % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# ------------------------------
# 134
# English: % s has no name or description
# Translated:  % s का कोई नाम या विवरण नहीं है
# Original:  % s का कोई नाम या विवरण नहीं
# ------------------------------
# 135
# English: _ Preferences...
# Translated:  - प्राथमिकताएं...
# Original:  पसंद (_ P)...
# ------------------------------
# 136
# English: _ Contents
# Translated:  सामग्री
# Original:  विषय सूची (_ C)
# ------------------------------
# 137
# English: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# Translated:  Accerciser आपके डेस्कटॉप पर एप्लिकेशन नहीं देख सका. इस समस्या को ठीक करने के लिए आपको डेस्कटॉप एक्सेसबिलिटी को सक्षम करना होगा. क्या आप इसे अभी सक्षम करना चाहते हैं?
# Original:  एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# ------------------------------
# 138
# English: Note: Changes only take effect after logout.
# Translated:  नोटः परिवर्तन केवल लॉग आउट के बाद ही प्रभावी होते हैं।
# Original:  टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# ------------------------------
# 139
# English: Children
# Translated:  बच्चे
# Original:  शिशु
# ------------------------------
# 140
# English: _ Refresh Registry
# Translated:  _ ताज़ा करने की सूची
# Original:  पंजी ताजा करें (_ R)
# ------------------------------
# 141
# English: Refresh all
# Translated:  सबको ताज़ा करें
# Original:  सभी को ताजा करें
# ------------------------------
# 142
# English: Refresh _ Node
# Translated:  रिफ्रेश _ नोड
# Original:  आसंधि (नोड) को ताजा करें (_ N)
# ------------------------------
# 143
# English: Refresh selected node 's children
# Translated:  चयनित नोड के बच्चों को ताज़ा करें
# Original:  चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# ------------------------------
# 144
# English: Component
# Translated:  घटक
# Original:  घटक
# ------------------------------
# 145
# English: Task
# Translated:  कार्य
# Original:  कार्य
# ------------------------------
# 146
# English: Key
# Translated:  कुंजी
# Original:  कुंजी
# ------------------------------
# 147
# English: Alt
# Translated:  अल्ट
# Original:  आल्ट
# ------------------------------
# 148
# English: Ctrl
# Translated:  Ctrl
# Original:  कंट्रोल
# ------------------------------
# 149
# English: Shift
# Translated:  शिफ्ट
# Original:  शिफ्ट
# ------------------------------
# 150
# English: Top panel
# Translated:  शीर्ष पैनल
# Original:  ऊपरी पटल
# ------------------------------
# 151
# English: Bottom panel
# Translated:  नीचे पैनल
# Original:  निचला पटल
# ------------------------------
# 152
# English: accerciser Preferences
# Translated:  अधिग्रहणकर्ता प्राथमिकताएँ
# Original:  एक्सेर्साइसर पसंद
# ------------------------------
# 153
# English: Plugins
# Translated:  प्लगइन्स
# Original:  प्लगइन्स
# ------------------------------
# 154
# English: Global Hotkeys
# Translated:  वैश्विक हॉटकीज़
# Original:  सार्वत्रिक फटाफट कुंजियां
# ------------------------------
# 155
# English: Highlighting
# Translated:  प्रकाशना
# Original:  हाइलाइटन
# ------------------------------
# 156
# English: Highlight duration:
# Translated:  प्रकाश अवधिः
# Original:  हाइलाइट अवधिः
# ------------------------------
# 157
# English: Border color:
# Translated:  सीमा रंगः
# Original:  सीमांत रंगः
# ------------------------------
# 158
# English: The border color of the highlight box
# Translated:  हाइलाइट बॉक्स का सीमा रंग
# Original:  हाइलाइट बक्से का सीमांत रंग
# ------------------------------
# 159
# English: Fill color:
# Translated:  भरने का रंगः
# Original:  भराई का रंगः
# ------------------------------
# 160
# English: The fill color of the highlight box
# Translated:  हाइलाइट बॉक्स का भरने का रंग
# Original:  हाइलाइट बक्से का भराई रंग
# ------------------------------
# 161
# English: translator - credits
# Translated:  अनुवादक - क्रेडिट
# Original:  रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# ------------------------------
# 162
# English: An interactive Python accessibility explorer
# Translated:  एक इंटरैक्टिव पायथन पहुंच खोजक
# Original:  एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# ------------------------------
# 163
# English: accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# Translated:  accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# Original:  एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
# ------------------------------
# 164
# English: The New BSD License See the COPYING and NOTICE files for details.
# Translated:  नया बीएसडी लाइसेंस विवरण के लिए कॉपीइंग और नोटिस फाइलें देखें।
# Original:  नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# ------------------------------
# 165
# English: Web site
# Translated:  वेबसाइट
# Original:  जाल स्थल
# ------------------------------
# 166
# English: _ Add Bookmark...
# Translated:  _ बुकमार्क जोड़ें ...
# Original:  पसंद जोड़ें... (_ A)
# ------------------------------
# 167
# English: Bookmark selected accessible.
# Translated:  बुकमार्क चयनित सुलभ।
# Original:  चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# ------------------------------
# 168
# English: _ Edit Bookmarks...
# Translated:  _ संपादित करें बुकमार्क...
# Original:  पुस्तक चिह्न संपादित करें (_ E)...
# ------------------------------
# 169
# English: Manage bookmarks.
# Translated:  बुकमार्क प्रबंधित करें।
# Original:  पुस्तक-चिह्नों को प्रबंधित करें।
# ------------------------------
# 170
# English: Edit Bookmarks...
# Translated:  संपादित करें बुकमार्क...
# Original:  पुस्तक चिह्नों को संपादित करें...
# ------------------------------
# 171
# English: Title
# Translated:  शीर्षक
# Original:  शीर्षक
# ------------------------------
# 172
# English: Application
# Translated:  आवेदन
# Original:  अनुप्रयोग
# ------------------------------
# 173
# English: Path
# Translated:  मार्ग
# Original:  पथ
# ------------------------------
# 174
# English: Add Bookmark...
# Translated:  बुकमार्क जोड़ें ...
# Original:  पुस्तक-चिह्न जोड़ें...
# ------------------------------
# 175
# English: Title:
# Translated:  शीर्षक:
# Original:  शीर्षकः
# ------------------------------
# 176
# English: Application:
# Translated:  आवेदनः
# Original:  अनुप्रयोगः
# ------------------------------
# 177
# English: Path:
# Translated:  पथ:
# Original:  पथः
# ------------------------------
# 178
# English: Plugin Errors
# Translated:  प्लगइन त्रुटियाँ
# Original:  प्लग-इन त्रुटियां
# ------------------------------
# 179
# English: View
# Translated:  दृश्य
# Original:  दृश्य
# ------------------------------
# 180
# English: No view
# Translated:  कोई दृश्य नहीं
# Original:  कोई दृश्य नहीं है
# ------------------------------
# 181
# English: _ Single plugins view
# Translated:  एकल प्लगइन दृश्य
# Original:  एकल प्लग-इन दृश्य
# ------------------------------
# 182
# English: Plugin View
# Translated:  प्लगइन दृश्य
# Original:  प्लग-इन दृश्य
# ------------------------------
# 183
# English: Plugin View (% d)
# Translated:  प्लगइन दृश्य (% d)
# Original:  प्लग-इन दृश्य (% d)
# ------------------------------
# 184
# English: _ New view...
# Translated:  - नया दृश्य...
# Original:  नया दृश्य...
# ------------------------------
# 185
# English: New View...
# Translated:  नया दृश्य...
# Original:  नया दृश्य...
# ------------------------------
# 186
# English: _ File
# Translated:  फ़ाइल
# Original:  फाइल (F)
# ------------------------------
# 187
# English: _ Edit
# Translated:  _ सम्पादन
# Original:  संपादित करें
# ------------------------------
# 188
# English: _ Bookmarks
# Translated:  _ बुकमार्क
# Original:  पुस्तक-चिह्न संपादित करें (_ E)...
# ------------------------------
# 189
# English: _ View
# Translated:  दृश्य
# Original:  दृश्य _ (V)
# ------------------------------
# 190
# English: _ Help
# Translated:  _ सहायता
# Original:  मदद
# ------------------------------
# 191
# English: Full name
# Translated:  पूरा नाम
# Original:  पूरा नाम
# ------------------------------
# 192
# English: Key binding
# Translated:  कुंजी बंधन
# Original:  कुंजी बंधन
# ------------------------------
# 193
# English: Content type
# Translated:  सामग्री का प्रकार
# Original:  विषय प्रकार
# ------------------------------
# 194
# English: Give your application an accessibility workout
# Translated:  अपने आवेदन को सुलभता प्रशिक्षण दें
# Original:  अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# ------------------------------
# 195
# English: Accerciser Accessibility Explorer
# Translated:  एक्सरसाइज़र एक्सेसिबिलिटी एक्सप्लोरर
# Original:  एक्सेर्साइसर पहुंचनीयता अन्वेषक
# ------------------------------
# 196
# English: The default plugin layout for the bottom panel
# Translated:  नीचे पैनल के लिए डिफ़ॉल्ट प्लगइन लेआउट
# Original:  निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# ------------------------------
# 197
# English: The default plugin layout for the top panel
# Translated:  शीर्ष पैनल के लिए डिफ़ॉल्ट प्लगइन लेआउट
# Original:  ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# ------------------------------
# 198
# English: A list of plugins that are disabled by default
# Translated:  प्लगइन्स की सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
# Original:  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# ------------------------------
# 199
# English: Highlight duration
# Translated:  हाइलाइट अवधि
# Original:  अवधि को हाइलाइट रकें
# ------------------------------
# 200
# English: The duration of the highlight box when selecting accessible nodes
# Translated:  सुलभ नोड्स का चयन करते समय हाइलाइट बॉक्स की अवधि
# Original:  पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# ------------------------------
# 201
# English: Highlight border color
# Translated:  सीमा रंग को हाइलाइट करें
# Original:  सीमांत (बोर्डर) के रंग को हाइलाइट करें
# ------------------------------
# 202
# English: The color and opacity of the highlight border.
# Translated:  प्रकाश सीमा का रंग और अस्पष्टता।
# Original:  हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# ------------------------------
# 203
# English: Highlight fill color
# Translated:  भरने का रंग हाइलाइट करें
# Original:  भराई के रंग को हाइलाइट करें
# ------------------------------
# 204
# English: The color and opacity of the highlight fill.
# Translated:  हाइलाइट भरने का रंग और अस्पष्टता।
# Original:  हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# ------------------------------
# 205
# English: API Browser
# Translated:  एपीआई ब्राउज़र
# Original:  एपीआई विचरक
# ------------------------------
# 206
# English: Browse the various methods of the current accessible
# Translated:  वर्तमान उपलब्ध की विभिन्न विधियों ब्राउज़ करें
# Original:  इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# ------------------------------
# 207
# English: Hide private attributes
# Translated:  निजी गुणों को छिपाएँ
# Original:  निजी गुणों को छिपाएं
# ------------------------------
# 208
# English: Method
# Translated:  विधि
# Original:  विधि
# ------------------------------
# 209
# English: Property
# Translated:  संपत्ति
# Original:  गुणधर्म
# ------------------------------
# 210
# English: Value
# Translated:  मूल्य
# Original:  मान
# ------------------------------
# 211
# English: IPython Console
# Translated:  आइपयथन कंसोल
# Original:  आईपाइथन कन्सोल
# ------------------------------
# 212
# English: Interactive console for manipulating currently selected accessible
# Translated:  वर्तमान में चयनित सुलभ के लिए हेरफेर के लिए इंटरैक्टिव कंसोल
# Original:  इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# ------------------------------
# 213
# English: Event monitor
# Translated:  घटना मॉनिटर
# Original:  घटना मानिटर
# ------------------------------
# 214
# English: _ Monitor Events
# Translated:  _ घटनाओं की निगरानी
# Original:  घटनाओं को मानिटर करें (_ M)
# ------------------------------
# 215
# English: C _ lear Selection
# Translated:  C _ lear चयन
# Original:  चुनाव को हटाएं (C _)
# ------------------------------
# 216
# English: Everything
# Translated:  सब कुछ
# Original:  सभी
# ------------------------------
# 217
# English: Selected application
# Translated:  चयनित आवेदन
# Original:  चुने गए अनुप्रयोग
# ------------------------------
# 218
# English: Selected accessible
# Translated:  चयनित सुलभ
# Original:  चुने गए एक्सेसेबेल
# ------------------------------
# 219
# English: Source
# Translated:  स्रोत
# Original:  स्रोत
# ------------------------------
# 220
# English: Event Monitor
# Translated:  घटना मॉनिटर
# Original:  घटना मानिटर
# ------------------------------
# 221
# English: Shows events as they occur from selected types and sources
# Translated:  घटनाओं को प्रदर्शित करता है जैसे वे चयनित प्रकारों और स्रोतों से होती हैं
# Original:  चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# ------------------------------
# 222
# English: Highlight last event entry
# Translated:  अंतिम घटना प्रविष्टि को हाइलाइट करें
# Original:  अंतिम प्रविष्ट घटना को हाइलाइट करो
# ------------------------------
# 223
# English: Start / stop event recording
# Translated:  प्रारंभ / रोक घटना रिकॉर्डिंग
# Original:  घटना रेकोर्डिंग शुरू करो/रोको
# ------------------------------
# 224
# English: Clear event log
# Translated:  घटना लॉग स्पष्ट
# Original:  घटना रोजनामचा मिटाओ
# ------------------------------
# 225
# English: (no description)
# Translated:  (कोई विवरण नहीं)
# Original:  कोई विवरण नहीं
# ------------------------------
# 226
# English: Description
# Translated:  विवरण
# Original:  वर्णन
# ------------------------------
# 227
# English: Show
# Translated:  दिखाएँ
# Original:  दिखाएं
# ------------------------------
# 228
# English: _ Accessible
# Translated:  _ पहुँच योग्य
# Original:  पहुंचनीय
# ------------------------------
# 229
# English: Perform action
# Translated:  कार्य करें
# Original:  कार्रवाई संपन्न करें
# ------------------------------
# 230
# English: Acti _ on
# Translated:  एक्टि _ ऑन
# Original:  कार्रवाई (_ o)
# ------------------------------
# 231
# English: ID
# Translated:  पहचान पत्र
# Original:  आईडी
# ------------------------------
# 232
# English: Toolkit
# Translated:  उपकरण
# Original:  औजार बक्सा
# ------------------------------
# 233
# English: Version
# Translated:  संस्करण
# Original:  संस्करण
# ------------------------------
# 234
# English: Ap _ plication
# Translated:  एप्लिकेशन
# Original:  अनुप्रयोग
# ------------------------------
# 235
# English: Col _ lection
# Translated:  क _ लक्शन
# Original:  संग्रह
# ------------------------------
# 236
# English: 0, 0
# Translated:  0
# Original:  0, 0
# ------------------------------
# 237
# English: Relative position
# Translated:  सापेक्ष स्थिति
# Original:  सापेक्ष स्थिति
# ------------------------------
# 238
# English: Size
# Translated:  आकार
# Original:  आकार
# ------------------------------
# 239
# English: WIDGET
# Translated:  विडगेट
# Original:  विडजेट
# ------------------------------
# 240
# English: Layer
# Translated:  परत
# Original:  स्तर
# ------------------------------
# 241
# English: MDI - Z - order
# Translated:  एमडीआई - जेड - क्रम
# Original:  एमडीआई-जेड-क्रम
# ------------------------------
# 242
# English: Alpha
# Translated:  अल्फा
# Original:  अल्फा
# ------------------------------
# 243
# English: Absolute position
# Translated:  पूर्ण स्थिति
# Original:  निरपेक्ष स्थिति
# ------------------------------
# 244
# English: Co _ mponent
# Translated:  सह-संरक्षण
# Original:  घटक
# ------------------------------
# 245
# English: Des _ ktop
# Translated:  शीर्ष पर
# Original:  डेस्कटोप
# ------------------------------
# 246
# English: Locale:
# Translated:  स्थानीय:
# Original:  स्थान-विशिष्टः
# ------------------------------
# 247
# English: _ Document
# Translated:  दस्तावेज़
# Original:  प्रलेख
# ------------------------------
# 248
# English: Hyperlink
# Translated:  हाइपरलिंक
# Original:  हाइपरकड़ी
# ------------------------------
# 249
# English: H _ ypertext
# Translated:  H _ ypertext
# Original:  हाइपरपाठ
# ------------------------------
# 250
# English: Position
# Translated:  स्थिति
# Original:  स्थिति
# ------------------------------
# 251
# English: Description
# Translated:  विवरण
# Original:  वर्णन
# ------------------------------
# 252
# English: Locale
# Translated:  स्थानीय
# Original:  स्थान-विशिष्ट
# ------------------------------
# 253
# English: _ Image
# Translated:  छवि
# Original:  छवि (_ I)
# ------------------------------
# 254
# English: Lo _ gin Helper
# Translated:  लो _ जिन सहायक
# Original:  प्रवेश सहायक
# ------------------------------
# 255
# English: Select All
# Translated:  सभी का चयन करें
# Original:  सभी चुनें
# ------------------------------
# 256
# English: _ Selection
# Translated:  _ चयन
# Original:  चयन (_ S)
# ------------------------------
# 257
# English: St _ reamable Content
# Translated:  St _ reamable सामग्री
# Original:  प्रवाहित करनेयोग्य विषयवस्तु
# ------------------------------
# 258
# English: Selected columns
# Translated:  चयनित स्तंभ
# Original:  चुने गए स्तंभ
# ------------------------------
# 259
# English: Selected rows
# Translated:  चयनित पंक्तियाँ
# Original:  चुनी गई पंक्तियां
# ------------------------------
# 260
# English: Columns
# Translated:  स्तंभ
# Original:  स्तंभ
# ------------------------------
# 261
# English: Rows
# Translated:  पंक्तियाँ
# Original:  पंक्तियां
# ------------------------------
# 262
# English: Table Information
# Translated:  तालिका की जानकारी
# Original:  & lt; bgt; सारणी सूचनाlt;/bgt;
# ------------------------------
# 263
# English: name (x, y)
# Translated:  नाम (x, y)
# Original:  नाम (x, y)
# ------------------------------
# 264
# English: Header:
# Translated:  शीर्षक:
# Original:  शीर्षकः
# ------------------------------
# 265
# English: Extents:
# Translated:  विस्तारः
# Original:  विस्तारः
# ------------------------------
# 266
# English: Row
# Translated:  पंक्ति
# Original:  पंक्ति
# ------------------------------
# 267
# English: Column
# Translated:  स्तंभ
# Original:  स्तंभ
# ------------------------------
# 268
# English: Selected Cell
# Translated:  चयनित सेल
# Original:  & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# ------------------------------
# 269
# English: _ Table
# Translated:  तालिका
# Original:  सारणी (_ T)
# ------------------------------
# 270
# English: Offset
# Translated:  ऑफसेट
# Original:  ओफसेट
# ------------------------------
# 271
# English: Include defaults
# Translated:  डिफ़ॉल्ट को शामिल करें
# Original:  डिफोल्टों को शामिल करें
# ------------------------------
# 272
# English: Te _ xt
# Translated:  ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ्
# Original:  पाठ (_ x)
# ------------------------------
# 273
# English: Current value
# Translated:  वर्तमान मूल्य
# Original:  मौजूदा मान
# ------------------------------
# 274
# English: Minimum increment
# Translated:  न्यूनतम वृद्धि
# Original:  न्यूनतम वृद्धि
# ------------------------------
# 275
# English: Maximum value
# Translated:  अधिकतम मूल्य
# Original:  अधिकतम मान
# ------------------------------
# 276
# English: Minimum value
# Translated:  न्यूनतम मूल्य
# Original:  न्यूनतम मान
# ------------------------------
# 277
# English: Val _ ue
# Translated:  वॉल _ यूई
# Original:  मान
# ------------------------------
# 278
# English: Interface Viewer
# Translated:  इंटरफेस दर्शक
# Original:  अंतराफलक दर्शक
# ------------------------------
# 279
# English: Allows viewing of various interface properties
# Translated:  विभिन्न इंटरफ़ेस गुणों को देखने की अनुमति देता है
# Original:  अंतराफलक के विभिन्न गुणों को देखने देता है
# ------------------------------
# 280
# English: (not implemented)
# Translated:  (नहीं लागू किया गया)
# Original:  (क्रियान्वित नहीं हुआ है)
# ------------------------------
# 281
# English: Name
# Translated:  नाम
# Original:  नाम
# ------------------------------
# 282
# English: URI
# Translated:  यूआरआई
# Original:  यूआरआई
# ------------------------------
# 283
# English: Start
# Translated:  शुरू करें
# Original:  प्रारंभ
# ------------------------------
# 284
# English: End
# Translated:  अंत
# Original:  अंत
# ------------------------------
# 285
# English: Too many selectable children
# Translated:  बहुत से चयन योग्य बच्चे
# Original:  बहुत अधिक चयनीय शिशु हैं
# ------------------------------
# 286
# English: Quick Select
# Translated:  त्वरित चयन
# Original:  तेज चुनाव
# ------------------------------
# 287
# English: Plugin with various methods of selecting accessibles quickly.
# Translated:  जल्दी से सुलभ वस्तुओं का चयन करने के विभिन्न तरीकों के साथ प्लगइन।
# Original:  प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# ------------------------------
# 288
# English: Inspect last focused accessible
# Translated:  निरीक्षण अंतिम केंद्रित सुलभ
# Original:  अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# ------------------------------
# 289
# English: Inspect accessible under mouse
# Translated:  माउस के तहत सुलभ निरीक्षण
# Original:  माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# ------------------------------
# 290
# English: Native
# Translated:  मूल
# Original:  वतनी
# ------------------------------
# 291
# English: Dogtail
# Translated:  कुत्ता
# Original:  श्वानपुच्छ
# ------------------------------
# 292
# English: LDTP
# Translated:  एलडीटीपी
# Original:  एलडीटीपी
# ------------------------------
# 293
# English: Script Type
# Translated:  स्क्रिप्ट प्रकार
# Original:  लिपि प्रकार
# ------------------------------
# 294
# English: Script Recorder
# Translated:  स्क्रिप्ट रिकॉर्डर
# Original:  लिपि रेकोर्डर
# ------------------------------
# 295
# English: Creates dogtail style scripts
# Translated:  कुत्ते के शैली स्क्रिप्ट बनाता है
# Original:  श्वानपुच्छ शैली की लिपियां निर्मित करता है
# ------------------------------
# 296
# English: The current script will be lost.
# Translated:  वर्तमान पटकथा खो जाएगी।
# Original:  वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
# ------------------------------
# 297
# English: Confirm clear
# Translated:  स्पष्ट पुष्टि करें
# Original:  मिटाने की पुष्टि करें
# ------------------------------
# 298
# English: Sche _ ma:
# Translated:  स्केच _ मा:
# Original:  स्कीमाः
# ------------------------------
# 299
# English: V _ alidate
# Translated:  V _ alidate
# Original:  सत्यापन
# ------------------------------
# 300
# English: Idle
# Translated:  निष्क्रिय
# Original:  खाली
# ------------------------------
# 301
# English: No description
# Translated:  कोई विवरण नहीं
# Original:  कोई विवरण नहीं
# ------------------------------
# 302
# English: AT - SPI Validator
# Translated:  एटी - एसपीआई सत्यापनकर्ता
# Original:  एटी-एसपीआई सत्यापक
# ------------------------------
# 303
# English: Validates application accessibility
# Translated:  आवेदन की पहुंच को मान्य करता है
# Original:  अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# ------------------------------
# 304
# English: Level
# Translated:  स्तर
# Original:  स्तर
# ------------------------------
# 305
# English: Role
# Translated:  भूमिका
# Original:  भूमिका
# ------------------------------
# 306
# English: Saving
# Translated:  बचत
# Original:  सहेज रहे हैं
# ------------------------------
# 307
# English: Validating
# Translated:  सत्यापन
# Original:  पुष्टि कर रहे हैं
# ------------------------------
# 308
# English: EXCEPT
# Translated:  अपवाद
# Original:  अपवाद
# ------------------------------
# 309
# English: ERROR
# Translated:  त्रुटि
# Original:  त्रुटि
# ------------------------------
# 310
# English: WARN
# Translated:  चेतावनी
# Original:  चेतावनी
# ------------------------------
# 311
# English: INFO
# Translated:  सूचना
# Original:  सूचना
# ------------------------------
# 312
# English: DEBUG
# Translated:  डीईबीयूजी
# Original:  दोषमुक्त करें
# ------------------------------
# 313
# English: Basic
# Translated:  मूल
# Original:  मूल
# ------------------------------
# 314
# English: Tests fundamental GUI application accessibility
# Translated:  बुनियादी जीयूआई अनुप्रयोगों की पहुंच का परीक्षण
# Original:  मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# ------------------------------
# 315
# English: actionable% s is not focusable or selectable
# Translated:  निष्पादित करने योग्य% s फोकस या चयन योग्य नहीं है
# Original:  % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# ------------------------------
# 316
# English: interactive% s is not actionable
# Translated:  इंटरैक्टिव% s को निष्पादित नहीं किया जा सकता है
# Original:  अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# ------------------------------
# 317
# English: more than one focused widget
# Translated:  एक से अधिक फोकस विगेट
# Original:  एक से अधिक विडजेट फोकस में है
# ------------------------------
# 318
# English: % s has no text interface
# Translated:  % s में कोई पाठ इंटरफ़ेस नहीं है
# Original:  % s का कोई पाठ अंतराफलक नहीं है
# ------------------------------
# 319
# English: % s index in parent does not match child index
# Translated:  माता-पिता में % s सूचकांक बच्चे सूचकांक से मेल नहीं खाता
# Original:  अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# ------------------------------
# 320
# English: Missing reciprocal for% s relation
# Translated:  %s संबंध के लिए पारस्परिक अनुपस्थित
# Original:  % s संबंध के लिए अन्योन्य गायब है
# ------------------------------
# 321
# English: % s missing name or label
# Translated:  % s नाम या लेबल गायब
# Original:  % s गायब नाम या सूचक
# ------------------------------
# 322
# English: focusable% s has table interface, no selection interface
# Translated:  फोकस करने योग्य% s में तालिका इंटरफ़ेस है, कोई चयन इंटरफ़ेस नहीं है
# Original:  फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# ------------------------------
# 323
# English: % s has% s state without% s state
# Translated:  % s में% s स्टेटस के बिना% s स्टेटस है
# Original:  % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# ------------------------------
# 324
# English: % s does not belong to a set
# Translated:  % s किसी सेट से संबंधित नहीं है
# Original:  % s किसी समुच्चय का सदस्य नहीं है
# ------------------------------
# 325
# English: % (rolename) s index% (num) d does not match row and column
# Translated:  % (रोल नाम) का सूचकांक% (संख्या) d पंक्ति और स्तंभ से मेल नहीं खाता
# Original:  % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# ------------------------------
# 326
# English: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# Translated:  % (रोलनाम) का मूल सूचकांक% (संख्या1) d पंक्ति और स्तंभ सूचकांक% (संख्या2) d से मेल नहीं खाता
# Original:  % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# ------------------------------
# 327
# English: % s has no name or description
# Translated:  % s का कोई नाम या विवरण नहीं है
# Original:  % s का कोई नाम या विवरण नहीं
# ------------------------------
# 328
# English: _ Preferences...
# Translated:  - प्राथमिकताएं...
# Original:  पसंद (_ P)...
# ------------------------------
# 329
# English: _ Contents
# Translated:  सामग्री
# Original:  विषय सूची (_ C)
# ------------------------------
# 330
# English: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# Translated:  Accerciser आपके डेस्कटॉप पर एप्लिकेशन नहीं देख सका. इस समस्या को ठीक करने के लिए आपको डेस्कटॉप एक्सेसबिलिटी को सक्षम करना होगा. क्या आप इसे अभी सक्षम करना चाहते हैं?
# Original:  एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# ------------------------------
# 331
# English: Note: Changes only take effect after logout.
# Translated:  नोटः परिवर्तन केवल लॉग आउट के बाद ही प्रभावी होते हैं।
# Original:  टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# ------------------------------
# 332
# English: Children
# Translated:  बच्चे
# Original:  शिशु
# ------------------------------
# 333
# English: _ Refresh Registry
# Translated:  _ ताज़ा करने की सूची
# Original:  पंजी ताजा करें (_ R)
# ------------------------------
# 334
# English: Refresh all
# Translated:  सबको ताज़ा करें
# Original:  सभी को ताजा करें
# ------------------------------
# 335
# English: Refresh _ Node
# Translated:  रिफ्रेश _ नोड
# Original:  आसंधि (नोड) को ताजा करें (_ N)
# ------------------------------
# 336
# English: Refresh selected node 's children
# Translated:  चयनित नोड के बच्चों को ताज़ा करें
# Original:  चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# ------------------------------
# 337
# English: Component
# Translated:  घटक
# Original:  घटक
# ------------------------------
# 338
# English: Task
# Translated:  कार्य
# Original:  कार्य
# ------------------------------
# 339
# English: Key
# Translated:  कुंजी
# Original:  कुंजी
# ------------------------------
# 340
# English: Alt
# Translated:  अल्ट
# Original:  आल्ट
# ------------------------------
# 341
# English: Ctrl
# Translated:  Ctrl
# Original:  कंट्रोल
# ------------------------------
# 342
# English: Shift
# Translated:  शिफ्ट
# Original:  शिफ्ट
# ------------------------------
# 343
# English: Top panel
# Translated:  शीर्ष पैनल
# Original:  ऊपरी पटल
# ------------------------------
# 344
# English: Bottom panel
# Translated:  नीचे पैनल
# Original:  निचला पटल
# ------------------------------
# 345
# English: accerciser Preferences
# Translated:  अधिग्रहणकर्ता प्राथमिकताएँ
# Original:  एक्सेर्साइसर पसंद
# ------------------------------
# 346
# English: Plugins
# Translated:  प्लगइन्स
# Original:  प्लगइन्स
# ------------------------------
# 347
# English: Global Hotkeys
# Translated:  वैश्विक हॉटकीज़
# Original:  सार्वत्रिक फटाफट कुंजियां
# ------------------------------
# 348
# English: Highlighting
# Translated:  प्रकाशना
# Original:  हाइलाइटन
# ------------------------------
# 349
# English: Highlight duration:
# Translated:  प्रकाश अवधिः
# Original:  हाइलाइट अवधिः
# ------------------------------
# 350
# English: Border color:
# Translated:  सीमा रंगः
# Original:  सीमांत रंगः
# ------------------------------
# 351
# English: The border color of the highlight box
# Translated:  हाइलाइट बॉक्स का सीमा रंग
# Original:  हाइलाइट बक्से का सीमांत रंग
# ------------------------------
# 352
# English: Fill color:
# Translated:  भरने का रंगः
# Original:  भराई का रंगः
# ------------------------------
# 353
# English: The fill color of the highlight box
# Translated:  हाइलाइट बॉक्स का भरने का रंग
# Original:  हाइलाइट बक्से का भराई रंग
# ------------------------------
# 354
# English: translator - credits
# Translated:  अनुवादक - क्रेडिट
# Original:  रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# ------------------------------
# 355
# English: An interactive Python accessibility explorer
# Translated:  एक इंटरैक्टिव पायथन पहुंच खोजक
# Original:  एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# ------------------------------
# 356
# English: accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# Translated:  accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# Original:  एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
# ------------------------------
# 357
# English: The New BSD License See the COPYING and NOTICE files for details.
# Translated:  नया बीएसडी लाइसेंस विवरण के लिए कॉपीइंग और नोटिस फाइलें देखें।
# Original:  नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# ------------------------------
# 358
# English: Web site
# Translated:  वेबसाइट
# Original:  जाल स्थल
# ------------------------------
# 359
# English: _ Add Bookmark...
# Translated:  _ बुकमार्क जोड़ें ...
# Original:  पसंद जोड़ें... (_ A)
# ------------------------------
# 360
# English: Bookmark selected accessible.
# Translated:  बुकमार्क चयनित सुलभ।
# Original:  चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# ------------------------------
# 361
# English: _ Edit Bookmarks...
# Translated:  _ संपादित करें बुकमार्क...
# Original:  पुस्तक चिह्न संपादित करें (_ E)...
# ------------------------------
# 362
# English: Manage bookmarks.
# Translated:  बुकमार्क प्रबंधित करें।
# Original:  पुस्तक-चिह्नों को प्रबंधित करें।
# ------------------------------
# 363
# English: Edit Bookmarks...
# Translated:  संपादित करें बुकमार्क...
# Original:  पुस्तक चिह्नों को संपादित करें...
# ------------------------------
# 364
# English: Title
# Translated:  शीर्षक
# Original:  शीर्षक
# ------------------------------
# 365
# English: Application
# Translated:  आवेदन
# Original:  अनुप्रयोग
# ------------------------------
# 366
# English: Path
# Translated:  मार्ग
# Original:  पथ
# ------------------------------
# 367
# English: Add Bookmark...
# Translated:  बुकमार्क जोड़ें ...
# Original:  पुस्तक-चिह्न जोड़ें...
# ------------------------------
# 368
# English: Title:
# Translated:  शीर्षक:
# Original:  शीर्षकः
# ------------------------------
# 369
# English: Application:
# Translated:  आवेदनः
# Original:  अनुप्रयोगः
# ------------------------------
# 370
# English: Path:
# Translated:  पथ:
# Original:  पथः
# ------------------------------
# 371
# English: Plugin Errors
# Translated:  प्लगइन त्रुटियाँ
# Original:  प्लग-इन त्रुटियां
# ...
# Translated:  पाठ
# Original:  पाठ
# ------------------------------
# 884
# English: Offset
# Translated:  ऑफसेट
# Original:  ओफसेट
# ------------------------------
# 885
# English: Include defaults
# Translated:  डिफ़ॉल्ट को शामिल करें
# Original:  डिफोल्टों को शामिल करें
# ------------------------------
# 886
# English: Start: 0
# Translated:  प्रारंभः 0
# Original:  प्रारंभः 0
# ------------------------------
# 887
# English: End: 0
# Translated:  अंतः 0
# Original:  अंतः 0
# ------------------------------
# 888
# English: Te _ xt
# Translated:  ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ् ्
# Original:  पाठ (_ x)
# ------------------------------
# 889
# English: Current value
# Translated:  वर्तमान मूल्य
# Original:  मौजूदा मान
# ------------------------------
# 890
# English: Minimum increment
# Translated:  न्यूनतम वृद्धि
# Original:  न्यूनतम वृद्धि
# ------------------------------
# 891
# English: Maximum value
# Translated:  अधिकतम मूल्य
# Original:  अधिकतम मान
# ------------------------------
# 892
# English: Minimum value
# Translated:  न्यूनतम मूल्य
# Original:  न्यूनतम मान
# ------------------------------
# 893
# English: Val _ ue
# Translated:  वॉल _ यूई
# Original:  मान
# ------------------------------
# 894
# English: unknown
# Translated:  अज्ञात
# Original:  अज्ञात
# ------------------------------
# 895
# English: Interface Viewer
# Translated:  इंटरफेस दर्शक
# Original:  अंतराफलक दर्शक
# ------------------------------
# 896
# English: Allows viewing of various interface properties
# Translated:  विभिन्न इंटरफ़ेस गुणों को देखने की अनुमति देता है
# Original:  अंतराफलक के विभिन्न गुणों को देखने देता है
# ------------------------------
# 897
# English: (not implemented)
# Translated:  (नहीं लागू किया गया)
# Original:  (क्रियान्वित नहीं हुआ है)
# ------------------------------
# 898
# English: Name
# Translated:  नाम
# Original:  नाम
# ------------------------------
# 899
# English: URI
# Translated:  यूआरआई
# Original:  यूआरआई
# ------------------------------
# 900
# English: Start
# Translated:  शुरू करें
# Original:  प्रारंभ
# ------------------------------
# 901
# English: End
# Translated:  अंत
# Original:  अंत
# ------------------------------
# 902
# English: Too many selectable children
# Translated:  बहुत से चयन योग्य बच्चे
# Original:  बहुत अधिक चयनीय शिशु हैं
# ------------------------------
# 903
# English: (Editable)
# Translated:  (संपादित)
# Original:  (संशोधनीय)
# ------------------------------
# 904
# English: Quick Select
# Translated:  त्वरित चयन
# Original:  तेज चुनाव
# ------------------------------
# 905
# English: Plugin with various methods of selecting accessibles quickly.
# Translated:  जल्दी से सुलभ वस्तुओं का चयन करने के विभिन्न तरीकों के साथ प्लगइन।
# Original:  प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# ------------------------------
# 906
# English: Inspect last focused accessible
# Translated:  निरीक्षण अंतिम केंद्रित सुलभ
# Original:  अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# ------------------------------
# 907
# English: Inspect accessible under mouse
# Translated:  माउस के तहत सुलभ निरीक्षण
# Original:  माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# ------------------------------
# 908
# English: Sche _ ma:
# Translated:  स्केच _ मा:
# Original:  स्कीमाः
# ------------------------------
# 909
# English: V _ alidate
# Translated:  V _ alidate
# Original:  सत्यापन
# ------------------------------
# 910
# English: Idle
# Translated:  निष्क्रिय
# Original:  खाली
# ------------------------------
# 911
# English: No description
# Translated:  कोई विवरण नहीं
# Original:  कोई विवरण नहीं
# ------------------------------
# 912
# English: AT - SPI Validator
# Translated:  एटी - एसपीआई सत्यापनकर्ता
# Original:  एटी-एसपीआई सत्यापक
# ------------------------------
# 913
# English: Validates application accessibility
# Translated:  आवेदन की पहुंच को मान्य करता है
# Original:  अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# ------------------------------
# 914
# English: Level
# Translated:  स्तर
# Original:  स्तर
# ------------------------------
# 915
# English: Role
# Translated:  भूमिका
# Original:  भूमिका
# ------------------------------
# 916
# English: Saving
# Translated:  बचत
# Original:  सहेज रहे हैं
# ------------------------------
# 917
# English: Validating
# Translated:  सत्यापन
# Original:  पुष्टि कर रहे हैं
# ------------------------------
# 918
# English: EXCEPT
# Translated:  अपवाद
# Original:  अपवाद
# ------------------------------
# 919
# English: ERROR
# Translated:  त्रुटि
# Original:  त्रुटि
# ------------------------------
# 920
# English: WARN
# Translated:  चेतावनी
# Original:  चेतावनी
# ------------------------------
# 921
# English: INFO
# Translated:  सूचना
# Original:  सूचना
# ------------------------------
# 922
# English: DEBUG
# Translated:  डीईबीयूजी
# Original:  दोषमुक्त करें
# ------------------------------
# 923
# English: Basic
# Translated:  मूल
# Original:  मूल
# ------------------------------
# 924
# English: Tests fundamental GUI application accessibility
# Translated:  बुनियादी जीयूआई अनुप्रयोगों की पहुंच का परीक्षण
# Original:  मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# ------------------------------
# 925
# English: actionable% s is not focusable or selectable
# Translated:  निष्पादित करने योग्य% s फोकस या चयन योग्य नहीं है
# Original:  % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# ------------------------------
# 926
# English: interactive% s is not actionable
# Translated:  इंटरैक्टिव% s को निष्पादित नहीं किया जा सकता है
# Original:  अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# ------------------------------
# 927
# English: more than one focused widget
# Translated:  एक से अधिक फोकस विगेट
# Original:  एक से अधिक विडजेट फोकस में है
# ------------------------------
# 928
# English: % s has no text interface
# Translated:  % s में कोई पाठ इंटरफ़ेस नहीं है
# Original:  % s का कोई पाठ अंतराफलक नहीं है
# ------------------------------
# 929
# English: % s index in parent does not match child index
# Translated:  माता-पिता में % s सूचकांक बच्चे सूचकांक से मेल नहीं खाता
# Original:  अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# ------------------------------
# 930
# English: Missing reciprocal for% s relation
# Translated:  %s संबंध के लिए पारस्परिक अनुपस्थित
# Original:  % s संबंध के लिए अन्योन्य गायब है
# ------------------------------
# 931
# English: % s missing name or label
# Translated:  % s नाम या लेबल गायब
# Original:  % s गायब नाम या सूचक
# ------------------------------
# 932
# English: focusable% s has a table interface, but not a selection interface
# Translated:  फोकस करने योग्य% s में तालिका इंटरफ़ेस है, लेकिन चयन इंटरफ़ेस नहीं है
# Original:  फोकस योग्य% s में सारणी अंतराफलक है, लेकिन कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# ------------------------------
# 933
# English: % s has% s state without% s state
# Translated:  % s में% s स्टेटस के बिना% s स्टेटस है
# Original:  % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# ------------------------------
# 934
# English: % s does not belong to a set
# Translated:  % s किसी सेट से संबंधित नहीं है
# Original:  % s किसी समुच्चय का सदस्य नहीं है
# ------------------------------
# 935
# English: % (rolename) s index% (num) d does not match row and column
# Translated:  % (रोल नाम) का सूचकांक% (संख्या) d पंक्ति और स्तंभ से मेल नहीं खाता
# Original:  % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# ------------------------------
# 936
# English: % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# Translated:  % (रोलनाम) का मूल सूचकांक% (संख्या1) d पंक्ति और स्तंभ सूचकांक% (संख्या2) d से मेल नहीं खाता
# Original:  % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# ------------------------------
# 937
# English: % s has no name or description
# Translated:  % s का कोई नाम या विवरण नहीं है
# Original:  % s का कोई नाम या विवरण नहीं
# ------------------------------
# 938
# English: _ Preferences...
# Translated:  - प्राथमिकताएं...
# Original:  पसंद (_ P)...
# ------------------------------
# 939
# English: _ Contents
# Translated:  सामग्री
# Original:  विषय सूची (_ C)
# ------------------------------
# 940
# English: Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# Translated:  Accerciser आपके डेस्कटॉप पर एप्लिकेशन नहीं देख सका. इस समस्या को ठीक करने के लिए आपको डेस्कटॉप एक्सेसबिलिटी को सक्षम करना होगा. क्या आप इसे अभी सक्षम करना चाहते हैं?
# Original:  एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# ------------------------------
# 941
# English: Note: Changes only take effect after logout.
# Translated:  नोटः परिवर्तन केवल लॉग आउट के बाद ही प्रभावी होते हैं।
# Original:  टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# ------------------------------
# 942
# English: < dead >
# Translated:  < मृत >
# Original:  <dead>
# ------------------------------
# 943
# English: Children
# Translated:  बच्चे
# Original:  शिशु
# ------------------------------
# 944
# English: _ Hide / Show Applications without children
# Translated:  बिना बच्चों के _ छिपाएँ / दिखाएँ
# Original:  बच्चों के बिना अनुप्रयोग छिपाएँ/दिखाएँ (_ H)
# ------------------------------
# 945
# English: _ Refresh Registry
# Translated:  _ ताज़ा करने की सूची
# Original:  पंजी ताजा करें (_ R)
# ------------------------------
# 946
# English: Refresh all
# Translated:  सबको ताज़ा करें
# Original:  सभी को ताजा करें
# ------------------------------
# 947
# English: Refresh _ Node
# Translated:  रिफ्रेश _ नोड
# Original:  आसंधि (नोड) को ताजा करें (_ N)
# ------------------------------
# 948
# English: Refresh selected node 's children
# Translated:  चयनित नोड के बच्चों को ताज़ा करें
# Original:  चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# ------------------------------
# 949
# English: Component
# Translated:  घटक
# Original:  घटक
# ------------------------------
# 950
# English: Task
# Translated:  कार्य
# Original:  कार्य
# ------------------------------
# 951
# English: Key
# Translated:  कुंजी
# Original:  कुंजी
# ------------------------------
# 952
# English: Alt
# Translated:  अल्ट
# Original:  आल्ट
# ------------------------------
# 953
# English: Ctrl
# Translated:  Ctrl
# Original:  कंट्रोल
# ------------------------------
# 954
# English: Shift
# Translated:  शिफ्ट
# Original:  शिफ्ट
# ------------------------------
# 955
# English: Top panel
# Translated:  शीर्ष पैनल
# Original:  ऊपरी पटल
# ------------------------------
# 956
# English: Bottom panel
# Translated:  नीचे पैनल
# Original:  निचला पटल
# ------------------------------
# 957
# English: accerciser Preferences
# Translated:  अधिग्रहणकर्ता प्राथमिकताएँ
# Original:  एक्सेर्साइसर पसंद
# ------------------------------
# 958
# English: Plugins
# Translated:  प्लगइन्स
# Original:  प्लगइन्स
# ------------------------------
# 959
# English: Global Hotkeys
# Translated:  वैश्विक हॉटकीज़
# Original:  सार्वत्रिक फटाफट कुंजियां
# ------------------------------
# 960
# English: Highlighting
# Translated:  प्रकाशना
# Original:  हाइलाइटन
# ------------------------------
# 961
# English: Highlight duration:
# Translated:  प्रकाश अवधिः
# Original:  हाइलाइट अवधिः
# ------------------------------
# 962
# English: Border color:
# Translated:  सीमा रंगः
# Original:  सीमांत रंगः
# ------------------------------
# 963
# English: The border color of the highlight box
# Translated:  हाइलाइट बॉक्स का सीमा रंग
# Original:  हाइलाइट बक्से का सीमांत रंग
# ------------------------------
# 964
# English: Fill color:
# Translated:  भरने का रंगः
# Original:  भराई का रंगः
# ------------------------------
# 965
# English: The fill color of the highlight box
# Translated:  हाइलाइट बॉक्स का भरने का रंग
# Original:  हाइलाइट बक्से का भराई रंग
# ------------------------------
# 966
# English: translator - credits
# Translated:  अनुवादक - क्रेडिट
# Original:  रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# ------------------------------
# 967
# English: An interactive Python accessibility explorer
# Translated:  एक इंटरैक्टिव पायथन पहुंच खोजक
# Original:  एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# ------------------------------
# 968
# English: accerciser Copyright (c) 2006, 2007 IBM Corporation (BSD)
# Translated:  accerciser Copyright (c) 2006, 2007 IBM Corporation (BSD)
# Original:  एक्सेर्साइसर सर्वाधिकार (c) 2006,2007 आईबीएम निगम (बीएसडी)
# ------------------------------
# 969
# English: The New BSD License See the COPYING and NOTICE files for details.
# Translated:  नया बीएसडी लाइसेंस विवरण के लिए कॉपीइंग और नोटिस फाइलें देखें।
# Original:  नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# ------------------------------
# 970
# English: Web site
# Translated:  वेबसाइट
# Original:  जाल स्थल
# ------------------------------
# 971
# English: _ Add Bookmark...
# Translated:  _ बुकमार्क जोड़ें ...
# Original:  पसंद जोड़ें... (_ A)
# ------------------------------
# 972
# English: Bookmark selected accessible.
# Translated:  बुकमार्क चयनित सुलभ।
# Original:  चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# ------------------------------
# 973
# English: _ Edit Bookmarks...
# Translated:  _ संपादित करें बुकमार्क...
# Original:  पुस्तक चिह्न संपादित करें (_ E)...
# ------------------------------
# 974
# English: Manage bookmarks.
# Translated:  बुकमार्क प्रबंधित करें।
# Original:  पुस्तक-चिह्नों को प्रबंधित करें।
# ------------------------------
# 975
# English: Edit Bookmarks...
# Translated:  संपादित करें बुकमार्क...
# Original:  पुस्तक चिह्नों को संपादित करें...
# ------------------------------
# 976
# English: Title
# Translated:  शीर्षक
# Original:  शीर्षक
# ------------------------------
# 977
# English: Application
# Translated:  आवेदन
# Original:  अनुप्रयोग
# ------------------------------
# 978
# English: Path
# Translated:  मार्ग
# Original:  पथ
# ------------------------------
# 979
# English: Add Bookmark...
# Translated:  बुकमार्क जोड़ें ...
# Original:  पुस्तक-चिह्न जोड़ें...
# ------------------------------
# 980
# English: Title:
# Translated:  शीर्षक:
# Original:  शीर्षकः
# ------------------------------
# 981
# English: Application:
# Translated:  आवेदनः
# Original:  अनुप्रयोगः
# ------------------------------
# 982
# English: Path:
# Translated:  पथ:
# Original:  पथः
# ------------------------------
# 983
# English: Plugin Errors
# Translated:  प्लगइन त्रुटियाँ
# Original:  प्लग-इन त्रुटियांviewport
# ------------------------------
# 984
# English: View
# Translated:  दृश्य
# Original:  दृश्य
# ------------------------------
# 985
# English: No view
# Translated:  कोई दृश्य नहीं
# Original:  कोई दृश्य नहीं है
# ------------------------------
# 986
# English: _ Single plugins view
# Translated:  एकल प्लगइन दृश्य
# Original:  एकल प्लग-इन दृश्य
# ------------------------------
# 987
# English: Plugin View
# Translated:  प्लगइन दृश्य
# Original:  प्लग-इन दृश्य
# ------------------------------
# 988
# English: Plugin View (% d)
# Translated:  प्लगइन दृश्य (% d)
# Original:  प्लग-इन दृश्य (% d)
# ------------------------------
# 989
# English: _ New view...
# Translated:  - नया दृश्य...
# Original:  नया दृश्य... (_ N)
# ------------------------------
# 990
# English: New View...
# Translated:  नया दृश्य...
# Original:  नया दृश्य...
# ------------------------------
# 991
# English: _ File
# Translated:  फ़ाइल
# Original:  फाइल (F)
# ------------------------------
# 992
# English: _ Edit
# Translated:  _ सम्पादन
# Original:  संपादित करेंmenu
# ------------------------------
# 993
# English: _ Bookmarks
# Translated:  _ बुकमार्क
# Original:  पसंद (_ B) menu
# ------------------------------
# 994
# English: _ View
# Translated:  दृश्य
# Original:  दृश्य _ (V)
# ------------------------------
# 995
# English: _ Help
# Translated:  _ सहायता
# Original:  मदद
# ------------------------------
# 996
# English: Accerciser
# Translated:  एसरसिज़र
# Original:  एक्सेर्साइसर
# ------------------------------
# 997
# English: Give your application an accessibility workout
# Translated:  अपने आवेदन को सुलभता प्रशिक्षण दें
# Original:  अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# ------------------------------
# 998
# English: Accerciser Accessibility Explorer
# Translated:  एक्सरसाइज़र एक्सेसिबिलिटी एक्सप्लोरर
# Original:  एक्सेर्साइसर पहुंचनीयता अन्वेषक
# ------------------------------
# 999
# English: A list of plugins that are disabled by default
# Translated:  प्लगइन्स की सूची जो डिफ़ॉल्ट रूप से अक्षम हैं
# Original:  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# ------------------------------
# 1000
# English: A list of plugins that are disabled by default.
# Translated:  प्लगइन्स की सूची जो डिफ़ॉल्ट रूप से अक्षम हैं।
# Original:  उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# ------------------------------

# %%
comaparision = pd.DataFrame({'Original': english_sentences, 'Translated': translatedEngHin})
comaparision.to_csv('/content/IITB_Translated_EngHin.csv', index=False)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk
from nltk.translate.bleu_score import corpus_bleu

# %%
references = [[hindi] for hindi in hindi_sentences]  # Create reference list of lists
candidates = translatedEngHin  # Model translations

# %%
bleu_score = corpus_bleu(references, candidates)
print(f"BLEU score: {bleu_score:.4f}")
# Out:
# BLEU score: 0.4279
