# %%
# !pip install streamlit googletrans==4.0.0-rc1
# !pip install googletrans==3.1.0a0
# !pip install nltk
# !pip install transformers
# !pip install datasets transformers[sentencepiece] sacrebleu
from timeit import default_timer as timer
import streamlit as st
import googletrans
from googletrans import Translator
from google.colab import drive
import pandas as pd
import numpy as np
from datasets import load_dataset
import tensorflow as tf
import pandas as pd
import numpy as np
# Out:
# Collecting streamlit
#   Downloading streamlit-1.33.0-py2.py3-none-any.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 24.5 MB/s eta 0:00:00
# Collecting googletrans==4.0.0-rc1
#   Downloading googletrans-4.0.0rc1.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==4.0.0-rc1)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.2.2)
# Collecting hstspreload (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hstspreload-2024.4.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 15.4 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.5 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.8 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.0 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 3.5 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<25,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.11.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 15.6 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17395 sha256=13baa18072ea93a273db52c915089dd87208f045d5e6c2bc83f08f8ecd08fb51
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, watchdog, smmap, idna, hstspreload, h2, pydeck, httpcore, gitdb, httpx, gitpython, googletrans, streamlit
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# Successfully installed chardet-3.0.4 gitdb-4.0.11 gitpython-3.1.43 googletrans-4.0.0rc1 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.4.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 pydeck-0.8.1b0 rfc3986-1.5.0 smmap-5.0.1 streamlit-1.33.0 watchdog-4.0.0
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: httpx==0.13.3 in /usr/local/lib/python3.10/dist-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.2.2)
# Requirement already satisfied: hstspreload in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.4.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in /usr/local/lib/python3.10/dist-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /usr/local/lib/python3.10/dist-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16353 sha256=23d3d34e0c4176466256a6f8a00865c90fb9559a9920f5396791679204892d81
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: googletrans
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 4.0.0rc1
#     Uninstalling googletrans-4.0.0rc1:
#       Successfully uninstalled googletrans-4.0.0rc1
# Successfully installed googletrans-3.1.0a0
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.4.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (0.1.99)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from transformers[sentencepiece]) (3.20.3)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, portalocker, dill, colorama, sacrebleu, multiprocess, datasets
# Successfully installed colorama-0.4.6 datasets-2.18.0 dill-0.3.8 multiprocess-0.70.16 portalocker-2.8.2 sacrebleu-2.4.2 xxhash-3.4.1

# %%
print(googletrans.LANGUAGES)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'latin', 'lv': 'latvian', 'lt': 'lithuanian', 'lb': 'luxembourgish', 'mk': 'macedonian', 'mg': 'malagasy', 'ms': 'malay', 'ml': 'malayalam', 'mt': 'maltese', 'mi': 'maori', 'mr': 'marathi', 'mn': 'mongolian', 'my': 'myanmar (burmese)', 'ne': 'nepali', 'no': 'norwegian', 'or': 'odia', 'ps': 'pashto', 'fa': 'persian', 'pl': 'polish', 'pt': 'portuguese', 'pa': 'punjabi', 'ro': 'romanian', 'ru': 'russian', 'sm': 'samoan', 'gd': 'scots gaelic', 'sr': 'serbian', 'st': 'sesotho', 'sn': 'shona', 'sd': 'sindhi', 'si': 'sinhala', 'sk': 'slovak', 'sl': 'slovenian', 'so': 'somali', 'es': 'spanish', 'su': 'sundanese', 'sw': 'swahili', 'sv': 'swedish', 'tg': 'tajik', 'ta': 'tamil', 'te': 'telugu', 'th': 'thai', 'tr': 'turkish', 'uk': 'ukrainian', 'ur': 'urdu', 'ug': 'uyghur', 'uz': 'uzbek', 'vi': 'vietnamese', 'cy': 'welsh', 'xh': 'xhosa', 'yi': 'yiddish', 'yo': 'yoruba', 'zu': 'zulu'}

# %%
translator = Translator()

# Define dataset path
dataset_path = "cfilt/iitb-english-hindi"

# Load dataset from 800,000 to 1,200,000 lines
train_dataset = load_dataset(dataset_path, split="train[:1000]")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/3.14k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/953 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/190M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/85.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1659083 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/520 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2507 [00:00<?, ? examples/s]

# %%
english_sentences = [item['en'] for item in train_dataset['translation']]
hindi_sentences = [item['hi'] for item in train_dataset['translation']]

# %%
len(english_sentences)
# Out:
# 1000

# %%
start = timer()
translatedEngHin = []
for index, (eng, hin) in enumerate(zip(english_sentences, hindi_sentences)):
    print("Index:", index)
    print("Hindi:", hin)
    translated_hi = translator.translate(hin, src='hi', dest='en').text
    print("Translated: ", translated_hi)
    print("Original: ", eng)
    print("------------------------------")
    translatedEngHin.append(translated_hi)
end = timer()

print("Time taken:", end - start)
# Out:
# Streaming output truncated to the last 5000 lines.
# Hindi: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# Translated:  Give your app the benefit of accessibility exercises
# Original:  Give your application an accessibility workout
# ------------------------------
# Index: 1
# Hindi: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# Translated:  Accessizer Accessibility Explorer
# Original:  Accerciser Accessibility Explorer
# ------------------------------
# Index: 2
# Hindi: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# Translated:  Default plug-in template for bottom panel
# Original:  The default plugin layout for the bottom panel
# ------------------------------
# Index: 3
# Hindi: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# Translated:  Default plug-in template for the top panel
# Original:  The default plugin layout for the top panel
# ------------------------------
# Index: 4
# Hindi: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Translated:  List of plug-ins that are disabled by default
# Original:  A list of plugins that are disabled by default
# ------------------------------
# Index: 5
# Hindi: अवधि को हाइलाइट रकें
# Translated:  keep duration highlighted
# Original:  Highlight duration
# ------------------------------
# Index: 6
# Hindi: पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# Translated:  Duration of highlight boxes when selecting accessible nodes
# Original:  The duration of the highlight box when selecting accessible nodes
# ------------------------------
# Index: 7
# Hindi: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# Translated:  Highlight the border color
# Original:  Highlight border color
# ------------------------------
# Index: 8
# Hindi: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# Translated:  Color and opacity of the highlighted margin.
# Original:  The color and opacity of the highlight border.
# ------------------------------
# Index: 9
# Hindi: भराई के रंग को हाइलाइट करें
# Translated:  Highlight the fill color
# Original:  Highlight fill color
# ------------------------------
# Index: 10
# Hindi: हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# Translated:  Highlighted filling color and transparency.
# Original:  The color and opacity of the highlight fill.
# ------------------------------
# Index: 11
# Hindi: एपीआई विचरक
# Translated:  api thinker
# Original:  API Browser
# ------------------------------
# Index: 12
# Hindi: इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# Translated:  Explore various methods of what has been achieved at this time
# Original:  Browse the various methods of the current accessible
# ------------------------------
# Index: 13
# Hindi: निजी गुणों को छिपाएं
# Translated:  hide private properties
# Original:  Hide private attributes
# ------------------------------
# Index: 14
# Hindi: विधि
# Translated:  Method
# Original:  Method
# ------------------------------
# Index: 15
# Hindi: गुणधर्म
# Translated:  properties
# Original:  Property
# ------------------------------
# Index: 16
# Hindi: मान
# Translated:  Value
# Original:  Value
# ------------------------------
# Index: 17
# Hindi: आईपाइथन कन्सोल
# Translated:  ipython console
# Original:  IPython Console
# ------------------------------
# Index: 18
# Hindi: इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# Translated:  Interactive console for working with the currently selected accessible
# Original:  Interactive console for manipulating currently selected accessible
# ------------------------------
# Index: 19
# Hindi: घटना मानिटर
# Translated:  event monitor
# Original:  Event monitor
# ------------------------------
# Index: 20
# Hindi: घटनाओं को मानिटर करें (_ M)
# Translated:  Monitor events (_ M)
# Original:  _ Monitor Events
# ------------------------------
# Index: 21
# Hindi: चुनाव को हटाएं (C _)
# Translated:  Delete selection (C_)
# Original:  C _ lear Selection
# ------------------------------
# Index: 22
# Hindi: सभी
# Translated:  All
# Original:  Everything
# ------------------------------
# Index: 23
# Hindi: चुने गए अनुप्रयोग
# Translated:  Selected applications
# Original:  Selected application
# ------------------------------
# Index: 24
# Hindi: चुने गए एक्सेसेबेल
# Translated:  selected accessible
# Original:  Selected accessible
# ------------------------------
# Index: 25
# Hindi: स्रोत
# Translated:  Source
# Original:  Source
# ------------------------------
# Index: 26
# Hindi: घटना मानिटर
# Translated:  event monitor
# Original:  Event Monitor
# ------------------------------
# Index: 27
# Hindi: चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# Translated:  Shows events as they occur from selected types and sources
# Original:  Shows events as they occur from selected types and sources
# ------------------------------
# Index: 28
# Hindi: अंतिम प्रविष्ट घटना को हाइलाइट करो
# Translated:  Highlight last entered event
# Original:  Highlight last event entry
# ------------------------------
# Index: 29
# Hindi: घटना रेकोर्डिंग शुरू करो/रोको
# Translated:  Start/stop event recording
# Original:  Start / stop event recording
# ------------------------------
# Index: 30
# Hindi: घटना रोजनामचा मिटाओ
# Translated:  delete event log
# Original:  Clear event log
# ------------------------------
# Index: 31
# Hindi: कोई विवरण नहीं
# Translated:  no description
# Original:  (no description)
# ------------------------------
# Index: 32
# Hindi: वर्णन
# Translated:  Description
# Original:  Description
# ------------------------------
# Index: 33
# Hindi: दिखाएं
# Translated:  Show
# Original:  Show
# ------------------------------
# Index: 34
# Hindi: पहुंचनीय
# Translated:  reachable
# Original:  _ Accessible
# ------------------------------
# Index: 35
# Hindi: कार्रवाई संपन्न करें
# Translated:  complete the action
# Original:  Perform action
# ------------------------------
# Index: 36
# Hindi: कार्रवाई (_ o)
# Translated:  action (_ o)
# Original:  Acti _ on
# ------------------------------
# Index: 37
# Hindi: आईडी
# Translated:  Id
# Original:  ID
# ------------------------------
# Index: 38
# Hindi: औजार बक्सा
# Translated:  tool box
# Original:  Toolkit
# ------------------------------
# Index: 39
# Hindi: संस्करण
# Translated:  version
# Original:  Version
# ------------------------------
# Index: 40
# Hindi: अनुप्रयोग
# Translated:  Application
# Original:  Ap _ plication
# ------------------------------
# Index: 41
# Hindi: संग्रह
# Translated:  Collection
# Original:  Col _ lection
# ------------------------------
# Index: 42
# Hindi: 0, 0
# Translated:  0, 0
# Original:  0, 0
# ------------------------------
# Index: 43
# Hindi: सापेक्ष स्थिति
# Translated:  relative position
# Original:  Relative position
# ------------------------------
# Index: 44
# Hindi: आकार
# Translated:  size
# Original:  Size
# ------------------------------
# Index: 45
# Hindi: विडजेट
# Translated:  Vidmate
# Original:  WIDGET
# ------------------------------
# Index: 46
# Hindi: स्तर
# Translated:  level
# Original:  Layer
# ------------------------------
# Index: 47
# Hindi: एमडीआई-जेड-क्रम
# Translated:  mdi-z-order
# Original:  MDI - Z - order
# ------------------------------
# Index: 48
# Hindi: अल्फा
# Translated:  Alpha
# Original:  Alpha
# ------------------------------
# Index: 49
# Hindi: निरपेक्ष स्थिति
# Translated:  absolute position
# Original:  Absolute position
# ------------------------------
# Index: 50
# Hindi: घटक
# Translated:  Constituent
# Original:  Co _ mponent
# ------------------------------
# Index: 51
# Hindi: डेस्कटोप
# Translated:  desktop
# Original:  Des _ ktop
# ------------------------------
# Index: 52
# Hindi: स्थान-विशिष्टः
# Translated:  Location specific:
# Original:  Locale:
# ------------------------------
# Index: 53
# Hindi: प्रलेख
# Translated:  document
# Original:  _ Document
# ------------------------------
# Index: 54
# Hindi: हाइपरकड़ी
# Translated:  hyperkey
# Original:  Hyperlink
# ------------------------------
# Index: 55
# Hindi: हाइपरपाठ
# Translated:  hypertext
# Original:  H _ ypertext
# ------------------------------
# Index: 56
# Hindi: स्थिति
# Translated:  Situation
# Original:  Position
# ------------------------------
# Index: 57
# Hindi: वर्णन
# Translated:  Description
# Original:  Description
# ------------------------------
# Index: 58
# Hindi: स्थान-विशिष्ट
# Translated:  location specific
# Original:  Locale
# ------------------------------
# Index: 59
# Hindi: छवि (_ I)
# Translated:  Image (_ I)
# Original:  _ Image
# ------------------------------
# Index: 60
# Hindi: प्रवेश सहायक
# Translated:  admission assistant
# Original:  Lo _ gin Helper
# ------------------------------
# Index: 61
# Hindi: सभी चुनें
# Translated:  sellect all
# Original:  Select All
# ------------------------------
# Index: 62
# Hindi: चयन (_ S)
# Translated:  Selection(_S)
# Original:  _ Selection
# ------------------------------
# Index: 63
# Hindi: प्रवाहित करनेयोग्य विषयवस्तु
# Translated:  streamable content
# Original:  St _ reamable Content
# ------------------------------
# Index: 64
# Hindi: चुने गए स्तंभ
# Translated:  selected columns
# Original:  Selected columns
# ------------------------------
# Index: 65
# Hindi: चुनी गई पंक्तियां
# Translated:  selected rows
# Original:  Selected rows
# ------------------------------
# Index: 66
# Hindi: स्तंभ
# Translated:  pillar
# Original:  Columns
# ------------------------------
# Index: 67
# Hindi: पंक्तियां
# Translated:  lines
# Original:  Rows
# ------------------------------
# Index: 68
# Hindi: & lt; bgt; सारणी सूचनाlt;/bgt;
# Translated:  &lt; bgt; Table Informationlt;/bgt;
# Original:  Table Information
# ------------------------------
# Index: 69
# Hindi: नाम (x, y)
# Translated:  name(x,y)
# Original:  name (x, y)
# ------------------------------
# Index: 70
# Hindi: शीर्षकः
# Translated:  Title:
# Original:  Header:
# ------------------------------
# Index: 71
# Hindi: विस्तारः
# Translated:  Detail:
# Original:  Extents:
# ------------------------------
# Index: 72
# Hindi: पंक्ति
# Translated:  Line
# Original:  Row
# ------------------------------
# Index: 73
# Hindi: स्तंभ
# Translated:  pillar
# Original:  Column
# ------------------------------
# Index: 74
# Hindi: & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# Translated:  &lt; bgt; Selected cellslt;/bgt;
# Original:  Selected Cell
# ------------------------------
# Index: 75
# Hindi: सारणी (_ T)
# Translated:  Table (_ T)
# Original:  _ Table
# ------------------------------
# Index: 76
# Hindi: ओफसेट
# Translated:  offset
# Original:  Offset
# ------------------------------
# Index: 77
# Hindi: डिफोल्टों को शामिल करें
# Translated:  include defaults
# Original:  Include defaults
# ------------------------------
# Index: 78
# Hindi: पाठ (_ x)
# Translated:  text(_x)
# Original:  Te _ xt
# ------------------------------
# Index: 79
# Hindi: मौजूदा मान
# Translated:  current value
# Original:  Current value
# ------------------------------
# Index: 80
# Hindi: न्यूनतम वृद्धि
# Translated:  minimum increase
# Original:  Minimum increment
# ------------------------------
# Index: 81
# Hindi: अधिकतम मान
# Translated:  maximum value
# Original:  Maximum value
# ------------------------------
# Index: 82
# Hindi: न्यूनतम मान
# Translated:  minimum value
# Original:  Minimum value
# ------------------------------
# Index: 83
# Hindi: मान
# Translated:  Value
# Original:  Val _ ue
# ------------------------------
# Index: 84
# Hindi: अंतराफलक दर्शक
# Translated:  interface viewer
# Original:  Interface Viewer
# ------------------------------
# Index: 85
# Hindi: अंतराफलक के विभिन्न गुणों को देखने देता है
# Translated:  Allows you to view various properties of the interface
# Original:  Allows viewing of various interface properties
# ------------------------------
# Index: 86
# Hindi: (क्रियान्वित नहीं हुआ है)
# Translated:  (not implemented)
# Original:  (not implemented)
# ------------------------------
# Index: 87
# Hindi: नाम
# Translated:  Name
# Original:  Name
# ------------------------------
# Index: 88
# Hindi: यूआरआई
# Translated:  URI
# Original:  URI
# ------------------------------
# Index: 89
# Hindi: प्रारंभ
# Translated:  Start
# Original:  Start
# ------------------------------
# Index: 90
# Hindi: अंत
# Translated:  Ending
# Original:  End
# ------------------------------
# Index: 91
# Hindi: बहुत अधिक चयनीय शिशु हैं
# Translated:  There are too many picky babies
# Original:  Too many selectable children
# ------------------------------
# Index: 92
# Hindi: तेज चुनाव
# Translated:  fast election
# Original:  Quick Select
# ------------------------------
# Index: 93
# Hindi: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# Translated:  Plug-in with multiple methods for quickly selecting accessible items
# Original:  Plugin with various methods of selecting accessibles quickly.
# ------------------------------
# Index: 94
# Hindi: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# Translated:  Check last focused accessible
# Original:  Inspect last focused accessible
# ------------------------------
# Index: 95
# Hindi: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# Translated:  Check what's accessible under the mouse
# Original:  Inspect accessible under mouse
# ------------------------------
# Index: 96
# Hindi: वतनी
# Translated:  motherland
# Original:  Native
# ------------------------------
# Index: 97
# Hindi: श्वानपुच्छ
# Translated:  dog tail
# Original:  Dogtail
# ------------------------------
# Index: 98
# Hindi: एलडीटीपी
# Translated:  ldtp
# Original:  LDTP
# ------------------------------
# Index: 99
# Hindi: लिपि प्रकार
# Translated:  script type
# Original:  Script Type
# ------------------------------
# Index: 100
# Hindi: लिपि रेकोर्डर
# Translated:  script recorder
# Original:  Script Recorder
# ------------------------------
# Index: 101
# Hindi: श्वानपुच्छ शैली की लिपियां निर्मित करता है
# Translated:  Creates dog tail style scripts
# Original:  Creates dogtail style scripts
# ------------------------------
# Index: 102
# Hindi: वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
# Translated:  The current script will be lost.
# Original:  The current script will be lost.
# ------------------------------
# Index: 103
# Hindi: मिटाने की पुष्टि करें
# Translated:  confirm deletion
# Original:  Confirm clear
# ------------------------------
# Index: 104
# Hindi: स्कीमाः
# Translated:  Schema:
# Original:  Sche _ ma:
# ------------------------------
# Index: 105
# Hindi: सत्यापन
# Translated:  verification
# Original:  V _ alidate
# ------------------------------
# Index: 106
# Hindi: खाली
# Translated:  Empty
# Original:  Idle
# ------------------------------
# Index: 107
# Hindi: कोई विवरण नहीं
# Translated:  no description
# Original:  No description
# ------------------------------
# Index: 108
# Hindi: एटी-एसपीआई सत्यापक
# Translated:  AT-SPI Verifier
# Original:  AT - SPI Validator
# ------------------------------
# Index: 109
# Hindi: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# Translated:  Verifies the accessibility of the application
# Original:  Validates application accessibility
# ------------------------------
# Index: 110
# Hindi: स्तर
# Translated:  level
# Original:  Level
# ------------------------------
# Index: 111
# Hindi: भूमिका
# Translated:  Role
# Original:  Role
# ------------------------------
# Index: 112
# Hindi: सहेज रहे हैं
# Translated:  are saving
# Original:  Saving
# ------------------------------
# Index: 113
# Hindi: पुष्टि कर रहे हैं
# Translated:  are confirming
# Original:  Validating
# ------------------------------
# Index: 114
# Hindi: अपवाद
# Translated:  Exception
# Original:  EXCEPT
# ------------------------------
# Index: 115
# Hindi: त्रुटि
# Translated:  Error
# Original:  ERROR
# ------------------------------
# Index: 116
# Hindi: चेतावनी
# Translated:  alert
# Original:  WARN
# ------------------------------
# Index: 117
# Hindi: सूचना
# Translated:  Information
# Original:  INFO
# ------------------------------
# Index: 118
# Hindi: दोषमुक्त करें
# Translated:  absolve
# Original:  DEBUG
# ------------------------------
# Index: 119
# Hindi: मूल
# Translated:  Original
# Original:  Basic
# ------------------------------
# Index: 120
# Hindi: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# Translated:  Basic GUI application accessibility testing
# Original:  Tests fundamental GUI application accessibility
# ------------------------------
# Index: 121
# Hindi: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# Translated:  %s that is actionable is neither focusable nor selectable
# Original:  actionable% s is not focusable or selectable
# ------------------------------
# Index: 122
# Hindi: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# Translated:  interactive %s action is not actionable
# Original:  interactive% s is not actionable
# ------------------------------
# Index: 123
# Hindi: एक से अधिक विडजेट फोकस में है
# Translated:  More than one widget is in focus
# Original:  more than one focused widget
# ------------------------------
# Index: 124
# Hindi: % s का कोई पाठ अंतराफलक नहीं है
# Translated:  %s has no text interface
# Original:  % s has no text interface
# ------------------------------
# Index: 125
# Hindi: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# Translated:  %s list in parent does not match child list
# Original:  % s index in parent does not match child index
# ------------------------------
# Index: 126
# Hindi: % s संबंध के लिए अन्योन्य गायब है
# Translated:  Relation missing for %s
# Original:  Missing reciprocal for% s relation
# ------------------------------
# Index: 127
# Hindi: % s गायब नाम या सूचक
# Translated:  %s missing name or pointer
# Original:  % s missing name or label
# ------------------------------
# Index: 128
# Hindi: फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# Translated:  Focusable %s has array interface, no selectable interface button has focused state without focusable state
# Original:  focusable% s has table interface, no selection interface
# ------------------------------
# Index: 129
# Hindi: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# Translated:  %s has %s status, but %s doesn't have status with it
# Original:  % s has% s state without% s state
# ------------------------------
# Index: 130
# Hindi: % s किसी समुच्चय का सदस्य नहीं है
# Translated:  %s is not a member of any set
# Original:  % s does not belong to a set
# ------------------------------
# Index: 131
# Hindi: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# Translated:  % (rolename) s list % (num) d row and column do not match parent index row and column index
# Original:  % (rolename) s index% (num) d does not match row and column
# ------------------------------
# Index: 132
# Hindi: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# Translated:  %(rolename)s do not match parent list %(num1)d row and column list %(num2)d
# Original:  % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# ------------------------------
# Index: 133
# Hindi: % s का कोई नाम या विवरण नहीं
# Translated:  %s has no name or description
# Original:  % s has no name or description
# ------------------------------
# Index: 134
# Hindi: पसंद (_ P)...
# Translated:  Like(_P)...
# Original:  _ Preferences...
# ------------------------------
# Index: 135
# Hindi: विषय सूची (_ C)
# Translated:  Table of Contents (_ C)
# Original:  _ Contents
# ------------------------------
# Index: 136
# Hindi: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# Translated:  Exerciser could not see the applications on your desktop. To resolve this issue, you need to activate desktop accessibility. Do you want to activate it?
# Original:  Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# ------------------------------
# Index: 137
# Hindi: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# Translated:  Note: Changes will take effect only after logout.
# Original:  Note: Changes only take effect after logout.
# ------------------------------
# Index: 138
# Hindi: शिशु
# Translated:  baby
# Original:  Children
# ------------------------------
# Index: 139
# Hindi: पंजी ताजा करें (_ R)
# Translated:  Refresh Register (_ R)
# Original:  _ Refresh Registry
# ------------------------------
# Index: 140
# Hindi: सभी को ताजा करें
# Translated:  refresh all
# Original:  Refresh all
# ------------------------------
# Index: 141
# Hindi: आसंधि (नोड) को ताजा करें (_ N)
# Translated:  Refresh the node (_ N)
# Original:  Refresh _ Node
# ------------------------------
# Index: 142
# Hindi: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# Translated:  Refresh children of selected nodes
# Original:  Refresh selected node 's children
# ------------------------------
# Index: 143
# Hindi: घटक
# Translated:  Constituent
# Original:  Component
# ------------------------------
# Index: 144
# Hindi: कार्य
# Translated:  Work
# Original:  Task
# ------------------------------
# Index: 145
# Hindi: कुंजी
# Translated:  Key
# Original:  Key
# ------------------------------
# Index: 146
# Hindi: आल्ट
# Translated:  alt
# Original:  Alt
# ------------------------------
# Index: 147
# Hindi: कंट्रोल
# Translated:  control
# Original:  Ctrl
# ------------------------------
# Index: 148
# Hindi: शिफ्ट
# Translated:  shift
# Original:  Shift
# ------------------------------
# Index: 149
# Hindi: ऊपरी पटल
# Translated:  upper plate
# Original:  Top panel
# ------------------------------
# Index: 150
# Hindi: निचला पटल
# Translated:  lower plate
# Original:  Bottom panel
# ------------------------------
# Index: 151
# Hindi: एक्सेर्साइसर पसंद
# Translated:  exerciser choice
# Original:  accerciser Preferences
# ------------------------------
# Index: 152
# Hindi: प्लगइन्स
# Translated:  plugins
# Original:  Plugins
# ------------------------------
# Index: 153
# Hindi: सार्वत्रिक फटाफट कुंजियां
# Translated:  universal hotkeys
# Original:  Global Hotkeys
# ------------------------------
# Index: 154
# Hindi: हाइलाइटन
# Translated:  highlighten
# Original:  Highlighting
# ------------------------------
# Index: 155
# Hindi: हाइलाइट अवधिः
# Translated:  Highlight period:
# Original:  Highlight duration:
# ------------------------------
# Index: 156
# Hindi: सीमांत रंगः
# Translated:  Border color:
# Original:  Border color:
# ------------------------------
# Index: 157
# Hindi: हाइलाइट बक्से का सीमांत रंग
# Translated:  border color of highlight boxes
# Original:  The border color of the highlight box
# ------------------------------
# Index: 158
# Hindi: भराई का रंगः
# Translated:  Filling colour:
# Original:  Fill color:
# ------------------------------
# Index: 159
# Hindi: हाइलाइट बक्से का भराई रंग
# Translated:  fill color of highlight boxes
# Original:  The fill color of the highlight box
# ------------------------------
# Index: 160
# Hindi: रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# Translated:  Ravi Shankar Srivastava (raviratlami @yahoo. com) Rajesh Ranjan (rajeshkajha @yahoo. com) Lt. Balasubramaniam (l.balasubramaniam@gmail.com)
# Original:  translator - credits
# ------------------------------
# Index: 161
# Hindi: एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# Translated:  An interactive Python accessibility explorer
# Original:  An interactive Python accessibility explorer
# ------------------------------
# Index: 162
# Hindi: एक्सेर्साइसर सर्वाधिकार © 2006,2007 आईबीएम निगम (बीएसडी)
# Translated:  Exerciser Copyright © 2006,2007 IBM Corporation (BSD)
# Original:  accerciser Copyright © 2006, 2007 IBM Corporation (BSD)
# ------------------------------
# Index: 163
# Hindi: नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# Translated:  See Copying and Information Files for new BSD license details
# Original:  The New BSD License See the COPYING and NOTICE files for details.
# ------------------------------
# Index: 164
# Hindi: जाल स्थल
# Translated:  trap site
# Original:  Web site
# ------------------------------
# Index: 165
# Hindi: पसंद जोड़ें... (_ A)
# Translated:  Add Like... (_ A)
# Original:  _ Add Bookmark...
# ------------------------------
# Index: 166
# Hindi: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# Translated:  Bookmark selected accessibles
# Original:  Bookmark selected accessible.
# ------------------------------
# Index: 167
# Hindi: पुस्तक चिह्न संपादित करें (_ E)...
# Translated:  Edit book icon (_ E)...
# Original:  _ Edit Bookmarks...
# ------------------------------
# Index: 168
# Hindi: पुस्तक-चिह्नों को प्रबंधित करें।
# Translated:  Manage bookmarks.
# Original:  Manage bookmarks.
# ------------------------------
# Index: 169
# Hindi: पुस्तक चिह्नों को संपादित करें...
# Translated:  Edit book marks...
# Original:  Edit Bookmarks...
# ------------------------------
# Index: 170
# Hindi: शीर्षक
# Translated:  Topic
# Original:  Title
# ------------------------------
# Index: 171
# Hindi: अनुप्रयोग
# Translated:  Application
# Original:  Application
# ------------------------------
# Index: 172
# Hindi: पथ
# Translated:  path
# Original:  Path
# ------------------------------
# Index: 173
# Hindi: पुस्तक-चिह्न जोड़ें...
# Translated:  Add bookmark...
# Original:  Add Bookmark...
# ------------------------------
# Index: 174
# Hindi: शीर्षकः
# Translated:  Title:
# Original:  Title:
# ------------------------------
# Index: 175
# Hindi: अनुप्रयोगः
# Translated:  Application:
# Original:  Application:
# ------------------------------
# Index: 176
# Hindi: पथः
# Translated:  Path:
# Original:  Path:
# ------------------------------
# Index: 177
# Hindi: प्लग-इन त्रुटियां
# Translated:  plug-in errors
# Original:  Plugin Errors
# ------------------------------
# Index: 178
# Hindi: दृश्य
# Translated:  Scene
# Original:  View
# ------------------------------
# Index: 179
# Hindi: कोई दृश्य नहीं है
# Translated:  there is no view
# Original:  No view
# ------------------------------
# Index: 180
# Hindi: एकल प्लग-इन दृश्य
# Translated:  single plug-in view
# Original:  _ Single plugins view
# ------------------------------
# Index: 181
# Hindi: प्लग-इन दृश्य
# Translated:  plug-in view
# Original:  Plugin View
# ------------------------------
# Index: 182
# Hindi: प्लग-इन दृश्य (% d)
# Translated:  Plug-in View (%d)
# Original:  Plugin View (% d)
# ------------------------------
# Index: 183
# Hindi: नया दृश्य...
# Translated:  New scene...
# Original:  _ New view...
# ------------------------------
# Index: 184
# Hindi: नया दृश्य...
# Translated:  New scene...
# Original:  New View...
# ------------------------------
# Index: 185
# Hindi: फाइल (F)
# Translated:  file (F)
# Original:  _ File
# ------------------------------
# Index: 186
# Hindi: संपादित करें
# Translated:  Edit
# Original:  _ Edit
# ------------------------------
# Index: 187
# Hindi: पुस्तक-चिह्न संपादित करें (_ E)...
# Translated:  Edit bookmark (_ E)...
# Original:  _ Bookmarks
# ------------------------------
# Index: 188
# Hindi: दृश्य _ (V)
# Translated:  View _ (V)
# Original:  _ View
# ------------------------------
# Index: 189
# Hindi: मदद
# Translated:  Help
# Original:  _ Help
# ------------------------------
# Index: 190
# Hindi: पूरा नाम
# Translated:  Full Name
# Original:  Full name
# ------------------------------
# Index: 191
# Hindi: कुंजी बंधन
# Translated:  key binding
# Original:  Key binding
# ------------------------------
# Index: 192
# Hindi: विषय प्रकार
# Translated:  subject type
# Original:  Content type
# ------------------------------
# Index: 193
# Hindi: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# Translated:  Give your app the benefit of accessibility exercises
# Original:  Give your application an accessibility workout
# ------------------------------
# Index: 194
# Hindi: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# Translated:  Accessizer Accessibility Explorer
# Original:  Accerciser Accessibility Explorer
# ------------------------------
# Index: 195
# Hindi: निचले पटल के लिए डिफोल्ट प्लग-इन खाका
# Translated:  Default plug-in template for bottom panel
# Original:  The default plugin layout for the bottom panel
# ------------------------------
# Index: 196
# Hindi: ऊपरी पटल के लिए डिफोल्ट प्लग-इन खाका
# Translated:  Default plug-in template for the top panel
# Original:  The default plugin layout for the top panel
# ------------------------------
# Index: 197
# Hindi: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Translated:  List of plug-ins that are disabled by default
# Original:  A list of plugins that are disabled by default
# ------------------------------
# Index: 198
# Hindi: अवधि को हाइलाइट रकें
# Translated:  keep duration highlighted
# Original:  Highlight duration
# ------------------------------
# Index: 199
# Hindi: पहुंचनीय आसंधि (नोड) को चुनते समय हाइलाइट बक्से की अवधि
# Translated:  Duration of highlight boxes when selecting accessible nodes
# Original:  The duration of the highlight box when selecting accessible nodes
# ------------------------------
# Index: 200
# Hindi: सीमांत (बोर्डर) के रंग को हाइलाइट करें
# Translated:  Highlight the border color
# Original:  Highlight border color
# ------------------------------
# Index: 201
# Hindi: हाइलाइट किए गए सीमांत का रंग और अपारदर्शिता।
# Translated:  Color and opacity of the highlighted margin.
# Original:  The color and opacity of the highlight border.
# ------------------------------
# Index: 202
# Hindi: भराई के रंग को हाइलाइट करें
# Translated:  Highlight the fill color
# Original:  Highlight fill color
# ------------------------------
# Index: 203
# Hindi: हाइलाइट किया गया भराई का रंग और पारदर्शिता।
# Translated:  Highlighted filling color and transparency.
# Original:  The color and opacity of the highlight fill.
# ------------------------------
# Index: 204
# Hindi: एपीआई विचरक
# Translated:  api thinker
# Original:  API Browser
# ------------------------------
# Index: 205
# Hindi: इस समय जिसे प्राप्त किया गया हो, उसकी विभिन्न विधियों (मेथड) में विचरण करें
# Translated:  Explore various methods of what has been achieved at this time
# Original:  Browse the various methods of the current accessible
# ------------------------------
# Index: 206
# Hindi: निजी गुणों को छिपाएं
# Translated:  hide private properties
# Original:  Hide private attributes
# ------------------------------
# Index: 207
# Hindi: विधि
# Translated:  Method
# Original:  Method
# ------------------------------
# Index: 208
# Hindi: गुणधर्म
# Translated:  properties
# Original:  Property
# ------------------------------
# Index: 209
# Hindi: मान
# Translated:  Value
# Original:  Value
# ------------------------------
# Index: 210
# Hindi: आईपाइथन कन्सोल
# Translated:  ipython console
# Original:  IPython Console
# ------------------------------
# Index: 211
# Hindi: इस समय चुने गए एक्सेसेबेल से काम लेने के लिए अंतर्क्रियात्मक कन्सोल
# Translated:  Interactive console for working with the currently selected accessible
# Original:  Interactive console for manipulating currently selected accessible
# ------------------------------
# Index: 212
# Hindi: घटना मानिटर
# Translated:  event monitor
# Original:  Event monitor
# ------------------------------
# Index: 213
# Hindi: घटनाओं को मानिटर करें (_ M)
# Translated:  Monitor events (_ M)
# Original:  _ Monitor Events
# ------------------------------
# Index: 214
# Hindi: चुनाव को हटाएं (C _)
# Translated:  Delete selection (C_)
# Original:  C _ lear Selection
# ------------------------------
# Index: 215
# Hindi: सभी
# Translated:  All
# Original:  Everything
# ------------------------------
# Index: 216
# Hindi: चुने गए अनुप्रयोग
# Translated:  Selected applications
# Original:  Selected application
# ------------------------------
# Index: 217
# Hindi: चुने गए एक्सेसेबेल
# Translated:  selected accessible
# Original:  Selected accessible
# ------------------------------
# Index: 218
# Hindi: स्रोत
# Translated:  Source
# Original:  Source
# ------------------------------
# Index: 219
# Hindi: घटना मानिटर
# Translated:  event monitor
# Original:  Event Monitor
# ------------------------------
# Index: 220
# Hindi: चुने गए प्रकारों और स्रोतों से घटनाएं जैसे-जैसे घटित होती हैं, उन्हें दर्शाता है
# Translated:  Shows events as they occur from selected types and sources
# Original:  Shows events as they occur from selected types and sources
# ------------------------------
# Index: 221
# Hindi: अंतिम प्रविष्ट घटना को हाइलाइट करो
# Translated:  Highlight last entered event
# Original:  Highlight last event entry
# ------------------------------
# Index: 222
# Hindi: घटना रेकोर्डिंग शुरू करो/रोको
# Translated:  Start/stop event recording
# Original:  Start / stop event recording
# ------------------------------
# Index: 223
# Hindi: घटना रोजनामचा मिटाओ
# Translated:  delete event log
# Original:  Clear event log
# ------------------------------
# Index: 224
# Hindi: कोई विवरण नहीं
# Translated:  no description
# Original:  (no description)
# ------------------------------
# Index: 225
# Hindi: वर्णन
# Translated:  Description
# Original:  Description
# ------------------------------
# Index: 226
# Hindi: दिखाएं
# Translated:  Show
# Original:  Show
# ------------------------------
# Index: 227
# Hindi: पहुंचनीय
# Translated:  reachable
# Original:  _ Accessible
# ------------------------------
# Index: 228
# Hindi: कार्रवाई संपन्न करें
# Translated:  complete the action
# Original:  Perform action
# ------------------------------
# Index: 229
# Hindi: कार्रवाई (_ o)
# Translated:  action (_ o)
# Original:  Acti _ on
# ------------------------------
# Index: 230
# Hindi: आईडी
# Translated:  Id
# Original:  ID
# ------------------------------
# Index: 231
# Hindi: औजार बक्सा
# Translated:  tool box
# Original:  Toolkit
# ------------------------------
# Index: 232
# Hindi: संस्करण
# Translated:  version
# Original:  Version
# ------------------------------
# Index: 233
# Hindi: अनुप्रयोग
# Translated:  Application
# Original:  Ap _ plication
# ------------------------------
# Index: 234
# Hindi: संग्रह
# Translated:  Collection
# Original:  Col _ lection
# ------------------------------
# Index: 235
# Hindi: 0, 0
# Translated:  0, 0
# Original:  0, 0
# ------------------------------
# Index: 236
# Hindi: सापेक्ष स्थिति
# Translated:  relative position
# Original:  Relative position
# ------------------------------
# Index: 237
# Hindi: आकार
# Translated:  size
# Original:  Size
# ------------------------------
# Index: 238
# Hindi: विडजेट
# Translated:  Vidmate
# Original:  WIDGET
# ------------------------------
# Index: 239
# Hindi: स्तर
# Translated:  level
# Original:  Layer
# ------------------------------
# Index: 240
# Hindi: एमडीआई-जेड-क्रम
# Translated:  mdi-z-order
# Original:  MDI - Z - order
# ------------------------------
# Index: 241
# Hindi: अल्फा
# Translated:  Alpha
# Original:  Alpha
# ------------------------------
# Index: 242
# Hindi: निरपेक्ष स्थिति
# Translated:  absolute position
# Original:  Absolute position
# ------------------------------
# Index: 243
# Hindi: घटक
# Translated:  Constituent
# Original:  Co _ mponent
# ------------------------------
# Index: 244
# Hindi: डेस्कटोप
# Translated:  desktop
# Original:  Des _ ktop
# ------------------------------
# Index: 245
# Hindi: स्थान-विशिष्टः
# Translated:  Location specific:
# Original:  Locale:
# ------------------------------
# Index: 246
# Hindi: प्रलेख
# Translated:  document
# Original:  _ Document
# ------------------------------
# Index: 247
# Hindi: हाइपरकड़ी
# Translated:  hyperkey
# Original:  Hyperlink
# ------------------------------
# Index: 248
# Hindi: हाइपरपाठ
# Translated:  hypertext
# Original:  H _ ypertext
# ------------------------------
# Index: 249
# Hindi: स्थिति
# Translated:  Situation
# Original:  Position
# ------------------------------
# Index: 250
# Hindi: वर्णन
# Translated:  Description
# Original:  Description
# ------------------------------
# Index: 251
# Hindi: स्थान-विशिष्ट
# Translated:  location specific
# Original:  Locale
# ------------------------------
# Index: 252
# Hindi: छवि (_ I)
# Translated:  Image (_ I)
# Original:  _ Image
# ------------------------------
# Index: 253
# Hindi: प्रवेश सहायक
# Translated:  admission assistant
# Original:  Lo _ gin Helper
# ------------------------------
# Index: 254
# Hindi: सभी चुनें
# Translated:  sellect all
# Original:  Select All
# ------------------------------
# Index: 255
# Hindi: चयन (_ S)
# Translated:  Selection(_S)
# Original:  _ Selection
# ------------------------------
# Index: 256
# Hindi: प्रवाहित करनेयोग्य विषयवस्तु
# Translated:  streamable content
# Original:  St _ reamable Content
# ------------------------------
# Index: 257
# Hindi: चुने गए स्तंभ
# Translated:  selected columns
# Original:  Selected columns
# ------------------------------
# Index: 258
# Hindi: चुनी गई पंक्तियां
# Translated:  selected rows
# Original:  Selected rows
# ------------------------------
# Index: 259
# Hindi: स्तंभ
# Translated:  pillar
# Original:  Columns
# ------------------------------
# Index: 260
# Hindi: पंक्तियां
# Translated:  lines
# Original:  Rows
# ------------------------------
# Index: 261
# Hindi: & lt; bgt; सारणी सूचनाlt;/bgt;
# Translated:  &lt; bgt; Table Informationlt;/bgt;
# Original:  Table Information
# ------------------------------
# Index: 262
# Hindi: नाम (x, y)
# Translated:  name(x,y)
# Original:  name (x, y)
# ------------------------------
# Index: 263
# Hindi: शीर्षकः
# Translated:  Title:
# Original:  Header:
# ------------------------------
# Index: 264
# Hindi: विस्तारः
# Translated:  Detail:
# Original:  Extents:
# ------------------------------
# Index: 265
# Hindi: पंक्ति
# Translated:  Line
# Original:  Row
# ------------------------------
# Index: 266
# Hindi: स्तंभ
# Translated:  pillar
# Original:  Column
# ------------------------------
# Index: 267
# Hindi: & lt; bgt; चुनी गई कोशिकाlt;/bgt;
# Translated:  &lt; bgt; Selected cellslt;/bgt;
# Original:  Selected Cell
# ------------------------------
# Index: 268
# Hindi: सारणी (_ T)
# Translated:  Table (_ T)
# Original:  _ Table
# ------------------------------
# Index: 269
# Hindi: ओफसेट
# Translated:  offset
# Original:  Offset
# ------------------------------
# Index: 270
# Hindi: डिफोल्टों को शामिल करें
# Translated:  include defaults
# Original:  Include defaults
# ------------------------------
# Index: 271
# Hindi: पाठ (_ x)
# Translated:  text(_x)
# Original:  Te _ xt
# ------------------------------
# Index: 272
# Hindi: मौजूदा मान
# Translated:  current value
# Original:  Current value
# ------------------------------
# Index: 273
# Hindi: न्यूनतम वृद्धि
# Translated:  minimum increase
# Original:  Minimum increment
# ------------------------------
# Index: 274
# Hindi: अधिकतम मान
# Translated:  maximum value
# Original:  Maximum value
# ------------------------------
# Index: 275
# Hindi: न्यूनतम मान
# Translated:  minimum value
# Original:  Minimum value
# ------------------------------
# Index: 276
# Hindi: मान
# Translated:  Value
# Original:  Val _ ue
# ------------------------------
# Index: 277
# Hindi: अंतराफलक दर्शक
# Translated:  interface viewer
# Original:  Interface Viewer
# ------------------------------
# Index: 278
# Hindi: अंतराफलक के विभिन्न गुणों को देखने देता है
# Translated:  Allows you to view various properties of the interface
# Original:  Allows viewing of various interface properties
# ------------------------------
# Index: 279
# Hindi: (क्रियान्वित नहीं हुआ है)
# Translated:  (not implemented)
# Original:  (not implemented)
# ------------------------------
# Index: 280
# Hindi: नाम
# Translated:  Name
# Original:  Name
# ------------------------------
# Index: 281
# Hindi: यूआरआई
# Translated:  URI
# Original:  URI
# ------------------------------
# Index: 282
# Hindi: प्रारंभ
# Translated:  Start
# Original:  Start
# ------------------------------
# Index: 283
# Hindi: अंत
# Translated:  Ending
# Original:  End
# ------------------------------
# Index: 284
# Hindi: बहुत अधिक चयनीय शिशु हैं
# Translated:  There are too many picky babies
# Original:  Too many selectable children
# ------------------------------
# Index: 285
# Hindi: तेज चुनाव
# Translated:  fast election
# Original:  Quick Select
# ------------------------------
# Index: 286
# Hindi: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# Translated:  Plug-in with multiple methods for quickly selecting accessible items
# Original:  Plugin with various methods of selecting accessibles quickly.
# ------------------------------
# Index: 287
# Hindi: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# Translated:  Check last focused accessible
# Original:  Inspect last focused accessible
# ------------------------------
# Index: 288
# Hindi: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# Translated:  Check what's accessible under the mouse
# Original:  Inspect accessible under mouse
# ------------------------------
# Index: 289
# Hindi: वतनी
# Translated:  motherland
# Original:  Native
# ------------------------------
# Index: 290
# Hindi: श्वानपुच्छ
# Translated:  dog tail
# Original:  Dogtail
# ------------------------------
# Index: 291
# Hindi: एलडीटीपी
# Translated:  ldtp
# Original:  LDTP
# ------------------------------
# Index: 292
# Hindi: लिपि प्रकार
# Translated:  script type
# Original:  Script Type
# ------------------------------
# Index: 293
# Hindi: लिपि रेकोर्डर
# Translated:  script recorder
# Original:  Script Recorder
# ------------------------------
# Index: 294
# Hindi: श्वानपुच्छ शैली की लिपियां निर्मित करता है
# Translated:  Creates dog tail style scripts
# Original:  Creates dogtail style scripts
# ------------------------------
# Index: 295
# Hindi: वर्तमान लिपि (स्क्रिप्ट) खो जाएगी।
# Translated:  The current script will be lost.
# Original:  The current script will be lost.
# ------------------------------
# Index: 296
# Hindi: मिटाने की पुष्टि करें
# Translated:  confirm deletion
# Original:  Confirm clear
# ------------------------------
# Index: 297
# Hindi: स्कीमाः
# Translated:  Schema:
# Original:  Sche _ ma:
# ------------------------------
# Index: 298
# Hindi: सत्यापन
# Translated:  verification
# Original:  V _ alidate
# ------------------------------
# Index: 299
# Hindi: खाली
# Translated:  Empty
# Original:  Idle
# ------------------------------
# Index: 300
# Hindi: कोई विवरण नहीं
# Translated:  no description
# Original:  No description
# ------------------------------
# Index: 301
# Hindi: एटी-एसपीआई सत्यापक
# Translated:  AT-SPI Verifier
# Original:  AT - SPI Validator
# ------------------------------
# Index: 302
# Hindi: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# Translated:  Verifies the accessibility of the application
# Original:  Validates application accessibility
# ------------------------------
# Index: 303
# Hindi: स्तर
# Translated:  level
# Original:  Level
# ------------------------------
# Index: 304
# Hindi: भूमिका
# Translated:  Role
# Original:  Role
# ------------------------------
# Index: 305
# Hindi: सहेज रहे हैं
# Translated:  are saving
# Original:  Saving
# ------------------------------
# Index: 306
# Hindi: पुष्टि कर रहे हैं
# Translated:  are confirming
# Original:  Validating
# ------------------------------
# Index: 307
# Hindi: अपवाद
# Translated:  Exception
# Original:  EXCEPT
# ------------------------------
# Index: 308
# Hindi: त्रुटि
# Translated:  Error
# Original:  ERROR
# ------------------------------
# Index: 309
# Hindi: चेतावनी
# Translated:  alert
# Original:  WARN
# ------------------------------
# Index: 310
# Hindi: सूचना
# Translated:  Information
# Original:  INFO
# ------------------------------
# Index: 311
# Hindi: दोषमुक्त करें
# Translated:  absolve
# Original:  DEBUG
# ------------------------------
# Index: 312
# Hindi: मूल
# Translated:  Original
# Original:  Basic
# ------------------------------
# Index: 313
# Hindi: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# Translated:  Basic GUI application accessibility testing
# Original:  Tests fundamental GUI application accessibility
# ------------------------------
# Index: 314
# Hindi: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# Translated:  %s that is actionable is neither focusable nor selectable
# Original:  actionable% s is not focusable or selectable
# ------------------------------
# Index: 315
# Hindi: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# Translated:  interactive %s action is not actionable
# Original:  interactive% s is not actionable
# ------------------------------
# Index: 316
# Hindi: एक से अधिक विडजेट फोकस में है
# Translated:  More than one widget is in focus
# Original:  more than one focused widget
# ------------------------------
# Index: 317
# Hindi: % s का कोई पाठ अंतराफलक नहीं है
# Translated:  %s has no text interface
# Original:  % s has no text interface
# ------------------------------
# Index: 318
# Hindi: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# Translated:  %s list in parent does not match child list
# Original:  % s index in parent does not match child index
# ------------------------------
# Index: 319
# Hindi: % s संबंध के लिए अन्योन्य गायब है
# Translated:  Relation missing for %s
# Original:  Missing reciprocal for% s relation
# ------------------------------
# Index: 320
# Hindi: % s गायब नाम या सूचक
# Translated:  %s missing name or pointer
# Original:  % s missing name or label
# ------------------------------
# Index: 321
# Hindi: फोकस योग्य% s में सारणी अंतराफलक है, कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# Translated:  Focusable %s has array interface, no selectable interface button has focused state without focusable state
# Original:  focusable% s has table interface, no selection interface
# ------------------------------
# Index: 322
# Hindi: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# Translated:  %s has %s status, but %s doesn't have status with it
# Original:  % s has% s state without% s state
# ------------------------------
# Index: 323
# Hindi: % s किसी समुच्चय का सदस्य नहीं है
# Translated:  %s is not a member of any set
# Original:  % s does not belong to a set
# ------------------------------
# Index: 324
# Hindi: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# Translated:  % (rolename) s list % (num) d row and column do not match parent index row and column index
# Original:  % (rolename) s index% (num) d does not match row and column
# ------------------------------
# Index: 325
# Hindi: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# Translated:  %(rolename)s do not match parent list %(num1)d row and column list %(num2)d
# Original:  % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# ------------------------------
# Index: 326
# Hindi: % s का कोई नाम या विवरण नहीं
# Translated:  %s has no name or description
# Original:  % s has no name or description
# ------------------------------
# Index: 327
# Hindi: पसंद (_ P)...
# Translated:  Like(_P)...
# Original:  _ Preferences...
# ------------------------------
# Index: 328
# Hindi: विषय सूची (_ C)
# Translated:  Table of Contents (_ C)
# Original:  _ Contents
# ------------------------------
# Index: 329
# Hindi: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# Translated:  Exerciser could not see the applications on your desktop. To resolve this issue, you need to activate desktop accessibility. Do you want to activate it?
# Original:  Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# ------------------------------
# Index: 330
# Hindi: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# Translated:  Note: Changes will take effect only after logout.
# Original:  Note: Changes only take effect after logout.
# ------------------------------
# Index: 331
# Hindi: शिशु
# Translated:  baby
# Original:  Children
# ------------------------------
# Index: 332
# Hindi: पंजी ताजा करें (_ R)
# Translated:  Refresh Register (_ R)
# Original:  _ Refresh Registry
# ------------------------------
# Index: 333
# Hindi: सभी को ताजा करें
# Translated:  refresh all
# Original:  Refresh all
# ------------------------------
# Index: 334
# Hindi: आसंधि (नोड) को ताजा करें (_ N)
# Translated:  Refresh the node (_ N)
# Original:  Refresh _ Node
# ------------------------------
# Index: 335
# Hindi: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# Translated:  Refresh children of selected nodes
# Original:  Refresh selected node 's children
# ------------------------------
# Index: 336
# Hindi: घटक
# Translated:  Constituent
# Original:  Component
# ------------------------------
# Index: 337
# Hindi: कार्य
# Translated:  Work
# Original:  Task
# ------------------------------
# Index: 338
# Hindi: कुंजी
# Translated:  Key
# Original:  Key
# ------------------------------
# Index: 339
# Hindi: आल्ट
# Translated:  alt
# Original:  Alt
# ------------------------------
# Index: 340
# Hindi: कंट्रोल
# Translated:  control
# Original:  Ctrl
# ------------------------------
# Index: 341
# Hindi: शिफ्ट
# Translated:  shift
# Original:  Shift
# ------------------------------
# Index: 342
# Hindi: ऊपरी पटल
# Translated:  upper plate
# Original:  Top panel
# ------------------------------
# Index: 343
# Hindi: निचला पटल
# Translated:  lower plate
# Original:  Bottom panel
# ------------------------------
# Index: 344
# Hindi: एक्सेर्साइसर पसंद
# Translated:  exerciser choice
# Original:  accerciser Preferences
# ------------------------------
# Index: 345
# Hindi: प्लगइन्स
# Translated:  plugins
# Original:  Plugins
# ------------------------------
# Index: 346
# Hindi: सार्वत्रिक फटाफट कुंजियां
# Translated:  universal hotkeys
# Original:  Global Hotkeys
# ------------------------------
# Index: 347
# Hindi: हाइलाइटन
# Translated:  highlighten
# Original:  Highlighting
# ------------------------------
# Index: 348
# Hindi: हाइलाइट अवधिः
# Translated:  Highlight period:
# Original:  Highlight duration:
# ------------------------------
# Index: 349
# Hindi: सीमांत रंगः
# Translated:  Border color:
# Original:  Border color:
# ------------------------------
# Index: 350
# Hindi: हाइलाइट बक्से का सीमांत रंग
# Translated:  border color of highlight boxes
# Original:  The border color of the highlight box
# ------------------------------
# Index: 351
# Hindi: भराई का रंगः
# Translated:  Filling colour:
# Original:  Fill color:
# ------------------------------
# Index: 352
# Hindi: हाइलाइट बक्से का भराई रंग
# Translated:  fill color of highlight boxes
# Original:  The fill color of the highlight box
# ------------------------------
# Index: 353
# ...
# Translated:  maximum value
# Original:  Maximum value
# ------------------------------
# Index: 891
# Hindi: न्यूनतम मान
# Translated:  minimum value
# Original:  Minimum value
# ------------------------------
# Index: 892
# Hindi: मान
# Translated:  Value
# Original:  Val _ ue
# ------------------------------
# Index: 893
# Hindi: अज्ञात
# Translated:  unknown
# Original:  unknown
# ------------------------------
# Index: 894
# Hindi: अंतराफलक दर्शक
# Translated:  interface viewer
# Original:  Interface Viewer
# ------------------------------
# Index: 895
# Hindi: अंतराफलक के विभिन्न गुणों को देखने देता है
# Translated:  Allows you to view various properties of the interface
# Original:  Allows viewing of various interface properties
# ------------------------------
# Index: 896
# Hindi: (क्रियान्वित नहीं हुआ है)
# Translated:  (not implemented)
# Original:  (not implemented)
# ------------------------------
# Index: 897
# Hindi: नाम
# Translated:  Name
# Original:  Name
# ------------------------------
# Index: 898
# Hindi: यूआरआई
# Translated:  URI
# Original:  URI
# ------------------------------
# Index: 899
# Hindi: प्रारंभ
# Translated:  Start
# Original:  Start
# ------------------------------
# Index: 900
# Hindi: अंत
# Translated:  Ending
# Original:  End
# ------------------------------
# Index: 901
# Hindi: बहुत अधिक चयनीय शिशु हैं
# Translated:  There are too many picky babies
# Original:  Too many selectable children
# ------------------------------
# Index: 902
# Hindi: (संशोधनीय)
# Translated:  (modifiable)
# Original:  (Editable)
# ------------------------------
# Index: 903
# Hindi: तेज चुनाव
# Translated:  fast election
# Original:  Quick Select
# ------------------------------
# Index: 904
# Hindi: प्लग-इन जिसमें हैं एक्सेसेबेलों को तेजी से चुनने के लिए कई विधियां
# Translated:  Plug-in with multiple methods for quickly selecting accessible items
# Original:  Plugin with various methods of selecting accessibles quickly.
# ------------------------------
# Index: 905
# Hindi: अंतिम बार फोकस किए गए एक्सेसेबल को जांचें
# Translated:  Check last focused accessible
# Original:  Inspect last focused accessible
# ------------------------------
# Index: 906
# Hindi: माउस के अधीन जो एक्सेसेबल है, उसे जांचें
# Translated:  Check what's accessible under the mouse
# Original:  Inspect accessible under mouse
# ------------------------------
# Index: 907
# Hindi: स्कीमाः
# Translated:  Schema:
# Original:  Sche _ ma:
# ------------------------------
# Index: 908
# Hindi: सत्यापन
# Translated:  verification
# Original:  V _ alidate
# ------------------------------
# Index: 909
# Hindi: खाली
# Translated:  Empty
# Original:  Idle
# ------------------------------
# Index: 910
# Hindi: कोई विवरण नहीं
# Translated:  no description
# Original:  No description
# ------------------------------
# Index: 911
# Hindi: एटी-एसपीआई सत्यापक
# Translated:  AT-SPI Verifier
# Original:  AT - SPI Validator
# ------------------------------
# Index: 912
# Hindi: अनुप्रयोग की पहुंचनीयता का सत्यापन करता है
# Translated:  Verifies the accessibility of the application
# Original:  Validates application accessibility
# ------------------------------
# Index: 913
# Hindi: स्तर
# Translated:  level
# Original:  Level
# ------------------------------
# Index: 914
# Hindi: भूमिका
# Translated:  Role
# Original:  Role
# ------------------------------
# Index: 915
# Hindi: सहेज रहे हैं
# Translated:  are saving
# Original:  Saving
# ------------------------------
# Index: 916
# Hindi: पुष्टि कर रहे हैं
# Translated:  are confirming
# Original:  Validating
# ------------------------------
# Index: 917
# Hindi: अपवाद
# Translated:  Exception
# Original:  EXCEPT
# ------------------------------
# Index: 918
# Hindi: त्रुटि
# Translated:  Error
# Original:  ERROR
# ------------------------------
# Index: 919
# Hindi: चेतावनी
# Translated:  alert
# Original:  WARN
# ------------------------------
# Index: 920
# Hindi: सूचना
# Translated:  Information
# Original:  INFO
# ------------------------------
# Index: 921
# Hindi: दोषमुक्त करें
# Translated:  absolve
# Original:  DEBUG
# ------------------------------
# Index: 922
# Hindi: मूल
# Translated:  Original
# Original:  Basic
# ------------------------------
# Index: 923
# Hindi: मूलभूत जीयूआई अनुप्रयोग पहुंचनीयता का परीक्षण करता है
# Translated:  Basic GUI application accessibility testing
# Original:  Tests fundamental GUI application accessibility
# ------------------------------
# Index: 924
# Hindi: % s जिस पर कार्रवाई हो सकती है, वह न तो फोकस करने योग्य है न ही चयनीय
# Translated:  %s that is actionable is neither focusable nor selectable
# Original:  actionable% s is not focusable or selectable
# ------------------------------
# Index: 925
# Hindi: अंतर्क्रियात्मक% s कार्रवाई करने योग्य नहीं है
# Translated:  interactive %s action is not actionable
# Original:  interactive% s is not actionable
# ------------------------------
# Index: 926
# Hindi: एक से अधिक विडजेट फोकस में है
# Translated:  More than one widget is in focus
# Original:  more than one focused widget
# ------------------------------
# Index: 927
# Hindi: % s का कोई पाठ अंतराफलक नहीं है
# Translated:  %s has no text interface
# Original:  % s has no text interface
# ------------------------------
# Index: 928
# Hindi: अभिभावक में% s सूची शिशु सूची सेमेल नहीं खाती
# Translated:  %s list in parent does not match child list
# Original:  % s index in parent does not match child index
# ------------------------------
# Index: 929
# Hindi: % s संबंध के लिए अन्योन्य गायब है
# Translated:  Relation missing for %s
# Original:  Missing reciprocal for% s relation
# ------------------------------
# Index: 930
# Hindi: % s गायब नाम या सूचक
# Translated:  %s missing name or pointer
# Original:  % s missing name or label
# ------------------------------
# Index: 931
# Hindi: फोकस योग्य% s में सारणी अंतराफलक है, लेकिन कोई चयनीय अंतराफलक नहीं हैbutton has focused state without focusable state
# Translated:  Focusable %s has table interface but no selectable interface button has focused state without focusable state
# Original:  focusable% s has a table interface, but not a selection interface
# ------------------------------
# Index: 932
# Hindi: % s में% s स्थिति है, पर उसके साथ% s स्थिति नहीं है
# Translated:  %s has %s status, but %s doesn't have status with it
# Original:  % s has% s state without% s state
# ------------------------------
# Index: 933
# Hindi: % s किसी समुच्चय का सदस्य नहीं है
# Translated:  %s is not a member of any set
# Original:  % s does not belong to a set
# ------------------------------
# Index: 934
# Hindi: % (rolename) s सूची% (num) d पंक्ति और स्तंभ से मेल नहीं खातेparent indexrow and column index
# Translated:  % (rolename) s list % (num) d row and column do not match parent index row and column index
# Original:  % (rolename) s index% (num) d does not match row and column
# ------------------------------
# Index: 935
# Hindi: % (rolename) s अभिभावक सूची% (num1) d पंक्ति और स्तंभ सूची% (num2) d से मेल नहीं खाते
# Translated:  %(rolename)s do not match parent list %(num1)d row and column list %(num2)d
# Original:  % (rolename) s parent index% (num1) d does not match row and column index% (num2) d
# ------------------------------
# Index: 936
# Hindi: % s का कोई नाम या विवरण नहीं
# Translated:  %s has no name or description
# Original:  % s has no name or description
# ------------------------------
# Index: 937
# Hindi: पसंद (_ P)...
# Translated:  Like(_P)...
# Original:  _ Preferences...
# ------------------------------
# Index: 938
# Hindi: विषय सूची (_ C)
# Translated:  Table of Contents (_ C)
# Original:  _ Contents
# ------------------------------
# Index: 939
# Hindi: एक्सेरसाइसर आपके डेस्कटोप में मौजूद अनुप्रयोग नहीं देख पाया। इस समस्या के समाधान के लिए आपको डेस्कटोप पहुंचनीयता को सक्रिय करना होगा। क्या आप इसे सक्रिय करना चाहते हैं?
# Translated:  Exerciser could not see the applications on your desktop. To resolve this issue, you need to activate desktop accessibility. Do you want to activate it?
# Original:  Accerciser could not see the applications on your desktop. You must enable desktop accessibility to fix this problem. Do you want to enable it now?
# ------------------------------
# Index: 940
# Hindi: टिप्पणीः परिवर्तन सत्रांत (लोगआउट) के बाद ही प्रभाव में आएंगे।
# Translated:  Note: Changes will take effect only after logout.
# Original:  Note: Changes only take effect after logout.
# ------------------------------
# Index: 941
# Hindi: <dead>
# Translated:  <dead>
# Original:  < dead >
# ------------------------------
# Index: 942
# Hindi: शिशु
# Translated:  baby
# Original:  Children
# ------------------------------
# Index: 943
# Hindi: बच्चों के बिना अनुप्रयोग छिपाएँ/दिखाएँ (_ H)
# Translated:  Hide/show apps without children (_ H)
# Original:  _ Hide / Show Applications without children
# ------------------------------
# Index: 944
# Hindi: पंजी ताजा करें (_ R)
# Translated:  Refresh Register (_ R)
# Original:  _ Refresh Registry
# ------------------------------
# Index: 945
# Hindi: सभी को ताजा करें
# Translated:  refresh all
# Original:  Refresh all
# ------------------------------
# Index: 946
# Hindi: आसंधि (नोड) को ताजा करें (_ N)
# Translated:  Refresh the node (_ N)
# Original:  Refresh _ Node
# ------------------------------
# Index: 947
# Hindi: चुनी गई आसंधियों (नोड) के शिशुओं को ताजा करें
# Translated:  Refresh children of selected nodes
# Original:  Refresh selected node 's children
# ------------------------------
# Index: 948
# Hindi: घटक
# Translated:  Constituent
# Original:  Component
# ------------------------------
# Index: 949
# Hindi: कार्य
# Translated:  Work
# Original:  Task
# ------------------------------
# Index: 950
# Hindi: कुंजी
# Translated:  Key
# Original:  Key
# ------------------------------
# Index: 951
# Hindi: आल्ट
# Translated:  alt
# Original:  Alt
# ------------------------------
# Index: 952
# Hindi: कंट्रोल
# Translated:  control
# Original:  Ctrl
# ------------------------------
# Index: 953
# Hindi: शिफ्ट
# Translated:  shift
# Original:  Shift
# ------------------------------
# Index: 954
# Hindi: ऊपरी पटल
# Translated:  upper plate
# Original:  Top panel
# ------------------------------
# Index: 955
# Hindi: निचला पटल
# Translated:  lower plate
# Original:  Bottom panel
# ------------------------------
# Index: 956
# Hindi: एक्सेर्साइसर पसंद
# Translated:  exerciser choice
# Original:  accerciser Preferences
# ------------------------------
# Index: 957
# Hindi: प्लगइन्स
# Translated:  plugins
# Original:  Plugins
# ------------------------------
# Index: 958
# Hindi: सार्वत्रिक फटाफट कुंजियां
# Translated:  universal hotkeys
# Original:  Global Hotkeys
# ------------------------------
# Index: 959
# Hindi: हाइलाइटन
# Translated:  highlighten
# Original:  Highlighting
# ------------------------------
# Index: 960
# Hindi: हाइलाइट अवधिः
# Translated:  Highlight period:
# Original:  Highlight duration:
# ------------------------------
# Index: 961
# Hindi: सीमांत रंगः
# Translated:  Border color:
# Original:  Border color:
# ------------------------------
# Index: 962
# Hindi: हाइलाइट बक्से का सीमांत रंग
# Translated:  border color of highlight boxes
# Original:  The border color of the highlight box
# ------------------------------
# Index: 963
# Hindi: भराई का रंगः
# Translated:  Filling colour:
# Original:  Fill color:
# ------------------------------
# Index: 964
# Hindi: हाइलाइट बक्से का भराई रंग
# Translated:  fill color of highlight boxes
# Original:  The fill color of the highlight box
# ------------------------------
# Index: 965
# Hindi: रविशंकर श्रीवास्तव (raviratlami @yahoo. com) राजेश रंजन (rajeshkajha @yahoo. com) ल. बालसुब्रमण्यम (l. balasubramaniam @gmail. com)
# Translated:  Ravi Shankar Srivastava (raviratlami @yahoo. com) Rajesh Ranjan (rajeshkajha @yahoo. com) Lt. Balasubramaniam (l.balasubramaniam@gmail.com)
# Original:  translator - credits
# ------------------------------
# Index: 966
# Hindi: एक अंतर्क्रियात्मक पाइथन पहुंचनीयता अन्वेषक
# Translated:  An interactive Python accessibility explorer
# Original:  An interactive Python accessibility explorer
# ------------------------------
# Index: 967
# Hindi: एक्सेर्साइसर सर्वाधिकार (c) 2006,2007 आईबीएम निगम (बीएसडी)
# Translated:  Exerciser Copyright (c) 2006,2007 IBM Corporation (BSD)
# Original:  accerciser Copyright (c) 2006, 2007 IBM Corporation (BSD)
# ------------------------------
# Index: 968
# Hindi: नया बीएसडी लाइसेन्स विवरण के लिए देखिए प्रतिलिपीकरण और सूचना फाइलें
# Translated:  See Copying and Information Files for new BSD license details
# Original:  The New BSD License See the COPYING and NOTICE files for details.
# ------------------------------
# Index: 969
# Hindi: जाल स्थल
# Translated:  trap site
# Original:  Web site
# ------------------------------
# Index: 970
# Hindi: पसंद जोड़ें... (_ A)
# Translated:  Add Like... (_ A)
# Original:  _ Add Bookmark...
# ------------------------------
# Index: 971
# Hindi: चुने गए एक्सेसेबलों को पुस्तक-चिह्नित करें
# Translated:  Bookmark selected accessibles
# Original:  Bookmark selected accessible.
# ------------------------------
# Index: 972
# Hindi: पुस्तक चिह्न संपादित करें (_ E)...
# Translated:  Edit book icon (_ E)...
# Original:  _ Edit Bookmarks...
# ------------------------------
# Index: 973
# Hindi: पुस्तक-चिह्नों को प्रबंधित करें।
# Translated:  Manage bookmarks.
# Original:  Manage bookmarks.
# ------------------------------
# Index: 974
# Hindi: पुस्तक चिह्नों को संपादित करें...
# Translated:  Edit book marks...
# Original:  Edit Bookmarks...
# ------------------------------
# Index: 975
# Hindi: शीर्षक
# Translated:  Topic
# Original:  Title
# ------------------------------
# Index: 976
# Hindi: अनुप्रयोग
# Translated:  Application
# Original:  Application
# ------------------------------
# Index: 977
# Hindi: पथ
# Translated:  path
# Original:  Path
# ------------------------------
# Index: 978
# Hindi: पुस्तक-चिह्न जोड़ें...
# Translated:  Add bookmark...
# Original:  Add Bookmark...
# ------------------------------
# Index: 979
# Hindi: शीर्षकः
# Translated:  Title:
# Original:  Title:
# ------------------------------
# Index: 980
# Hindi: अनुप्रयोगः
# Translated:  Application:
# Original:  Application:
# ------------------------------
# Index: 981
# Hindi: पथः
# Translated:  Path:
# Original:  Path:
# ------------------------------
# Index: 982
# Hindi: प्लग-इन त्रुटियांviewport
# Translated:  plug-in errorsviewport
# Original:  Plugin Errors
# ------------------------------
# Index: 983
# Hindi: दृश्य
# Translated:  Scene
# Original:  View
# ------------------------------
# Index: 984
# Hindi: कोई दृश्य नहीं है
# Translated:  there is no view
# Original:  No view
# ------------------------------
# Index: 985
# Hindi: एकल प्लग-इन दृश्य
# Translated:  single plug-in view
# Original:  _ Single plugins view
# ------------------------------
# Index: 986
# Hindi: प्लग-इन दृश्य
# Translated:  plug-in view
# Original:  Plugin View
# ------------------------------
# Index: 987
# Hindi: प्लग-इन दृश्य (% d)
# Translated:  Plug-in View (%d)
# Original:  Plugin View (% d)
# ------------------------------
# Index: 988
# Hindi: नया दृश्य... (_ N)
# Translated:  New scene... (_ N)
# Original:  _ New view...
# ------------------------------
# Index: 989
# Hindi: नया दृश्य...
# Translated:  New scene...
# Original:  New View...
# ------------------------------
# Index: 990
# Hindi: फाइल (F)
# Translated:  file (F)
# Original:  _ File
# ------------------------------
# Index: 991
# Hindi: संपादित करेंmenu
# Translated:  editmenu
# Original:  _ Edit
# ------------------------------
# Index: 992
# Hindi: पसंद (_ B) menu
# Translated:  Like (_ B) menu
# Original:  _ Bookmarks
# ------------------------------
# Index: 993
# Hindi: दृश्य _ (V)
# Translated:  View _ (V)
# Original:  _ View
# ------------------------------
# Index: 994
# Hindi: मदद
# Translated:  Help
# Original:  _ Help
# ------------------------------
# Index: 995
# Hindi: एक्सेर्साइसर
# Translated:  exerciser
# Original:  Accerciser
# ------------------------------
# Index: 996
# Hindi: अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें
# Translated:  Give your app the benefit of accessibility exercises
# Original:  Give your application an accessibility workout
# ------------------------------
# Index: 997
# Hindi: एक्सेर्साइसर पहुंचनीयता अन्वेषक
# Translated:  Accessizer Accessibility Explorer
# Original:  Accerciser Accessibility Explorer
# ------------------------------
# Index: 998
# Hindi: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Translated:  List of plug-ins that are disabled by default
# Original:  A list of plugins that are disabled by default
# ------------------------------
# Index: 999
# Hindi: उन प्लग-इनों की सूची जिन्हें डिफोल्ट रूप से निष्क्रिय किया गया है
# Translated:  List of plug-ins that are disabled by default
# Original:  A list of plugins that are disabled by default.
# ------------------------------
# Time taken: 46.45200832299997

# %%
import nltk
from nltk.translate.bleu_score import corpus_bleu
references = [[eng] for eng in english_sentences]
candidates = translatedEngHin
bleu_score = corpus_bleu(references, candidates)
print(f"BLEU score: {bleu_score:.4f}")
# Out:
# BLEU score: 0.6291
